# %% [markdown]
# - これを試す
#   - http://delivery.acm.org/10.1145/1410000/1401920/p213-elkan.pdf?ip=136.187.169.129&id=1401920&acc=ACTIVE%20SERVICE&key=D2341B890AD12BFE%2E8B4B057ECC320604%2E4D4702B0C3E38B35%2E4D4702B0C3E38B35&__acm__=1531211567_f8f5482db93255fb472e2644d1332f99

# %%
import numpy as np
import pandas as pd
import json
import gensim
import collections
import matplotlib.pyplot as plt
import pprint
import itertools
import seaborn as sns
import networkx as nx
from IPython.display import display_svg
import tqdm

SYMBOLS = ["'", '>', '<','=', '(', ')', '[', ']', '**', ':', ',','"','-','/']

def remove_symbols(value):
    for s in SYMBOLS:
        value = value.replace(s, "")
    return value.replace("_", " ")


# %matplotlib inline

# %%
with open("./lt.json", "r") as f:
    raw_lt = json.load(f)

# %%
# カテゴリ別分類

lt_per_cat = {}
for ltid, value in raw_lt.items():
    if value['cat'] not in lt_per_cat:
        lt_per_cat[value['cat']] = [value['lt']]
    else:
        lt_per_cat[value['cat']].append(value['lt'])

# %%
# カテゴリ別コーパス作成

all_corpus = dict()
for cat, lts in lt_per_cat.items():
    corpus = []
    for lt in lts:
        words = [remove_symbols(t) for t in lt.split()]
        split_words = []
        for w in words:
            if len(w.split()) > 1: # さらに分割できる場合
                split_words.extend(w.split())
            else:
                split_words.append(w)
        split_words = [t.lower() for t in split_words if t != '']
        corpus.extend(split_words)
    all_corpus[cat] = corpus

# %%
## TF-IDF

df = dict()
for cat, words in all_corpus.items():
    for word in set(words):
        if word not in df:
            df[word] = 1
        else:
            df[word] += 1
            
tfidfs = {}
for cat, words in all_corpus.items():
    all_word_freq = len(words)
    tfidf_per_word = {}
    
    for word, cnt in collections.Counter(words).items():
        tf = cnt/all_word_freq
        tfidf = tf/np.log(len(all_corpus.keys())/df[word])
        tfidf_per_word[word] = tfidf
    
    tfidfs[cat] = tfidf_per_word
    
for cat, tfidfs_per_word in tfidfs.items():
    print(cat)
    pprint.pprint(sorted(tfidfs_per_word.items(), key=lambda x:x[1])[-10::][::-1])
    print()
# Out:
# system(cron)
# [('cmd', 0.06515396958853382),
#  ('usrsbincron', 0.062051399608127465),
#  ('a', 0.025305948826832625),
#  ('root', 0.021081836661046363),
#  ('l', 0.015512849902031866),
#  ('usrsbinchecksupport', 0.015512849902031866),
#  ('adjkerntz', 0.015512849902031866),
#  ('newsyslog', 0.015512849902031866),
#  ('etccrontab', 0.007756424951015933),
#  ('reload', 0.007756424951015933)]
#
# network(lacp)
# [('for', 0.05630897414532094),
#  ('not', 0.049232804344377865),
#  ('state', 0.04481276120079805),
#  ('lacp', 0.04084605853077733),
#  ('ifl', 0.0343498819259277),
#  ('info', 0.0343498819259277),
#  ('found', 0.025762411444445774),
#  ('current', 0.01932180858333433),
#  ('is', 0.014077243536330235),
#  ('cleared', 0.014008650243425203)]
#
# service(ntp)
# [('xntpd', 0.049547102414368445),
#  ('kernel', 0.04114558319337836),
#  ('time', 0.040412833429517556),
#  ('to', 0.03999419579271391),
#  ('on', 0.023888655698014946),
#  ('sync', 0.01311540946262694),
#  ('from', 0.01135114340161109),
#  ('reset', 0.010241300495545778),
#  ('ntpd', 0.010200874026487622),
#  ('changed', 0.00926859498021151)]
#
# monitor(syslog)
# [('message', 0.09368810631745932),
#  ('queue', 0.031362935671499205),
#  ('last', 0.031362935671499205),
#  ('slot', 0.028414649412714665),
#  ('messages', 0.028414649412714665),
#  ('times', 0.028414649412714665),
#  ('repeated', 0.028414649412714665),
#  ('lost', 0.025090348537199363),
#  ('syslog', 0.025090348537199363),
#  ('overflowed.', 0.02090862378099947)]
#
# network(mtu)
# [('rpd', 0.08291848287818057),
#  ('index', 0.06562923183659587),
#  ('event', 0.0585866006452371),
#  ('multicast', 0.04393995048392782),
#  ('broadcast', 0.04393995048392782),
#  ('mtu', 0.0431268029157446),
#  ('up', 0.03622750322214652),
#  ('address', 0.030080064591773106),
#  ('#', 0.023588782232760896),
#  ('to', 0.01339907067167065)]
#
# mgmt(login)
# [('login', 0.11521463057489),
#  ('from', 0.07531047064530434),
#  ('for', 0.038589366896793376),
#  ('user', 0.03194779228075793),
#  ('failed', 0.029242376397500883),
#  ('host', 0.020177553019426066),
#  ('evt', 0.01985535320309238),
#  ('on', 0.01653830009862573),
#  ('access', 0.010088776509713031),
#  ('of', 0.00920237991201062)]
#
# system(ui)
# [('ui', 0.049931581112534144),
#  ('mgd', 0.048683291584720796),
#  ('event', 0.03985345416820341),
#  ('user', 0.035868108751383077),
#  ('login', 0.02333998041111952),
#  ('child', 0.015941381667281363),
#  ('status', 0.014118143410154634),
#  ('is', 0.010888475663459851),
#  ('file', 0.010502991185003785),
#  ('class', 0.009751878070008704)]
#
# mgmt(command)
# [('to', 0.09540784056575126),
#  ('junoscript', 0.041716483110042314),
#  ('user', 0.04055769191254114),
#  ('ui', 0.032666082583260286),
#  ('client', 0.028354858324041374),
#  ('mgd', 0.027221735486050242),
#  ('command', 0.02362181698165436),
#  ('cmd', 0.020858241555021157),
#  ('used', 0.017381867962517634),
#  ('run', 0.015209134467202928)]
#
# mgmt(ssh)
# [('from', 0.10061240742337102),
#  ('for', 0.05212070334112352),
#  ('sshd', 0.03974366503826346),
#  ('by', 0.02962214751954635),
#  ('received', 0.025924737884759203),
#  ('port', 0.01987183251913173),
#  ('user', 0.015897466015305384),
#  ('password', 0.014307719413774844),
#  ('disconnect', 0.011923099511479037),
#  ('accepted', 0.010802263413098138)]
#
# network(l2)
# [('state', 0.041825243787411516),
#  ('l2cp', 0.03205988979753252),
#  ('rpd', 0.019105194300586634),
#  ('machines', 0.01602994489876626),
#  ('received', 0.013941747929137173),
#  ('initializing', 0.012823955919013008),
#  ('evt', 0.012619180035743156),
#  ('address', 0.011971258029453136),
#  ('message', 0.011971258029453136),
#  ('with', 0.011328282753591847)]
#
# system(unix)
# [('init', 0.04207860535926143),
#  ('signal', 0.037570183356483426),
#  ('pid', 0.03155895401944608),
#  ('sent', 0.024044917348149394),
#  ('terminate', 0.01923593387851951),
#  ('kernel', 0.018858392296965083),
#  ('to', 0.01649760576449449),
#  ('task', 0.01402620178642048),
#  ('on', 0.01313876063390822),
#  ('by', 0.012445416145364957)]
#
# network(storm)
# [('port', 0.14426950408889636),
#  ('evt', 0.0851794652412663),
#  ('storm', 0.0432808512266689),
#  ('nif', 0.0432808512266689),
#  ('multicast', 0.018033688011112044),
#  ('recovered.', 0.018033688011112044),
#  ('detected.', 0.018033688011112044),
#  ('broadcast', 0.018033688011112044)]
#
# system(pic)
# [('pic', 0.06654497421074555),
#  ('slot', 0.05064308363963537),
#  ('init', 0.0283925223299181),
#  ('system', 0.015970793810578934),
#  ('to', 0.014610425769294012),
#  ('on', 0.008726852081562654),
#  ('fpc', 0.008684329302197173),
#  ('received', 0.006945151182411505),
#  ('the', 0.006286307397879431),
#  ('sent', 0.005323597936859644)]
#
# network(pfe)
# [('to', 0.03666134614332109),
#  ('pfe', 0.01815380379145659),
#  ('kernel', 0.014667638453195065),
#  ('pfeman', 0.011020587117901803),
#  ('on', 0.010948967194923517),
#  ('pfed', 0.008682886820165058),
#  ('after', 0.007040894090687723),
#  ('failed', 0.006637555277527978),
#  ('destination', 0.006411977959506504),
#  ('retries', 0.0060112293370373476)]
#
# system(ppe)
# [('to', 0.044739269869815565),
#  ('the', 0.028874394997039424),
#  ('ppe', 0.024452458320151922),
#  ('error', 0.024452458320151922),
#  ('evt', 0.019249596664692947),
#  ('and', 0.014320462557330962),
#  ('count', 0.013296345993759515),
#  ('queue', 0.012226229160075961),
#  ('software', 0.012226229160075961),
#  ('trap', 0.011076897228685378)]
#
# mgmt(pam)
# [('error', 0.13961564911828678),
#  ('login', 0.08176522169830903),
#  ('for', 0.07628957787430579),
#  ('authentication', 0.06980782455914339),
#  ('pam', 0.05584625964731471),
#  ('user', 0.0465385497060956),
#  ('b^', 0.009307709941219119)]
#
# mgmt(su)
# [('to', 0.32995211528988977),
#  ('on', 0.1970814095086233),
#  ('su', 0.09016844005556023),
#  ('bad', 0.04903027585198821)]
#
# egp(bgp)
# [('rpd', 0.051038441273829185),
#  ('to', 0.03782460277632309),
#  ('from', 0.021087333954886517),
#  ('as', 0.020304049961333927),
#  ('bgp', 0.016833903240669582),
#  ('peer', 0.014609658413025308),
#  ('message', 0.01433610224612095),
#  ('error', 0.012551594521551883),
#  ('received', 0.010916517058126853),
#  ('notification', 0.010336607253042727)]
#
# network(mld)
# [('is', 0.09854070475431165),
#  ('kernel', 0.09429196148482541),
#  ('not', 0.08615740760266126),
#  ('input', 0.05280670568015792),
#  ('src', 0.04084605853077733),
#  ('linklocal', 0.03606737602222408),
#  ('grp', 0.03005614668518674),
#  ('mld6', 0.03005614668518674)]
#
# system(fpc)
# [('luchip', 0.017505504680242652),
#  ('is', 0.011544517711802201),
#  ('error', 0.010563666617387809),
#  ('read', 0.010060634873702673),
#  ('pio', 0.009658209478754566),
#  ('lu', 0.008450933293910246),
#  ('register', 0.007545476155277005),
#  ('mqchip', 0.007545476155277005),
#  ('init', 0.007042444411591872),
#  ('trinity', 0.006036380924221604)]
#
# network(arp)
# [('from', 0.03266753478952028),
#  ('to', 0.030693220026966492),
#  ('for', 0.027499731559342787),
#  ('kernel', 0.02631403576320709),
#  ('mac', 0.025163285596900526),
#  ('is', 0.01833315437289519),
#  ('l2ald', 0.016775523731267016),
#  ('addr', 0.016775523731267016),
#  ('limit', 0.014736755073532443),
#  ('state', 0.014590201321190063)]
#
# interface(port)
# [('port', 0.11136593298090244),
#  ('to', 0.083356323862709),
#  ('the', 0.05977506332720441),
#  ('evt', 0.05977506332720441),
#  ('on', 0.016596329221778804),
#  ('error', 0.015186263588304879),
#  ('in', 0.012576420525842484),
#  ('up.', 0.01138969769122866),
#  ('administratively.', 0.010319004260406906),
#  ('check', 0.0095132801909144)]
#
# mgmt(config)
# [('set', 0.04842633742593589),
#  ('user', 0.04106391937677108),
#  ('ui', 0.03817908475105306),
#  ('mgd', 0.03589973640770661),
#  ('cfg', 0.03014819397281927),
#  ('audit', 0.024118555178255414),
#  ('other', 0.016438562661903612),
#  ('unconfigured', 0.007711523930869149),
#  ('delete', 0.006887302933445782),
#  ('interface', 0.006329166777414101)]
#
# interface(agg)
# [('to', 0.04653170856652292),
#  ('kernel', 0.04351936683915019),
#  ('from', 0.021010529853943603),
#  ('evt', 0.01820074043616801),
#  ('bundle', 0.012947263187465056),
#  ('port', 0.012330726845204816),
#  ('link', 0.012330726845204816),
#  ('mac', 0.011560056417379514),
#  ('set', 0.01035974252548829),
#  ('for', 0.01010673894916017)]
#
# monitor(snmp)
# [('to', 0.022040023418185173),
#  ('chassisd', 0.021730180707561338),
#  ('snmp', 0.019259438207046287),
#  ('trap', 0.013802597381716504),
#  ('index', 0.009525264247403771),
#  ('send', 0.007794521340755697),
#  ('rpd', 0.006756257316513937),
#  ('snmpd', 0.006377335642436479),
#  ('fru', 0.0059521799329407135),
#  ('generated', 0.005432545176890334)]
#
# interface(if_event)
# [('rpd', 0.09045615737288923),
#  ('index', 0.06671134013619834),
#  ('event', 0.05955258859038862),
#  ('multicast', 0.04466444144279146),
#  ('broadcast', 0.04466444144279146),
#  ('address', 0.029593752391245877),
#  ('up', 0.024207084655021683),
#  ('#', 0.022814070237982563),
#  ('updown', 0.012313505159666822),
#  ('add', 0.011417977511691052)]
#
# interface(vlan)
# [('vlan', 0.053471203894835784),
#  ('is', 0.0429995802564269),
#  ('evt', 0.041299134662432145),
#  ('to', 0.023996517475628348),
#  ('interface', 0.022813769338588096),
#  ('status', 0.020649567331216073),
#  ('address', 0.01958933132092331),
#  ('table', 0.014263352975123843),
#  ('rsp', 0.01311540946262694),
#  ('not', 0.012531986560387093)]
#
# mgmt(enable)
# [('rsp', 0.07213475204444818),
#  ('enable', 0.05770780163555854),
#  ('after', 0.042245364544126335),
#  ('login', 0.042245364544126335),
#  ('out', 0.03606737602222409),
#  ('timed', 0.032676846824621866),
#  ('seconds.', 0.02885390081777927),
#  ('sorry', 0.024044917348149394)]
#
# vpn(mpls)
# [('rpd', 0.07943192195624334),
#  ('flag', 0.058178245670631026),
#  ('label', 0.04030137233787648),
#  ('lsp', 0.03904685491101651),
#  ('on', 0.027848460039261988),
#  ('mpls', 0.02665849532077432),
#  ('route', 0.01989257909486041),
#  ('change', 0.017454174786104826),
#  ('up', 0.015514822032093182),
#  ('to', 0.014345744143038686)]
#
# network(stp)
# [('rpd', 0.08817781984886139),
#  ('state', 0.05630321279074627),
#  ('to', 0.050761863890752275),
#  ('stp', 0.04624022566951806),
#  ('index', 0.03453247508496096),
#  ('handler', 0.023120112834759027),
#  ('mcsn', 0.016248217132356284),
#  ('tcgeneration', 0.01541340855650602),
#  ('ifl', 0.012330726845204816),
#  ('from', 0.012006017059396343)]
#
# igp(ospf)
# [('to', 0.12411991797738801),
#  ('rpd', 0.08085270315295284),
#  ('from', 0.044034608023491295),
#  ('state', 0.029500563799898405),
#  ('ospf', 0.02894435191752152),
#  ('neighbor', 0.027810428069801035),
#  ('changed', 0.0239705042591677),
#  ('reason', 0.022612774935563695),
#  ('event', 0.022612774935563695),
#  ('due', 0.01986459147842931)]
#
# network(rsvp)
# [('rpd', 0.11573338855163057),
#  ('down', 0.06279255450477964),
#  ('for', 0.037900271059350635),
#  ('rsvp', 0.03745458279230963),
#  ('bypass', 0.03606737602222408),
#  ('interface', 0.030162435423614076),
#  ('reason', 0.018496090267807228),
#  ('on', 0.015160108423740255),
#  ('neighbor', 0.014217189990811747),
#  ('up', 0.012254152017106565)]
#
# vpn(l2vc)
# [('rpd', 0.1146311658035198),
#  ('to', 0.08798723074397061),
#  ('of', 0.043864677580583954),
#  ('state', 0.041825243787411516),
#  ('up', 0.03398484826077554),
#  ('changed', 0.03398484826077554),
#  ('vc', 0.03205988979753252),
#  ('from', 0.031215644354430493),
#  ('layer', 0.01923593387851951),
#  ('down', 0.01892877005361473)]
#
# vpn(vpls)
# [('rpd', 0.1322667297732921),
#  ('vpls', 0.0502720720378798),
#  ('id', 0.036992180535614455),
#  ('enabled', 0.027744135401710838),
#  ('intf', 0.027744135401710838),
#  ('create', 0.022195308321368668),
#  ('dyn', 0.022195308321368668),
#  ('0......', 0.018496090267807228),
#  ('nsr', 0.018496090267807228),
#  ('profilesession', 0.018496090267807228)]
#
# network(tcp)
# [('from', 0.10405214784810164),
#  ('kernel', 0.08381507687540037),
#  ('packet', 0.04007486224691565),
#  ('ok', 0.04007486224691565),
#  ('auth', 0.03630760758291318),
#  ('tcp', 0.03630760758291318),
#  ('md5', 0.03205988979753252),
#  ('digest', 0.026716574831277103),
#  ('has', 0.00801497244938313),
#  ('unexpectedly', 0.00801497244938313)]
#
# system(fan)
# [('chassisd', 0.07398436107122891),
#  ('to', 0.050761863890752275),
#  ('speed', 0.044390616642737336),
#  ('and', 0.03249643426471257),
#  ('set', 0.02071948505097658),
#  ('impellers', 0.018496090267807228),
#  ('fans', 0.018496090267807228),
#  ('blowers', 0.018496090267807228),
#  ('at', 0.01508623872368868),
#  ('normal', 0.013872067700855419)]
#
# mgmt(ftp)
# [('from', 0.20810429569620328),
#  ('login', 0.07040894090687722),
#  ('failed', 0.06637555277527978),
#  ('ftpd', 0.053433149662554205),
#  ('ftp', 0.04007486224691565),
#  ('connection', 0.029928145073632836),
#  ('as', 0.020037431123457825)]
#
# network(sfp)
# [('link', 0.07335737496045577),
#  ('sfp', 0.04401442497627346),
#  ('power', 0.03667868748022789),
#  ('low', 0.03667868748022789),
#  ('mic', 0.033230691686056135),
#  ('receive', 0.019944518990639273),
#  ('current', 0.018339343740113943),
#  ('output', 0.014671474992091154),
#  ('cleared', 0.013296345993759515),
#  ('bias', 0.012226229160075963)]
#
# system(power)
# [('is', 0.08900450752002342),
#  ('chassisd', 0.031025699804063733),
#  ('err', 0.02915360058506026),
#  ('power', 0.029086593566309746),
#  ('status', 0.027477246852021384),
#  ('for', 0.025429859291435264),
#  ('ps', 0.0232692748530478),
#  ('input', 0.02044130542457726),
#  ('evt', 0.01831816456801426),
#  ('check', 0.01457680029253013)]
#
# system(system_conf)
# [('chassisd', 0.1373995277037108),
#  ('configuration', 0.0686997638518554),
#  ('new', 0.060350520777323335),
#  ('complete', 0.05603460097370081),
#  ('using', 0.04668120974945981),
#  ('parse', 0.04121985831111324)]
#
# network(socket)
# [('kernel', 0.0905202830254324),
#  ('peer', 0.07136818134762864),
#  ('error', 0.02885390081777927),
#  ('is', 0.015766512760689865),
#  ('msg', 0.014426950408889635),
#  ('not', 0.013785185216425803),
#  ('ifd', 0.013070738729848746),
#  ('down', 0.01135726203216884),
#  ('index', 0.010774132226507822),
#  ('message', 0.010774132226507822)]
#
# system(tnp)
# [('to', 0.0899869405336063),
#  ('kernel', 0.08571996498620492),
#  ('from', 0.06385018163406236),
#  ('neighbor', 0.03840487685829667),
#  ('version', 0.03081005516375686),
#  ('interface', 0.028517211673235125),
#  ('active', 0.02054003677583791),
#  ('on', 0.01791649177351121),
#  ('is', 0.01791649177351121),
#  ('adding', 0.016394261828283675)]
#
# system(alarm)
# [('alarm', 0.026011652012509896),
#  ('set', 0.025585010564266594),
#  ('cleared', 0.022768676912796635),
#  ('class', 0.02069879719345149),
#  ('craftd', 0.017510282818177392),
#  ('alarmd', 0.014591902348481163),
#  ('major', 0.014274687080035918),
#  ('color', 0.012688610737809707),
#  ('re', 0.012070603048672985),
#  ('pem', 0.008621859320480704)]
#
# system(gres)
# [('kernel', 0.08229116638675672),
#  ('for', 0.07166596709404484),
#  ('is', 0.05733277367523587),
#  ('not', 0.025063973120774186),
#  ('ready', 0.0237649795088159),
#  ('the', 0.020649567331216073),
#  ('engine', 0.01967311419394041),
#  ('routing', 0.01967311419394041),
#  ('index', 0.01958933132092331),
#  ('peer', 0.01853718996042302)]
#
# network(pim)
# [('rpd', 0.09967927461175635),
#  ('to', 0.05738297657215474),
#  ('pim', 0.03345379804959915),
#  ('the', 0.03291960009324301),
#  ('neighbor', 0.0306125830029901),
#  ('interface', 0.027277332904833595),
#  ('due', 0.01836754980179406),
#  ('instance', 0.017054008991995898),
#  ('message', 0.01561468438624322),
#  ('nbrdown', 0.014207324706357332)]
#
# egp(msdp)
# [('rpd', 0.09659929702543804),
#  ('of', 0.033268154344824906),
#  ('msdp', 0.027016761065336396),
#  ('active', 0.020309249845772315),
#  ('limit', 0.018986680693989365),
#  ('number', 0.018986680693989365),
#  ('instance', 0.017628863227681153),
#  ('configured', 0.016210056639201838),
#  ('exceeded', 0.016210056639201838),
#  ('messages', 0.014686223291964883)]
#
# interface(interface)
# [('in', 0.12800999463803955),
#  ('kernel', 0.053881120848471666),
#  ('plugged', 0.05152482288889155),
#  ('mic', 0.04668120974945981),
#  ('sfp+', 0.04121985831111324),
#  ('mode', 0.028017300486850406),
#  ('unplugged', 0.02060992915555662),
#  ('promiscuous', 0.01717494096296385)]
#
# system(others)
# [('pcie', 0.06074505435321951),
#  ('rpd', 0.045249144396126234),
#  ('for', 0.04149082305444701),
#  ('common', 0.030372527176609754),
#  ('status', 0.029887531663602206),
#  ('link', 0.025310439313841464),
#  ('bringup', 0.025310439313841464),
#  ('read', 0.025310439313841464),
#  ('handle', 0.015186263588304877),
#  ('took', 0.012655219656920732)]
#
# system(config_apply)
# [('rpd', 0.14328895725439975),
#  ('state', 0.10456310946852879),
#  ('task', 0.0801497244938313),
#  ('parseconfig', 0.04007486224691565),
#  ('foreground', 0.04007486224691565),
#  ('reconfig', 0.04007486224691565)]
#
# mgmt(config_process)
# [('to', 0.07763579183291525),
#  ('limit', 0.049700428875442744),
#  ('of', 0.03870412727698584),
#  ('policy', 0.03844334920543749),
#  ('eventd', 0.03394576566797561),
#  ('system', 0.028288138056646345),
#  ('number', 0.024850214437721372),
#  ('current', 0.021216103542484755),
#  ('exceeded', 0.021216103542484755),
#  ('because', 0.016972882833987804)]
#
# network(routing)
# [('rpd', 0.14328895725439975),
#  ('no', 0.04978166458145983),
#  ('buffer', 0.032686850567992136),
#  ('update', 0.032686850567992136),
#  ('retries', 0.030056146685186736),
#  ('krt', 0.030056146685186736),
#  ('q', 0.02404491734814939),
#  ('available', 0.020037431123457825),
#  ('space', 0.020037431123457825),
#  ('route', 0.018828367044518082)]
#
# mgmt(ui_error)
# [('read', 0.0457998425679036),
#  ('ui', 0.03586355627527254),
#  ('peer', 0.03236652215311956),
#  ('from', 0.02972918509945761),
#  ('mgd', 0.02869084502021803),
#  ('rpd', 0.027293134715123762),
#  ('timeout', 0.02682245367881037),
#  ('on', 0.025026210731253752),
#  ('error', 0.0228999212839518),
#  ('of', 0.020887941705039978)]
#
# system(None)
# [('to', 0.020807791054317373),
#  ('kernel', 0.014441111218396684),
#  ('for', 0.012428557356399667),
#  ('rpd', 0.008713517670875661),
#  ('is', 0.007989786871971216),
#  ('on', 0.007989786871971216),
#  ('not', 0.006597639320924511),
#  ('chassisd', 0.005686298021521816),
#  ('id', 0.005144745828995928),
#  ('port', 0.005144745828995928)]
#
# system(cos)
# [('for', 0.02649834077426868),
#  ('is', 0.02649834077426868),
#  ('to', 0.022181654809404355),
#  ('failed', 0.02007999915890817),
#  ('on', 0.01987375558070151),
#  ('not', 0.017376283886251013),
#  ('ifl', 0.016164650318083625),
#  ('cosd', 0.016164650318083625),
#  ('gencfg', 0.014144069028323172),
#  ('kernel', 0.012677910787875685)]
#
# system(ppm)
# [('to', 0.17597446148794121),
#  ('connection', 0.07182754817671881),
#  ('ppman', 0.04808983469629879),
#  ('established', 0.04808983469629878),
#  ('ppmd', 0.03205988979753252),
#  ('closed', 0.02178456454974791),
#  ('side', 0.01602994489876626),
#  ('remote', 0.01602994489876626),
#  ('disconnected;', 0.01602994489876626)]
#
# monitor(bfd)
# [('state', 0.10755062688191533),
#  ('bfdd', 0.04946382997333589),
#  ('new', 0.036210312466394),
#  ('interface', 0.03585020896063844),
#  ('local', 0.03091489373333493),
#  ('peer', 0.029129869937807605),
#  ('up', 0.029129869937807605),
#  ('trap', 0.028008725849675887),
#  ('addr', 0.027479905540742162),
#  ('discriminator', 0.020609929155556622)]
#
# system(lisence)
# [('to', 0.10701149685077507),
#  ('from', 0.0506199638179954),
#  ('licensecheck', 0.025994505241242586),
#  ('error', 0.01949587893093194),
#  ('rcp', 0.01949587893093194),
#  ('failed', 0.01614540472912211),
#  ('no', 0.01614540472912211),
#  ('copy', 0.01559670314474555),
#  ('priv', 0.012997252620621293),
#  ('config.license', 0.012997252620621293)]
#
# network(icmp)
# [('to', 0.2199680768599265),
#  ('of', 0.10966169395145987),
#  ('init', 0.0801497244938313),
#  ('rate', 0.05446141137436977),
#  ('periff', 0.04007486224691565),
#  ('icmp', 0.04007486224691565)]
#
# system(csu)
# [('from', 0.06348944614460439),
#  ('system', 0.05705573608035449),
#  ('evt', 0.04812399166173237),
#  ('to', 0.044739269869815565),
#  ('is', 0.040084354476330165),
#  ('on', 0.026722902984220108),
#  ('changed', 0.025920646978557615),
#  ('csu', 0.024452458320151926),
#  ('this', 0.018339343740113943),
#  ('other', 0.018339343740113943)]
#
# system(boot)
# [('by', 0.11947599499550361),
#  ('system', 0.04808983469629879),
#  ('event', 0.04808983469629879),
#  ('ui', 0.045188080906843404),
#  ('mgd', 0.045188080906843404),
#  ('reboot', 0.03606737602222409),
#  ('shutdown', 0.024044917348149394),
#  ('rebooted', 0.012022458674074697),
#  ('halt', 0.012022458674074697),
#  ('halted', 0.012022458674074697)]
#
# system(pci)
# [('error', 0.1479687221424578),
#  ('pci', 0.06658592496410601),
#  ('status', 0.03640148087233602),
#  ('info', 0.03082681711301204),
#  ('correctable', 0.01849609026780722),
#  ('err', 0.017380031118016694),
#  ('counts', 0.01541340855650602),
#  ('btlp', 0.009248045133903614),
#  ('id', 0.006165363422602408),
#  ('link', 0.006165363422602408)]
#
# interface(inet6)
# [('chassisd', 0.0686997638518554),
#  ('chassis', 0.04668120974945981),
#  ('linklocal', 0.04121985831111324),
#  ('cm', 0.04121985831111324),
#  ('maca5', 0.0343498819259277),
#  ('inet6', 0.0343498819259277),
#  ('java', 0.0343498819259277)]
#
# network(lldp)
# [('task', 0.14426950408889636),
#  ('reinitializing', 0.06535369364924373),
#  ('lldpd', 0.04808983469629879),
#  ('reinit', 0.03606737602222409),
#  ('done', 0.032676846824621866),
#  ('reconfigure', 0.032676846824621866)]
#
# network(mcsnoop)
# [('task', 0.14426950408889636),
#  ('reinitializing', 0.06535369364924373),
#  ('mcsnoopd', 0.04808983469629879),
#  ('reinit', 0.03606737602222409),
#  ('done', 0.032676846824621866),
#  ('reconfigure', 0.032676846824621866)]

# %%
'''LDA用のコーパス作成

[ [(word_id, cnt), ...], ... ]

'''

all_words = list(set([word for cat, words in all_corpus.items() for word in words]))
word_dict = {w:i for i, w in enumerate(all_words)}
inv_word_dict = {v:k for k,v in word_dict.items()}

corpus = []
for ltid, data in sorted(raw_lt.items()):
    cat = data['cat']
    lt = data['lt']
    if True: #cat == 'system(alarm)' or cat == 'service(ntp)':
#         for lt in lts:

        words = [remove_symbols(t) for t in lt.split()]
        split_words = []
        for w in words:
            if len(w.split()) > 1: # さらに分割できる場合
                split_words.extend(w.split())
            else:
                split_words.append(w)
        split_words = [t.lower() for t in split_words if t != '']

        split_words = split_words[:7] # 前方のみ残す

        lt_word_id_cnt = collections.Counter([word_dict[w] for w in split_words])

        corpus.append([(wid, cnt) for wid, cnt in lt_word_id_cnt.items()])

# %%
# 単語のカウント
word_cnt = {}
for wid, cnt in sorted(collections.Counter([c[0] for s in corpus for c in s]).items(), key= lambda x: x[1])[::-1]:
    print(inv_word_dict[wid], cnt)
    word_cnt[inv_word_dict[wid]] = cnt
# Out:
# ui 543
# user 537
# mgd 505
# cfg 470
# audit 466
# rpd 374
# set 324
# other 257
# event 198
# index 174
# broadcast 162
# delete 136
# multicast 115
# up 110
# kernel 105
# mpls 85
# lsp 83
# to 80
# evt 62
# from 61
# init 60
# login 55
# updown 55
# bgp 53
# for 51
# mtu 46
# chassisd 42
# file 41
# pic 41
# change 41
# alarm 41
# task 41
# address 40
# error 40
# trap 40
# received 39
# read 39
# mcsn 39
# sent 38
# is 38
# port 38
# add 36
# on 36
# snmp 36
# notification 36
# pointtopoint 35
# failed 34
# xntpd 34
# cmd 31
# luchip 30
# class 30
# pid 29
# down 28
# status 28
# deactivate 28
# bandwidth 27
# message 27
# signal 26
# state 26
# neighbor 26
# link 25
# cleared 25
# junoscript 24
# of 24
# connection 24
# info 24
# peer 23
# generated 23
# craftd 23
# alarmd 23
# used 22
# slot 22
# no 22
# switch 22
# reinitializing 22
# activate 21
# pci 21
# not 21
# pfe 20
# color 20
# terminate 19
# master 19
# recv 19
# chas 18
# bulkget 18
# pfeman 18
# system 18
# sshd 18
# config 18
# libjsnmp 17
# as 17
# time 17
# active 16
# secret 16
# re 16
# interface 16
# rsp 16
# lu 15
# failure 15
# snmpd 15
# with 15
# by 15
# realm 15
# ospf 15
# mqchip 15
# major 15
# fpc 15
# rsvp 14
# entry 14
# queue 14
# changed 14
# err 14
# pp 14
# in 14
# mac 14
# ns 13
# create 13
# cmtfpc 13
# send 13
# process 13
# the 13
# register 13
# access 13
# reinit 13
# ifl 13
# pem 12
# stp 12
# pio 12
# l2cp 12
# nbrdown 12
# op 12
# at 12
# minor 12
# id 12
# power 12
# reset 12
# child 12
# mib2d 12
# sa 11
# krt 11
# ok 11
# limit 11
# nbrup 11
# trap10 11
# timeout 11
# flags 11
# new 11
# v4 11
# done 11
# reconfigure 11
# supply 10
# pwr 10
# instance 10
# msdp 10
# sfp 10
# manager 10
# version 10
# commit 10
# complete 10
# configuration 10
# pfed 10
# addr 10
# hostif 10
# trap7 10
# src 10
# start 10
# encapsulation 9
# connect 9
# low 9
# mic 9
# cmt 9
# + 9
# ae 9
# auth 9
# request 9
# update 9
# jspec 9
# host 9
# errors 9
# sync 9
# starting 9
# found 9
# log 8
# ucode 8
# asic 8
# thread 8
# v 8
# destination 8
# turning 8
# pfealiveness 8
# number 8
# jsr 8
# last 8
# trinity 8
# synchronized 8
# nif 8
# local 8
# stream 8
# bist 8
# enabled 8
# loopback 8
# show 8
# logout 8
# group 8
# channel 8
# usrsbincron 8
# retries 7
# bypass 7
# chassism 7
# resync 7
# img 7
# program 7
# established 7
# socket 7
# ready 7
# ipc 7
# attempt 7
# load 7
# handler 7
# msg 7
# ntpd 7
# and 7
# initialized 7
# dcd 7
# tcp 7
# disconnect 7
# password 7
# cannot 7
# invalid 7
# storm 7
# cos 7
# mq 7
# initializing 7
# exited 7
# detected 7
# lacp 7
# csu 6
# input 6
# server 6
# rows 6
# reg 6
# device 6
# cm 6
# sending 6
# mask 6
# seg 6
# dest 6
# clksync 6
# vq 6
# allocate 6
# operation 6
# due 6
# proto 6
# software 6
# if 6
# machines 6
# packet 6
# inetd 6
# vlan 6
# administratively. 6
# many 6
# incorrect 6
# ps 6
# count 6
# bfdd 5
# ifdev 5
# q 5
# backup 5
# partial 5
# termination 5
# all 5
# adding 5
# exit 5
# unsupported 5
# ifd 5
# route 5
# receive 5
# online 5
# serverrouter 5
# toe 5
# initial 5
# connected 5
# normal 5
# l2alm 5
# made 5
# tcgeneration 5
# pam 5
# bad 5
# performing 5
# common 5
# ppe 5
# error. 5
# bundle 5
# detached 5
# processing 5
# will 5
# this 5
# linkspeed 5
# disconnected 5
# accepted 5
# authenticated 5
# fxp0 5
# gencfg 5
# pre 5
# setting 5
# up. 5
# client 5
# reason 5
# mpc 5
# dropped 5
# exiting 5
# rename 5
# disabled 5
# counts 5
# correctable 5
# tftpd 4
# tnp.tftpd 4
# fan 4
# duplicate 4
# idpd 4
# cosd 4
# nh 4
# type 4
# mgmt 4
# routing 4
# ftpd 4
# after 4
# closed 4
# drained 4
# iff 4
# su 4
# stratum 4
# vccpd 4
# decode 4
# sample 4
# runlength 4
# ignoring 4
# write 4
# sdrl 4
# conn 4
# thresh 4
# under 4
# over 4
# started 4
# vector 4
# npc 4
# has 4
# chassis 4
# initialization 4
# gumem 4
# pcie 4
# bringup 4
# li 4
# restart 4
# service 4
# max 4
# call 4
# cell 4
# reorder 4
# fi 4
# fpc1 4
# fpc11 4
# off 4
# specified 4
# authentication 4
# table 4
# caps 4
# requested 4
# default 4
# family 4
# check 4
# rt 4
# prl 4
# command 4
# ntp 4
# occurred 4
# handle; 4
# ifadminstatus 4
# ifindex 4
# lidx 4
# module 4
# pnac 4
# aggregatedetheroptions 4
# warning 4
# logged 4
# information 4
# insert 4
# ethernet 4
# kern 4
# exceeded 4
# pim.master 4
# pim 4
# cleanup 4
# classifier 4
# mode 4
# absent 4
# hw 4
# buffer 4
# head 4
# retry 4
# passed 4
# verify 4
# ddr3 4
# x 4
# notice 4
# current 4
# can 4
# dbase 4
# fatal 3
# tlv 3
# options 3
# mc 3
# built 3
# standby 3
# management 3
# detach 3
# nhop 3
# addandget 3
# perform 3
# unreachable 3
# veto 3
# eventd 3
# engine 3
# mastership 3
# slave 3
# ftp 3
# speed 3
# throttle 3
# rtsock 3
# rtslib 3
# succeeded 3
# hold 3
# notconnect. 3
# off. 3
# handle 3
# licensecheck 3
# vccp 3
# sfid 3
# reboot 3
# usrlibexecuipackage 3
# xcvr 3
# eswd 3
# vpls 3
# ack 3
# watchdog 3
# cmsfpc 3
# using 3
# listener 3
# output 3
# bias 3
# laser 3
# plugged 3
# peering 3
# estd 3
# transaction 3
# slots 3
# timestamp 3
# localup 3
# chip 3
# calling 3
# ppman 3
# sntpd 3
# lock 3
# pll 3
# builder 3
# man 3
# session 3
# list 3
# path 3
# total 3
# failures 3
# response 3
# nlri 3
# mismatch 3
# shutting 3
# empty 3
# lost 3
# value 3
# # 3
# be 3
# l2ald 3
# times 3
# repeated 3
# getnext 3
# recovered. 3
# detected. 3
# reasonhost 3
# arp 3
# enable 3
# unavailable 3
# temporarily 3
# resource 3
# copy 3
# btlp 3
# rldram 3
# rev 3
# jtag 3
# initiated 3
# string 3
# bootpd 3
# tnp.bootpd 3
# offline 3
# too 3
# because 3
# r8 3
# cant 3
# root 3
# cap 2
# monitor 2
# blocks 2
# tftp 2
# connected. 2
# transceiver 2
# dad 2
# feed 2
# dipswitch 2
# trap6 2
# idmem 2
# tnpv2 2
# sglinkrd 2
# entering 2
# rewrite 2
# based 2
# fc 2
# bcm5389 2
# disabled. 2
# fifo 2
# tcam 2
# hup 2
# fpga 2
# sigterm 2
# kmd 2
# source 2
# sendto 2
# messages 2
# syslog 2
# shop 2
# ifinfo 2
# ip 2
# l 2
# usrsbinchecksupport 2
# intf 2
# next 2
# indirect 2
# slowest 2
# possible 2
# bundlestate 2
# packets 2
# recovery 2
# pending 2
# reseting 2
# ix 2
# unable 2
# policy 2
# completed. 2
# u64 2
# a 2
# adjkerntz 2
# s 2
# gres 2
# parseconfig 2
# foreground 2
# reconfig 2
# logicalrouter 2
# top 2
# ddl 2
# parity 2
# communication 2
# loss 2
# reasonloss 2
# deleting 2
# tnpv3 2
# soreceive 2
# inputs 2
# parse 2
# group. 2
# normal. 2
# fans 2
# blowers 2
# out 2
# timed 2
# queuing 2
# rem 2
# attempted 2
# frag 2
# terminated 2
# reconnection 2
# dq 2
# attach 2
# connections 2
# aborted 2
# mvlan 2
# modem 2
# excessive 2
# reasonexcessive 2
# me 2
# io 2
# mcsnoopd 2
# lldpd 2
# called 2
# intr 2
# mpfe 2
# shutdown 2
# ifcm 2
# itable 2
# map 2
# cache 2
# loaded 2
# bd 2
# snooping 2
# cfmd 2
# linklocal 2
# dyn 2
# vc 2
# layer2 2
# pcf8584wr 2
# phy 2
# method 2
# writeconnect 2
# events 2
# mq0 2
# edit 2
# unreplicate 2
# soft 2
# rate 2
# periff 2
# icmp 2
# disable 2
# plane 2
# libjnx 2
# cms 2
# model 2
# locate 2
# base 2
# ms 2
# interval 2
# probe 2
# fabric 2
# sfp+ 2
# connecting 2
# creating... 2
# ... 2
# complete. 2
# layer 2
# forwarding 2
# prescaler 2
# hash 2
# replicated 2
# pools 2
# mem 2
# 4way 2
# jnh 2
# skipping... 2
# #; 2
# complete! 2
# initialising 2
# ddr 2
# memory 2
# mah 2
# absent. 2
# qx 2
# ppmd 2
# set. 2
# day 2
# took 2
# training 2
# information. 2
# diagnostic 2
# contains 2
# nvram 2
# onboard 2
# utc 2
# i2 2
# dev 2
# i2c 2
# creating 2
# hostname 2
# entered 2
# handles 2
# svc 2
# pool 2
# tb 2
# size 2
# buckets 2
# createqsize 2
# cmlc 2
# max6657 2
# max6697 2
# sys 2
# periodic 2
# maxfpc 2
# chassisid 2
# startup 2
# reconn 2
# entries 2
# udp 2
# netsnmp 2
# jnx 2
# identification 2
# protocol 2
# unauthenticated 2
# junos 2
# rollback 2
# was 2
# could 2
# pc 2
# fault 2
# data 2
# lmem 2
# hardware 2
# equipment 2
# 0800000000000000 2
# e3 2
# username 2
# different 2
# gumem.ucode.instr 2
# u256 2
# . 2
# joins 2
# attached 2
# leaves 2
# reinitialized 2
# l2cpd 2
# ppm 2
# frequency 2
# listening 2
# usec 2
# precision 2
# phase 2
# profile 2
# acess 2
# 802.1x 2
# spd 2
# value! 2
# reduced 2
# usrsbinsshd 2
# ifbd 2
# referred 2
# argument 2
# media 2
# threshold 2
# prefixlimit 2
# maximum 2
# configured 2
# lldp 2
# open 2
# failed; 2
# action 2
# unbind 2
# coscos 2
# credit 2
# wo 2
# dram 2
# done. 2
# block 2
# ddrio 2
# registering 2
# dmc 2
# boot 2
# bootstring 2
# expired 2
# taking 2
# fru 2
# dropping 2
# timer 2
# while 2
# wedge 2
# reasonfpc 2
# it 2
# ipv6 2
# plx 2
# newsyslog 2
# translatedtag. 1
# community 1
# nsa 1
# header 1
# ctl 1
# & 1
# advanced 1
# uncorrectable 1
# cap0 1
# stat 1
# dr 1
# added 1
# anycast 1
# router 1
# subnet 1
# seconds. 1
# bank 1
# ap 1
# nack 1
# rd 1
# clear 1
# chassiscontrol 1
# packetforwardingengine 1
# virtualchassiscontrol 1
# devstop 1
# eth 1
# ethswitch 1
# softwareforwarding 1
# chassismanager 1
# inetprocess 1
# tnpprocess 1
# halt 1
# halted 1
# ssh2 1
# ieee802.1 1
# 8021p 1
# reachable 1
# servers 1
# removed 1
# commands 1
# initialized. 1
# r6 1
# board 1
# recovered 1
# abort 1
# caused 1
# accept 1
# recvcomplete 1
# l4 1
# incompatible 1
# warn 1
# identical 1
# rpd1896 1
# got 1
# fec 1
# label 1
# lookup 1
# reverse 1
# sendcomplete 1
# release 1
# switchover 1
# errors. 1
# bouncing 1
# cmg 1
# sp71 1
# failedindex 1
# modify 1
# inactive. 1
# notconnected. 1
# failed. 1
# negotiation 1
# auto 1
# extend 1
# increase 1
# mmap 1
# cli 1
# simplex 1
# activated 1
# psp 1
# intervention 1
# manual 1
# valid 1
# pkt 1
# inbound 1
# ipsec 1
# missing 1
# skipped 1
# container 1
# esc 1
# high 1
# samples 1
# sm 1
# did 1
# pseudos 1
# 2 1
# corrected 1
# network 1
# overwrite 1
# peertype 1
# initoverriding 1
# asp 1
# tnp 1
# usr1 1
# sntpsync 1
# illegal 1
# sgls 1
# gbus 1
# became 1
# becoming 1
# perms 1
# rtcb 1
# rts 1
# ifarequest 1
# daemons 1
# kern.securelevel 1
# package 1
# success!!! 1
# cosman 1
# vectors 1
# cosfpc 1
# mt 1
# cospic 1
# 2nd 1
# 1st 1
# forbes1 1
# forbes0 1
# sg 1
# match 1
# ver 1
# succesfully 1
# aser 1
# nl9k 1
# bisttcam 1
# overwritten 1
# corruption 1
# ai 1
# appidd 1
# resending 1
# connecton 1
# processes 1
# image. 1
# acbc 1
# older 1
# clksyncd 1
# rhost 1
# control 1
# select 1
# ksyncd 1
# smartd 1
# platform 1
# sdk 1
# libjunos 1
# relayd 1
# success 1
# license 1
# completed 1
# idp 1
# pseudo 1
# pt 1
# length 1
# bind 1
# clk 1
# def 1
# mld6 1
# but 1
# successfully 1
# overflowed. 1
# db 1
# flushsession 1
# repo 1
# l2vpn 1
# receiving 1
# discriminator 1
# side 1
# remote 1
# disconnected; 1
# 20120010 1
# opadd 1
# pics 1
# bytes 1
# without 1
# ifstate 1
# flag 1
# services 1
# mpc3d16xgesfpp 1
# use 1
# unilistnh 1
# unlist 1
# 0...... 1
# nsr 1
# second 1
# idr 1
# idl 1
# delayed 1
# exist 1
# does 1
# seen 1
# have 1
# seconds 1
# xe 1
# synchronize 1
# ssh 1
# chassisfpc 1
# mspd 1
# processed 1
# modified 1
# being 1
# are 1
# profiles 1
# dynamicprofiles 1
# ffp 1
# promiscuous 1
# ixchip 1
# sysif 1
# logic 1
# reasonbackup 1
# gap 1
# sequence 1
# af 1
# idx 1
# peek 1
# ecc 1
# toggle 1
# clearing 1
# unexpected 1
# impellers 1
# medium 1
# md5 1
# rejecting 1
# execute. 1
# running 1
# * 1
# main 1
# jl2tpd 1
# moves 1
# move 1
# throttled 1
# sms 1
# finish 1
# daemon 1
# restarting 1
# tries 1
# reconnecting 1
# abruptly 1
# stop 1
# queued 1
# telnet 1
# unplugged 1
# died 1
# ttloop 1
# telnetd 1
# ## 1
# offset 1
# step 1
# ntpdate 1
# rcvd 1
# iffm 1
# such 1
# etccrontab 1
# reload 1
# *system* 1
# console 1
# cfgduplex 1
# autoneg 1
# acl 1
# egress 1
# vrf 1
# reestablished 1
# usrlibexecatrun 1
# member 1
# r 1
# rcp 1
# replicate 1
# 10.4r2.6 1
# sendmsg 1
# rawsock 1
# tx 1
# rebooted 1
# novalidate 1
# validate 1
# uplink 1
# tsunami 1
# errno 1
# advertise 1
# cmfpc 1
# scheduler 1
# sec 1
# slip 1
# sched 1
# cmtsunami 1
# cubs 1
# lion 1
# subtype 1
# inserted 1
# remove 1
# freeing 1
# debug 1
# mb 1
# eeprom 1
# syscall 1
# helper 1
# pmap 1
# accounting 1
# bdid 1
# snp 1
# l2 1
# associated 1
# iflogical 1
# rtbid 1
# maca5 1
# inet6 1
# java 1
# profilesession 1
# disassociate 1
# type. 1
# line 1
# authenticating 1
# byte 1
# target 1
# resetting 1
# workaround 1
# qt2025 1
# vs. 1
# differ 1
# versions 1
# jflow 1
# sampling 1
# forwardingoptions 1
# usrsbinsampled 1
# mup 1
# bulk 1
# level2 1
# level3 1
# unrepl 1
# reinject 1
# primary 1
# reinjectreinject 1
# error2 1
# kind 1
# wexit 1
# exec 1
# record 1
# initiating 1
# sampledc 1
# rpd1866 1
# sfpc 1
# ratelimitburst 1
# cmx 1
# mesg 1
# ichip 1
# chg 1
# v2.2 1
# ia 1
# opchange 1
# #cboentries; 1
# #kmbentries; 1
# #kmaentries; 1
# #gumementries; 1
# reason? 1
# disconnecting 1
# opdelete 1
# run# 1
# capacity. 1
# beyond 1
# unexpectedly 1
# netconf. 1
# another 1
# execution 1
# signaled 1
# prefix 1
# maxprefixes 1
# returned 1
# temperature 1
# 7 1
# level 1
# tolerance 1
# 20120014 1
# restarted. 1
# malformed 1
# synchronization 1
# lu0 1
# ae6.107 1
# ae6.202 1
# resumed 1
# 4.2.0a 1
# wrong 1
# reached 1
# nd6 1
# sorry 1
# down. 1
# mlockall 1
# rto 1
# bdllp 1
# fgets 1
# noblock 1
# port. 1
# subsystem 1
# ifachange 1
# unknown 1
# keepalive 1
# rdp 1
# lacpd 1
# loopbackclearing 1
# loopbackhost 1
# refused 1
# log. 1
# denied 1
# rxe 1
# allowed 1
# trunk 1
# switchport 1

# %% [markdown]
# - labeledは1割ぐらいでいい
# - raw logs は結局テンプレート化される
# - TF-IDFをログ単位で出すので，IDF値は #raw log に影響される． TFは1logのなかの単語頻度なので，LTごとに共通
#   - なので，ltidごとのログ発生数をカウントする

# %%
with open("cnt_per_id.json", "r") as f:
    cnt_per_id = json.load(f)

# %% [markdown]
# - TF =  words in LT x num of logs
# - DF = num of word per LT x num of logs

# %%
## TF-IDF

ltid_black_list = ['0', '10', '11','18','19','12', '8','20','21','23','24','1150', '1617']

df = dict()
for ltid, words in enumerate(corpus):
    if str(ltid) not in ltid_black_list:
        for word in set([w[0] for w in words]):
            if word not in df:
                df[word] = cnt_per_id[str(ltid)]
            else:
                df[word] += cnt_per_id[str(ltid)]
            
tfidfs = {}
for ltid, words in enumerate(corpus):
    if str(ltid) not in ltid_black_list:
        all_word_freq = len(words)
        tfidf_per_word = {}

        for word, cnt in collections.Counter([w[0] for w in words]).items():
            tf = cnt/all_word_freq
            tfidf = tf/np.log(sum([v for v in cnt_per_id.values()])/df[word])
            tfidf_per_word[word] = tfidf
        tfidfs[ltid] = tfidf_per_word

# %% [markdown]
# - ラベルを振る
# - paper 中のanomalyは以下の通り
#
# ```
# FAN RECOVERED
# OSPF NEIGHBOR CHANGED
# FAN FAILED
# BOARD DISABLE
# BGP NEIGHBOR CHANGED
# POWER DOWN
# SYSTEM REBOOT
# INTERFACE DOWN
# PORT DOWN
# PROTOCOL DOWN
# OSPF DOWN
# MODEL OUT
# ```
#
# - 35Mデータがあるので，1割ぐらいの3.5Mがlabeledになるようにやってみる
#     - ospf down 151 - 649
#     - ospf nb down 153 - 410
#     - bgp nb changed 181- 1429
#     - bgp tmp. unavailable 43 - 3609
#     - port down 453 - 162
#     - rsvp down 376 - 867
#
#     計: 7126

# %%
for k,v in raw_lt.items():
    print(k, v)
# Out:
# 0 {'cat': 'system(cron)', 'lt': '/usr/sbin/cron[**]: (root) CMD (newsyslog)'}
# 1 {'cat': 'network(lacp)', 'lt': 'mib2d[**]: lacp info not found for ifl:**'}
# 2 {'cat': 'network(lacp)', 'lt': 'mib2d[**]: cleared lacp info not found for ifl:**'}
# 3 {'cat': 'system(cron)', 'lt': '/usr/sbin/cron[**]: (**) CMD (adjkerntz -a)'}
# 4 {'cat': 'service(ntp)', 'lt': 'xntpd[**]: NTP Server Unreachable'}
# 5 {'cat': 'monitor(syslog)', 'lt': 'last message repeated ** times'}
# 6 {'cat': 'network(mtu)', 'lt': '/kernel: MTU for ** reduced to **'}
# 7 {'cat': 'mgmt(login)', 'lt': 'login: LOGIN_INFORMATION: User ** logged in from host ** on device **'}
# 8 {'cat': 'system(ui)', 'lt': "mgd[**]: UI_AUTH_EVENT: Authenticated user '**' at permission level '**'"}
# 9 {'cat': 'system(ui)', 'lt': "mgd[**]: UI_LOGIN_EVENT: User '**' login, class '**' [**], ssh-connection '', client-mode 'cli'"}
# 10 {'cat': 'system(ui)', 'lt': "mgd[**]: UI_CHILD_START: Starting child '**'"}
# 11 {'cat': 'system(ui)', 'lt': "mgd[**]: UI_CHILD_STATUS: Cleanup child '**', PID **, status **"}
# 12 {'cat': 'system(ui)', 'lt': "mgd[**]: UI_LOGOUT_EVENT: User '**' logout"}
# 13 {'cat': 'mgmt(command)', 'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '(unauthenticated user)' used JUNOScript client to run command 'request-authentication user=** logname=** host=** agent=mgd current-directory=/var/tmp pid=** ppid=**'"}
# 14 {'cat': 'system(ui)', 'lt': "mgd[**]: UI_LOGIN_EVENT: User '**' login, class '**' **[**], ssh-connection '', client-mode 'junoscript'"}
# 15 {'cat': 'mgmt(command)', 'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to ** command 'show system **'"}
# 16 {'cat': 'mgmt(command)', 'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to ** command '**'"}
# 17 {'cat': 'service(ntp)', 'lt': 'xntpd[**]: kernel time sync enabled **'}
# 18 {'cat': 'mgmt(login)', 'lt': '[**]: EVT ** ** ** ACCESS ** **:** Login ** from ** (**)**'}
# 19 {'cat': 'mgmt(login)', 'lt': '[**]: EVT ** ** ** ACCESS ** **:** Logout ** from ** (**).'}
# 20 {'cat': 'mgmt(ssh)', 'lt': 'sshd[**]: Accepted password for ** from ** port ** **'}
# 21 {'cat': 'system(ui)', 'lt': "mgd[**]: UI_LOGIN_EVENT: User '**' login, class '**' [**], ssh-connection '** ** ** **', client-mode 'cli'"}
# 22 {'cat': 'network(l2)', 'lt': 'jl2tpd: jl2tpd: main: *** jl2tpd not running in active mode***'}
# 23 {'cat': 'mgmt(ssh)', 'lt': 'sshd[**]: Received disconnect from **: **: disconnected by user'}
# 24 {'cat': 'system(unix)', 'lt': 'inetd[**]: **[**]: exited, status **'}
# 25 {'cat': 'mgmt(command)', 'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to run command 'get-software-information level=**'"}
# 26 {'cat': 'network(storm)', 'lt': '[**]: EVT ** ** ** PORT ** ** **:** NIF ** Port **:broadcast storm detected.'}
# 27 {'cat': 'network(storm)', 'lt': '[**]: EVT ** ** ** PORT ** ** **:** NIF ** Port **:broadcast storm recovered.'}
# 28 {'cat': 'network(mtu)', 'lt': 'rpd[**]: EVENT <MTU> ** index ** <Up Broadcast PointToPoint Multicast> address #** **'}
# 29 {'cat': 'system(pic)', 'lt': 'Slot **, PIC Slot **) idx ** af **'}
# 30 {'cat': 'system(pic)', 'lt': 'Slot **, PIC Slot **) ifl family **'}
# 31 {'cat': 'network(pfe)', 'lt': 'pfed: PFED: rtslib sequence gap ** - **'}
# 32 {'cat': 'network(pfe)', 'lt': 'pfed: PFED: rtsock init completed.'}
# 33 {'cat': 'network(pfe)', 'lt': 'pfed: PFED: rtsock recovery ** completed.'}
# 34 {'cat': 'system(ppe)', 'lt': '[**]: EVT ** ** ** SOFTWARE ** **:** Received many packets and loaded into the queue to CPU.'}
# 35 {'cat': 'system(ppe)', 'lt': '[**]: EVT ** ** ** SOFTWARE ** **:** Processed the packets in the queue to CPU.'}
# 36 {'cat': 'mgmt(pam)', 'lt': 'login: LOGIN_PAM_AUTHENTICATION_ERROR: PAM authentication error for user **'}
# 37 {'cat': 'mgmt(login)', 'lt': 'login: LOGIN_FAILED: Login failed for user ** from host **'}
# 38 {'cat': 'mgmt(login)', 'lt': "login: LOGIN_FAILED_LIMIT: Specified number of login failures (**) for user '**' reached from '**'"}
# 39 {'cat': 'network(pfe)', 'lt': 'pfed: rtslib: ERROR IDL IDR Decode Error **(Invalid Buffer Size)'}
# 40 {'cat': 'service(ntp)', 'lt': 'xntpd[**]: synchronized to **, stratum=**'}
# 41 {'cat': 'system(cron)', 'lt': '/usr/sbin/cron[**]: (**) CMD (/usr/sbin/check-support -l)'}
# 42 {'cat': 'mgmt(su)', 'lt': 'su: ** to ** on **'}
# 43 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_send: sending ** bytes to ** (** AS **) blocked (no spooling requested): Resource temporarily unavailable'}
# 44 {'cat': 'network(lacp)', 'lt': 'ifinfo: lacp info not found for ifl:**'}
# 45 {'cat': 'network(lacp)', 'lt': 'ifinfo: cleared lacp info not found for ifl:**'}
# 46 {'cat': 'mgmt(command)', 'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to run command 'get-virtual-chassis-adjacency-information verbosity_level=**'"}
# 47 {'cat': 'mgmt(command)', 'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to run command 'get-virtual-chassis-database-information verbosity_level=**'"}
# 48 {'cat': 'mgmt(command)', 'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to run command 'get-virtual-chassis-route-information verbosity_level=**'"}
# 49 {'cat': 'mgmt(command)', 'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to run command 'get-virtual-chassis-port-statistics verbosity_level=**'"}
# 50 {'cat': 'mgmt(ssh)', 'lt': "sshd: User '**' authenticated successfully but no local login-id configured."}
# 51 {'cat': 'mgmt(ssh)', 'lt': 'sshd[**]: Accepted password for ** from ** port **'}
# 52 {'cat': 'mgmt(ssh)', 'lt': 'sshd[**]: Connection closed by **'}
# 53 {'cat': 'network(mld)', 'lt': '/kernel: mld6_input: src ** is not link-local (grp=**)'}
# 54 {'cat': 'system(fpc)', 'lt': 'MQCHIP(**) LI Packet length error, pt entry **'}
# 55 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_hold_timeout:**: NOTIFICATION sent to ** (** AS **): code ** (Hold Timer Expired Error), Reason: holdtime expired for ** (** AS **), socket buffer sndcc: ** rcvcc: ** TCP state: **, snd_una: ** snd_nxt: ** snd_wnd: ** rcv_nxt: ** rcv_adv: **, hold timer **'}
# 56 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: RPD_BGP_NEIGHBOR_STATE_CHANGED: BGP peer ** (** AS **) changed state from ** to ** (event **)'}
# 57 {'cat': 'network(arp)', 'lt': '/kernel: KERN_ARP_ADDR_CHANGE: ** info overwritten for ** from ** to **'}
# 58 {'cat': 'mgmt(login)', 'lt': '[**]: EVT ** ** ** ACCESS ** **:** Login incorrect **'}
# 59 {'cat': 'mgmt(ssh)', 'lt': 'sshd[**]: Failed password for ** from ** port ** **'}
# 60 {'cat': 'interface(port)', 'lt': '[**]: EVT ** ** ** PORT ** ** **:** Port disabled administratively.'}
# 61 {'cat': 'system(ui)', 'lt': "mgd[**]: UI_DBASE_LOGIN_EVENT: User '**' entering configuration mode"}
# 62 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_COMMIT: User '**' requested 'commit' operation (comment: none)"}
# 63 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [interfaces ** unit **]"}
# 64 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' activate: [interfaces ** unit **]"}
# 65 {'cat': 'interface(agg)', 'lt': 'dcd[**]: ** : Warning: aggregated-ether-options link-speed no kernel value! default to **'}
# 66 {'cat': 'system(pic)', 'lt': 'spd[**]: **: This PIC will be reset on graceful switchover'}
# 67 {'cat': 'network(l2)', 'lt': 'l2cp[**]: Initializing PNAC state machines'}
# 68 {'cat': 'network(l2)', 'lt': 'l2cp[**]: Initializing PNAC state machines complete'}
# 69 {'cat': 'network(l2)', 'lt': 'l2cp[**]: Initialized 802.1X module and state machines'}
# 70 {'cat': 'network(l2)', 'lt': 'l2cp[**]: Read acess profile () config'}
# 71 {'cat': 'mgmt(config)', 'lt': 'rpd[**]: Synchronized commit processing phase ** **'}
# 72 {'cat': 'service(ntp)', 'lt': 'xntpd[**]: ntpd exiting on signal **'}
# 73 {'cat': 'service(ntp)', 'lt': 'xntpd[**]: ntpd ** ** ** ** ** ** ** (**)'}
# 74 {'cat': 'service(ntp)', 'lt': 'xntpd[**]: precision = ** usec'}
# 75 {'cat': 'service(ntp)', 'lt': 'xntpd[**]: Listening on interface **, **#**'}
# 76 {'cat': 'service(ntp)', 'lt': 'xntpd[**]: kernel time sync status **'}
# 77 {'cat': 'service(ntp)', 'lt': 'xntpd[**]: frequency initialized ** PPM from **'}
# 78 {'cat': 'mgmt(config)', 'lt': 'rpd[**]: RPD_TASK_REINIT: Reinitializing'}
# 79 {'cat': 'mgmt(config)', 'lt': 'rpd[**]: task_reconfigure reinitializing done'}
# 80 {'cat': 'mgmt(config)', 'lt': 'rpd[**]: Synchronized commit processing complete'}
# 81 {'cat': 'interface(agg)', 'lt': 'dcd[**]: ** : aggregated-ether-options link-speed set to kernel value of **'}
# 82 {'cat': 'interface(agg)', 'lt': '/kernel: ae_link_op: link ** (lidx=**) detached from bundle **'}
# 83 {'cat': 'interface(agg)', 'lt': '/kernel: ** leaves **'}
# 84 {'cat': 'interface(agg)', 'lt': '/kernel: bundle **: bundle IFL state changed to **'}
# 85 {'cat': 'monitor(snmp)', 'lt': 'mib2d[**]: SNMP_TRAP_LINK_DOWN: ifIndex **, ifAdminStatus **(**), ifOperStatus **(**), ifName **'}
# 86 {'cat': 'interface(agg)', 'lt': '**: rpd[**]: Received MC_AE_OPTIONS TLV for intf device **; mc_ae_id **, status **'}
# 87 {'cat': 'interface(agg)', 'lt': 'mcsn[**]: Received MC_AE_OPTIONS TLV for intf device **; mc_ae_id **, status **'}
# 88 {'cat': 'interface(agg)', 'lt': '/kernel: ae_link_op: link ** (lidx=**) attached to bundle **'}
# 89 {'cat': 'interface(agg)', 'lt': '/kernel: ** joins **'}
# 90 {'cat': 'monitor(snmp)', 'lt': 'mib2d[**]: SNMP_TRAP_LINK_UP: ifIndex **, ifAdminStatus **(**), ifOperStatus **(**), ifName **'}
# 91 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT Delete UpDown ** index ** ** -> ** <Broadcast Multicast Localup>'}
# 92 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT <Delete UpDown> ** index ** <Broadcast Multicast> address #** **'}
# 93 {'cat': 'interface(agg)', 'lt': 'rpd[**]: Received MC_AE_OPTIONS TLV for intf device **; mc_ae_id **, status **'}
# 94 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT <Add> ** index ** <Up Broadcast Multicast> address #** **'}
# 95 {'cat': 'network(mtu)', 'lt': 'rpd[**]: EVENT <MTU> ** index ** <Up Broadcast Multicast> address #** **'}
# 96 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT <Flags> ** index ** <Up Broadcast Multicast> address #** **'}
# 97 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT Add ** index ** ** -> ** <Up Broadcast Multicast Localup>'}
# 98 {'cat': 'network(l2)', 'lt': 'l2cp[**]: L2CPD_TASK_REINIT: Reinitialized'}
# 99 {'cat': 'mgmt(config)', 'lt': 'l2cp[**]: task_reconfigure reinitializing done'}
# 100 {'cat': 'mgmt(config)', 'lt': 'mcsn[**]: RPD_TASK_REINIT: Reinitializing'}
# 101 {'cat': 'mgmt(config)', 'lt': 'mcsn[**]: task_reconfigure reinitializing done'}
# 102 {'cat': 'service(ntp)', 'lt': 'xntpd[**]: kernel time sync disabled **'}
# 103 {'cat': 'system(ui)', 'lt': "mgd[**]: UI_DBASE_LOGOUT_EVENT: User '**' exiting configuration mode"}
# 104 {'cat': 'monitor(snmp)', 'lt': 'rpd[**]: EVENT <SNMP Index> ** index ** <Up Broadcast Multicast> address #** **'}
# 105 {'cat': 'interface(port)', 'lt': '[**]: EVT ** ** ** PORT ** ** **:** Port enabled administratively.'}
# 106 {'cat': 'system(ui)', 'lt': "mgd[**]: UI_CHILD_EXITED: Child exited: PID **, status **, command '**'"}
# 107 {'cat': 'interface(port)', 'lt': '[**]: EVT ** ** ** PORT ** ** **:** Port up.'}
# 108 {'cat': 'interface(port)', 'lt': '[**]: EVT ** ** ** PORT ** ** **:** Error detected on the port.'}
# 109 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [interfaces ** unit **]"}
# 110 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [class-of-service interfaces ** unit **]"}
# 111 {'cat': 'interface(vlan)', 'lt': '[**]: EVT ** ** ** VLAN ** **:** VLAN (**) Status is Down.'}
# 112 {'cat': 'mgmt(enable)', 'lt': '[**]: RSP ** ** **(**):enable: Sorry'}
# 113 {'cat': 'network(storm)', 'lt': '[**]: EVT ** ** ** PORT ** ** **:** NIF ** Port **:storm detected.'}
# 114 {'cat': 'network(storm)', 'lt': '[**]: EVT ** ** ** PORT ** ** **:** NIF ** Port **:storm recovered.'}
# 115 {'cat': 'interface(vlan)', 'lt': '[**]: RSP ** ** **(**):interface : Cannot change vlan configuration referred by flow configuration.[**]'}
# 116 {'cat': 'network(arp)', 'lt': 'l2ald[**]: L2ALD_MAC_LIMIT_REACHED_IFBD: Limit on learned MAC addresses reached for ** flags [0x **] state [0x **]; current count is **'}
# 117 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <Flags> ** index ** <Up Broadcast Multicast> address #** **'}
# 118 {'cat': 'network(arp)', 'lt': 'l2ald[**]: L2ALD_MAC_LIMIT_RESET_IF: Resumed adding MAC addresses learned by ** flags [0x **] state [0x **]; current count is **'}
# 119 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [interfaces ** unit **]"}
# 120 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [interfaces ** unit ** vlan-id] <unconfigured> -> "**"'}
# 121 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [interfaces ** unit ** family **]"}
# 122 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [interfaces ** unit ** family ** mtu] <unconfigured> -> "**"'}
# 123 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [interfaces ** unit ** family ** address **]"}
# 124 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [class-of-service interfaces ** unit ** classifiers **] <unconfigured> -> "**"'}
# 125 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [class-of-service interfaces ** unit ** rewrite-rules **] <unconfigured> -> "**"'}
# 126 {'cat': 'interface(vlan)', 'lt': '[**]: EVT ** ** ** VLAN ** **:** VLAN (**) Status is Up.'}
# 127 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_read_v4_message:**: NOTIFICATION received from ** (** AS **): code ** (Hold Timer Expired Error), socket buffer sndcc: ** rcvcc: ** TCP state: **, snd_una: ** snd_nxt: ** snd_wnd: ** rcv_nxt: ** rcv_adv: **, hold timer **'}
# 128 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_process_caps: mismatch NLRI with ** (** AS **): peer: <** **>(**) us: <**>(**)'}
# 129 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_read_message:**: NOTIFICATION sent to **+** (proto): code ** (Message Header Error) subcode ** (bad length) value **'}
# 130 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' delete: [protocols bgp group ** neighbor **] "**'}
# 131 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [protocols bgp group ** neighbor **] <**> -> "**"'}
# 132 {'cat': 'system(ppe)', 'lt': 'LU ** ** Errors lmem addr error'}
# 133 {'cat': 'system(ppe)', 'lt': 'PPE PPE HW Fault Trap: Count **, PC **, 0x0056: ipv4_input_set_proto_and_ports'}
# 134 {'cat': 'mgmt(ssh)', 'lt': 'sshd[**]: Disconnecting: Too many password failures for **'}
# 135 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_PATH_DOWN: MPLS path ** down on LSP **'}
# 136 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_DOWN: MPLS LSP ** down on primary(**)'}
# 137 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <UpDown> index ** <Broadcast Multicast> address #** **'}
# 138 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <UpDown> ** index ** <Broadcast Multicast> address #** **'}
# 139 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT UpDown ** index ** ** -> ** <Broadcast Multicast Localup>'}
# 140 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT UpDown ** index ** <Broadcast Multicast Localup>'}
# 141 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT <UpDown> ** index ** <Broadcast Multicast> address #** **'}
# 142 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT UpDown ** index ** ** -> ** <Broadcast Multicast Localup>'}
# 143 {'cat': 'interface(if_event)', 'lt': 'mcsn[**]: EVENT <UpDown> index ** <Broadcast Multicast> address #** **'}
# 144 {'cat': 'network(stp)', 'lt': '**: rpd[**]: STP handler: index=**, op=change, state=**, tc-generation=**'}
# 145 {'cat': 'network(stp)', 'lt': '**: rpd[**]: STP Chg'}
# 146 {'cat': 'network(stp)', 'lt': 'mcsn[**]: STP handler: index=**, op=**, state=**, tc-generation=**'}
# 147 {'cat': 'network(stp)', 'lt': 'mcsn[**]: STP **'}
# 148 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT <UpDown> index ** <Broadcast Multicast> address #** **'}
# 149 {'cat': 'network(stp)', 'lt': 'rpd[**]: STP handler: index=**, op=**, state=**, tc-generation=**'}
# 150 {'cat': 'network(stp)', 'lt': 'rpd[**]: STP **'}
# 151 {'cat': 'igp(ospf)', 'lt': '**:rpd[**]: RPD_OSPF_NBRDOWN: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to KillNbr (event reason: interface went down)'}
# 152 {'cat': 'network(rsvp)', 'lt': '**:rpd[**]: RPD_RSVP_NBRDOWN: RSVP neighbor ** down on interface **, triggered by IGP neighbor down event'}
# 153 {'cat': 'igp(ospf)', 'lt': 'rpd[**]: RPD_OSPF_NBRDOWN: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to KillNbr (event reason: interface went down)'}
# 154 {'cat': 'vpn(l2vc)', 'lt': '**:rpd[**]: RPD_LAYER2_VC_DOWN: State of Layer ** VC (VPN : **, local-site : **, remote-site : **) changed from ** to **'}
# 155 {'cat': 'vpn(vpls)', 'lt': '**: rpd[**]: vpls_dyn_disassociate_profile:session ID **'}
# 156 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT Delete UpDown ** index ** <Broadcast PointToPoint Multicast Localup>'}
# 157 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <Delete UpDown> ** index ** <Broadcast PointToPoint Multicast>'}
# 158 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <UpDown> ** index ** <Up Broadcast Multicast> address #** **'}
# 159 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT UpDown ** index ** ** -> ** <Up Broadcast Multicast>'}
# 160 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <UpDown> index ** <Up Broadcast Multicast> address #** **'}
# 161 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT UpDown ** index ** <Up Broadcast Multicast>'}
# 162 {'cat': 'interface(if_event)', 'lt': 'mcsn[**]: EVENT <UpDown> index ** <Up Broadcast Multicast> address #** **'}
# 163 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT <UpDown> ** index ** <Up Broadcast Multicast> address #** **'}
# 164 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT UpDown ** index ** ** -> ** <Up Broadcast Multicast>'}
# 165 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT <UpDown> index ** <Up Broadcast Multicast> address #** **'}
# 166 {'cat': 'igp(ospf)', 'lt': '**:rpd[**]: RPD_OSPF_NBRUP: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to 2WayRcvd (event reason: neighbor detected this router)'}
# 167 {'cat': 'igp(ospf)', 'lt': 'rpd[**]: RPD_OSPF_NBRUP: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to 2WayRcvd (event reason: neighbor detected this router)'}
# 168 {'cat': 'igp(ospf)', 'lt': '**:rpd[**]: RPD_OSPF_NBRUP: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to LoadDone (event reason: OSPF loading completed)'}
# 169 {'cat': 'igp(ospf)', 'lt': 'rpd[**]: RPD_OSPF_NBRUP: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to LoadDone (event reason: OSPF loading completed)'}
# 170 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <Add> ** index ** <Up Broadcast PointToPoint Multicast>'}
# 171 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <Instance> ** index ** <Up Broadcast PointToPoint Multicast>'}
# 172 {'cat': 'network(mtu)', 'lt': '**: rpd[**]: EVENT <MTU> ** index ** <Up Broadcast PointToPoint Multicast>'}
# 173 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <Flags> ** index ** <Up Broadcast PointToPoint Multicast>'}
# 174 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT Add ** index ** <Up Broadcast PointToPoint Multicast Localup>'}
# 175 {'cat': 'monitor(snmp)', 'lt': '**: rpd[**]: EVENT <SNMP Index> ** index ** <Up Broadcast PointToPoint Multicast>'}
# 176 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_PATH_UP: MPLS path ** up on LSP ** path bandwidth ** bps'}
# 177 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 178 {'cat': 'vpn(l2vc)', 'lt': '**:rpd[**]: RPD_LAYER2_VC_UP: State of Layer ** VC (VPN : **, local-site : **, remote-site : **) changed to UP'}
# 179 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 180 {'cat': 'egp(bgp)', 'lt': '**: rpd[**]: bgp_hold_timeout:**: NOTIFICATION sent to ** (** AS **): code ** (Hold Timer Expired Error), Reason: holdtime expired for ** (** AS **), socket buffer sndcc: ** rcvcc: ** TCP state: **, snd_una: ** snd_nxt: ** snd_wnd: ** rcv_nxt: ** rcv_adv: **, hold timer **'}
# 181 {'cat': 'egp(bgp)', 'lt': '**:rpd[**]: RPD_BGP_NEIGHBOR_STATE_CHANGED: BGP peer ** (** AS **) changed state from ** to ** (event **)'}
# 182 {'cat': 'monitor(snmp)', 'lt': 'snmpd[**]: SNMPD_TRAP_QUEUED: Adding trap to ** to ** queue, ** traps in queue'}
# 183 {'cat': 'egp(bgp)', 'lt': '**: rpd[**]: bgp_read_v4_message:**: NOTIFICATION received from ** (** AS **): code ** (Hold Timer Expired Error), socket buffer sndcc: ** rcvcc: ** TCP state: **, snd_una: ** snd_nxt: ** snd_wnd: ** rcv_nxt: ** rcv_adv: **, hold timer **'}
# 184 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 185 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 186 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 187 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 188 {'cat': 'network(rsvp)', 'lt': '**:rpd[**]: RPD_RSVP_NBRUP: RSVP neighbor ** up on interface **'}
# 189 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 190 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 191 {'cat': 'monitor(snmp)', 'lt': 'snmpd[**]: SNMPD_TRAP_QUEUE_DRAINED: trap_dq_send_traps: traps queued to ** sent successfully'}
# 192 {'cat': 'monitor(snmp)', 'lt': 'BULKGET: Master socket closed'}
# 193 {'cat': 'monitor(snmp)', 'lt': 'bulkget_stop_pfeman_transaction'}
# 194 {'cat': 'monitor(snmp)', 'lt': 'BULKGET disconnected: BULKGET socket closed abruptly'}
# 195 {'cat': 'system(unix)', 'lt': 'init: ** (PID **) exited with status=** Normal Exit'}
# 196 {'cat': 'system(unix)', 'lt': 'init: ** (PID **) started'}
# 197 {'cat': 'network(pfe)', 'lt': 'pfed: LIBJSNMP_SA_IPC_REG_ROWS: ns_subagent_register_mibs: registering ** rows'}
# 198 {'cat': 'network(pfe)', 'lt': 'pfed: LIBJSNMP_NS_LOG_INFO: INFO: ns_subagent_open_session: NET-SNMP version ** AgentX subagent connected'}
# 199 {'cat': 'monitor(snmp)', 'lt': 'BULKGET: re-connecting to serverRouter'}
# 200 {'cat': 'monitor(snmp)', 'lt': 'Bulkget manager reconnection succeeded after ** tries'}
# 201 {'cat': 'monitor(snmp)', 'lt': 'BULKGET master RE reconnection made'}
# 202 {'cat': 'monitor(snmp)', 'lt': 'bulkget_start_pfeman_transaction'}
# 203 {'cat': 'monitor(snmp)', 'lt': 'mib2d[**]: MIB2D_RTSLIB_READ_FAILURE: check_rtsock_rc: failed in reading ifls: ** (Invalid argument)'}
# 204 {'cat': 'system(ui)', 'lt': "mgd[**]: UI_RESTART_EVENT: User '**' restarting daemon 'Management Information Base II process'"}
# 205 {'cat': 'system(unix)', 'lt': 'init: ** (PID **) terminated by signal number **'}
# 206 {'cat': 'monitor(snmp)', 'lt': 'mib2d[**]: LIBJSNMP_SA_IPC_REG_ROWS: ns_subagent_register_mibs: registering ** rows'}
# 207 {'cat': 'monitor(snmp)', 'lt': 'mib2d[**]: LIBJSNMP_NS_LOG_INFO: INFO: ns_subagent_open_session: NET-SNMP version ** AgentX subagent connected'}
# 208 {'cat': 'monitor(snmp)', 'lt': 'mib2d[**]: LIBJSNMP_SA_PARTIAL_SEND_FRAG: Attempted to send ** bytes, actually sent ** bytes'}
# 209 {'cat': 'monitor(snmp)', 'lt': 'mib2d[**]: LIBJSNMP_SA_PARTIAL_SEND_REM: Queuing message remainder, ** bytes'}
# 210 {'cat': 'monitor(snmp)', 'lt': 'mib2d[**]: LIBJSNMP_SA_PARTIAL_FINISH: sms_send_finished: Received socket error: Invalid argument'}
# 211 {'cat': 'monitor(snmp)', 'lt': 'snmpd[**]: SNMPD_TRAP_THROTTLED: trap_queue_send_trap_throttled: traps throttled after ** traps'}
# 212 {'cat': 'monitor(snmp)', 'lt': 'snmpd[**]: SNMPD_THROTTLE_QUEUE_DRAINED: trap_throttle_timer_handler: cleared all throttled traps'}
# 213 {'cat': 'network(arp)', 'lt': 'l2ald[**]: L2ALD_MAC_MOVE_NOTIFICATION: MAC Moves detected in the system'}
# 214 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [routing-options rib ** static route ** next-hop **]"}
# 215 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [policy-options prefix-list ** **]"}
# 216 {'cat': 'mgmt(login)', 'lt': 'login: ** LOGIN ** FROM **'}
# 217 {'cat': 'mgmt(login)', 'lt': 'login: LOGIN_TIMED_OUT: Login attempt timed out after ** seconds'}
# 218 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [protocols bgp group ** neighbor **]"}
# 219 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [protocols bgp group ** neighbor ** description] <unconfigured> -> "**"'}
# 220 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [protocols bgp group ** neighbor ** **]"}
# 221 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [protocols bgp group ** neighbor ** export **]"}
# 222 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [protocols bgp group ** neighbor ** peer-as] <unconfigured> -> "**"'}
# 223 {'cat': 'mgmt(login)', 'lt': '[**]: EVT ** ** ** ACCESS ** **:** Login incorrect **#**'}
# 224 {'cat': 'system(ui)', 'lt': "[**]: RSP ** ** **(**):Can't execute."}
# 225 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_pp_recv: rejecting connection from ** (** AS **), peer in state **'}
# 226 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_pp_recv:**: NOTIFICATION sent to **+** (proto): code ** (Cease) subcode ** (Connection Rejected)'}
# 227 {'cat': 'network(tcp)', 'lt': '/kernel: tcp_auth_ok: Packet from **:** ** MD5 digest'}
# 228 {'cat': 'system(fan)', 'lt': 'chassisd[**]: CHASSISD_BLOWERS_SPEED_MEDIUM: Fans and impellers being set to intermediate speed'}
# 229 {'cat': 'system(fan)', 'lt': 'chassisd[**]: CHASSISD_BLOWERS_SPEED: Fans and impellers are now running at normal speed'}
# 230 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_read_v4_message:**: NOTIFICATION received from ** (** AS **): code ** (Cease) subcode ** (** **)'}
# 231 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' delete: [protocols bgp group ** neighbor ** export] ""**"'}
# 232 {'cat': 'mgmt(login)', 'lt': 'login: ** LOGIN ** FROM **, **'}
# 233 {'cat': 'mgmt(login)', 'lt': 'login: LOGIN_ABORTED: Client aborted login'}
# 234 {'cat': 'mgmt(ftp)', 'lt': 'ftpd[**]: connection from ** (**)'}
# 235 {'cat': 'mgmt(ftp)', 'lt': 'ftpd[**]: FTP LOGIN FROM ** as **'}
# 236 {'cat': 'mgmt(ftp)', 'lt': 'ftpd[**]: FTP LOGIN FAILED FROM **'}
# 237 {'cat': 'mgmt(ftp)', 'lt': 'ftpd[**]: FTP LOGIN FAILED FROM **, **'}
# 238 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' delete: [interfaces **] "**'}
# 239 {'cat': 'network(sfp)', 'lt': 'MIC(**) link ** SFP laser bias current low ** **'}
# 240 {'cat': 'network(sfp)', 'lt': 'MIC(**) link ** SFP output power low ** **'}
# 241 {'cat': 'network(sfp)', 'lt': 'MIC(**) link ** SFP receive power low ** **'}
# 242 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [interfaces **] <unconfigured> -> "**"'}
# 243 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_read_v4_message:**: NOTIFICATION received from ** (** AS **): code ** (Cease) subcode ** (Other Configuration Change)'}
# 244 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_read_v4_message:**: NOTIFICATION received from ** (** AS **): code ** (Cease) subcode ** (invalid)'}
# 245 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_recv: read from peer ** (** AS **) failed: Connection reset by peer'}
# 246 {'cat': 'system(power)', 'lt': '[**]: ERR ** ** ** PS ** **:** **, ** is power off.'}
# 247 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_recv: peer ** (** AS **): received unexpected EOF'}
# 248 {'cat': 'system(power)', 'lt': '[**]: EVT ** ** R8 PS ** **:** **, **, **, ** is normal.'}
# 249 {'cat': 'interface(agg)', 'lt': '[**]: EVT ** ** ** MAC ** **:** Port(**) ** to Channel Group(**).'}
# 250 {'cat': 'interface(agg)', 'lt': '[**]: EVT ** ** ** MAC ** **:** Channel Group(**) is Up.'}
# 251 {'cat': 'mgmt(su)', 'lt': 'su: BAD SU ** to ** on **'}
# 252 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [logical-systems ** interfaces ** unit **]"}
# 253 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [logical-systems ** routing-instances **]"}
# 254 {'cat': 'system(system_conf)', 'lt': 'chassisd[**]: CHASSISD_PARSE_COMPLETE: Using new configuration'}
# 255 {'cat': 'mgmt(config)', 'lt': '**:rpd[**]: RPD_TASK_REINIT: Reinitializing'}
# 256 {'cat': 'mgmt(config)', 'lt': '**: rpd[**]: task_reconfigure reinitializing done'}
# 257 {'cat': 'network(l2)', 'lt': '**: rpd[**]: **: received table message with address family ** op **'}
# 258 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [chassis redundancy **]"}
# 259 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' deactivate: [routing-options] "**'}
# 260 {'cat': 'network(socket)', 'lt': '/kernel: peer_inputs: soreceive() error **'}
# 261 {'cat': 'network(pfe)', 'lt': '/kernel: pfe_listener_disconnect: conn dropped: listener idx=**, tnpaddr=**, reason: none'}
# 262 {'cat': 'network(socket)', 'lt': '/kernel: clearing slave peer'}
# 263 {'cat': 'system(tnp)', 'lt': '/kernel: TNPv3: deleting active neighbor entry ** from **'}
# 264 {'cat': 'monitor(snmp)', 'lt': 'chassisd[**]: CHASSISD_SNMP_TRAP10: SNMP trap generated: Fru Offline (jnxFruContentsIndex **, jnxFruL1Index **, jnxFruL2Index **, jnxFruL3Index **, jnxFruName Routing Engine **, jnxFruType **, jnxFruSlot **, jnxFruOfflineReason **, jnxFruLastPowerOff **, jnxFruLastPowerOn **)'}
# 265 {'cat': 'system(alarm)', 'lt': 'alarmd[**]: Alarm set: RE color=**, class=**, reason=Loss of communication with Backup RE'}
# 266 {'cat': 'system(alarm)', 'lt': 'craftd[**]: Minor alarm set, Loss of communication with Backup RE'}
# 267 {'cat': 'system(gres)', 'lt': 'chassisd[**]: No response from the other routing engine for the last ** seconds.'}
# 268 {'cat': 'system(tnp)', 'lt': '/kernel: TNPv3: adding neighbor ** to interface **'}
# 269 {'cat': 'monitor(snmp)', 'lt': 'chassisd[**]: CHASSISD_SNMP_TRAP7: SNMP trap generated: Fru Online (jnxFruContentsIndex **, jnxFruL1Index **, jnxFruL2Index **, jnxFruL3Index **, jnxFruName Routing Engine **, jnxFruType **, jnxFruSlot **)'}
# 270 {'cat': 'system(alarm)', 'lt': 'alarmd[**]: Alarm cleared: RE color=**, class=**, reason=Loss of communication with Backup RE'}
# 271 {'cat': 'system(alarm)', 'lt': 'craftd[**]: Minor alarm cleared, Loss of communication with Backup RE'}
# 272 {'cat': 'system(ui)', 'lt': "mgd[**]: UI_MASTERSHIP_EVENT: Toggle routing engine mastership by '**'"}
# 273 {'cat': 'network(pim)', 'lt': 'rpd[**]: RPD_PIM_NBRUP: Instance PIM.master: PIM new neighbor ** interface **'}
# 274 {'cat': 'egp(msdp)', 'lt': 'rpd[**]: RPD_MSDP_PEER_UP: MSDP peer ** peer-group ** into ** state'}
# 275 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_pp_recv:**: NOTIFICATION sent to ** (** AS **): code ** (Cease) subcode ** (Connection collision resolution), Reason: dropping ** (** AS **), connection collision prefers **+** (proto)'}
# 276 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_pp_recv: dropping ** (** AS **), connection collision prefers **+** (proto)'}
# 277 {'cat': 'network(pfe)', 'lt': 'PFE[**] Fabric Probe Thread Started, interval = ** ms'}
# 278 {'cat': 'network(pfe)', 'lt': 'PFE[**]Aliveness Turning Destination ** on'}
# 279 {'cat': 'interface(interface)', 'lt': '** plugged in'}
# 280 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_recv: peer **+** (proto): received unexpected EOF'}
# 281 {'cat': 'system(alarm)', 'lt': 'alarmd[**]: Alarm cleared: RE color=**, class=**, reason=Host ** ECC ** parity error'}
# 282 {'cat': 'system(alarm)', 'lt': 'craftd[**]: Major alarm cleared, Host ** ECC ** parity error'}
# 283 {'cat': 'mgmt(command)', 'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to run command 'get-software-information'"}
# 284 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' activate: [chassis redundancy **]"}
# 285 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' activate: [routing-options] "**'}
# 286 {'cat': 'system(others)', 'lt': 'rpd[**]: Read ddl top handle ** for logical-router **'}
# 287 {'cat': 'system(config_apply)', 'lt': 'rpd[**]: task state: <ReConfig Foreground ParseConfig>'}
# 288 {'cat': 'system(pic)', 'lt': '/kernel: pic_listener_connect: conn established: mgmt addr=**,'}
# 289 {'cat': 'network(pfe)', 'lt': '/kernel: if_pfe_peek_peer_info: peer_type **, peer_index **'}
# 290 {'cat': 'system(gres)', 'lt': '/kernel: Peer ** (type ** index **) is not ready for GRES (reinserted)'}
# 291 {'cat': 'system(gres)', 'lt': '/kernel: Slave is not ready for GRES'}
# 292 {'cat': 'system(gres)', 'lt': '/kernel: Peer ** (type ** index **) is ready for GRES'}
# 293 {'cat': 'system(gres)', 'lt': '/kernel: Slave is ready for GRES'}
# 294 {'cat': 'service(ntp)', 'lt': 'xntpd[**]: time reset +** s'}
# 295 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** interfaces ** unit **]"}
# 296 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [logical-systems ** interfaces ** unit ** vlan-id] <unconfigured> -> "**"'}
# 297 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** interfaces ** unit ** family **]"}
# 298 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [logical-systems ** interfaces ** unit ** family ** mtu] <unconfigured> -> "**"'}
# 299 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** interfaces ** unit ** family ** address **]"}
# 300 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** routing-instances ** interface **]"}
# 301 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <Add> ** index ** <Broadcast Multicast> address #** **'}
# 302 {'cat': 'monitor(snmp)', 'lt': '**: rpd[**]: EVENT <SNMP Index> ** index ** <Broadcast Multicast> address #** **'}
# 303 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <Instance> ** index ** <Broadcast Multicast> address #** **'}
# 304 {'cat': 'network(mtu)', 'lt': '**: rpd[**]: EVENT <MTU> ** index ** <Broadcast Multicast> address #** **'}
# 305 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <Flags> ** index ** <Broadcast Multicast> address #** **'}
# 306 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT Add ** index ** ** -> ** <Broadcast Multicast>'}
# 307 {'cat': 'system(fpc)', 'lt': 'MQ(**): pio_handle(**); pio_read_u64() failed: **(generic failure)! addr=**'}
# 308 {'cat': 'system(fpc)', 'lt': 'trinity_pio: ** PIO errors occurred'}
# 309 {'cat': 'system(fpc)', 'lt': 'trinity_pio: Last error: ** MQ-0 Trinity PCI ** Write I2C ** ** **'}
# 310 {'cat': 'mgmt(command)', 'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to run command 'get-checksum-information path=**'"}
# 311 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [protocols pim **]"}
# 312 {'cat': 'system(alarm)', 'lt': 'alarmd[**]: Alarm cleared: RE color=**, class=**, reason=Backup RE Active'}
# 313 {'cat': 'system(alarm)', 'lt': 'craftd[**]: Minor alarm cleared, Backup RE Active'}
# 314 {'cat': 'network(pim)', 'lt': 'rpd[**]: RPD_PIM_NBRDOWN: Instance PIM.master: PIM neighbor ** (**) removed due to: the interface is purged'}
# 315 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT Flags ** index ** ** -> (**) <Broadcast Multicast>'}
# 316 {'cat': 'egp(bgp)', 'lt': '**: rpd[**]: task_connect: task **+** addr **+**: No route to host'}
# 317 {'cat': 'egp(bgp)', 'lt': '**: rpd[**]: bgp_connect_start: connect ** (** AS **): No route to host'}
# 318 {'cat': 'igp(ospf)', 'lt': '**:rpd[**]: RPD_OSPF_NBRUP: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to ExchangeDone (event reason: DBD exchange of slave completed)'}
# 319 {'cat': 'igp(ospf)', 'lt': 'rpd[**]: RPD_OSPF_NBRUP: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to ExchangeDone (event reason: DBD exchange of ** completed)'}
# 320 {'cat': 'mgmt(config_process)', 'lt': "eventd[**]: EVENTD_POLICY_LIMIT_EXCEEDED: Unable to execute policy '**' because current number of policies (**) exceeds system limit (**)"}
# 321 {'cat': 'igp(ospf)', 'lt': '**:rpd[**]: RPD_OSPF_NBRUP: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to ExchangeDone (event reason: ** exchange of ** completed)'}
# 322 {'cat': 'system(pic)', 'lt': 'CMT: Bypass ASIC attach to logic PIC (**:**)'}
# 323 {'cat': 'system(fpc)', 'lt': 'ix_chip_pre_init: SYSIF PLL lock OK!'}
# 324 {'cat': 'system(others)', 'lt': 'bringup_pcie_common: PCIe status **'}
# 325 {'cat': 'system(others)', 'lt': 'bringup_pcie_common: PCIe link training took **'}
# 326 {'cat': 'system(fpc)', 'lt': 'IXCHIP(**): jtag id ** major rev ** minor rev **'}
# 327 {'cat': 'system(fpc)', 'lt': 'Initializing IX[**] JSPEC'}
# 328 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: ** (** AS **): reseting pending active connection'}
# 329 {'cat': 'egp(bgp)', 'lt': '**: rpd[**]: ** (** AS **): reseting pending active connection'}
# 330 {'cat': 'network(routing)', 'lt': 'rpd[**]: RPD_KRT_Q_RETRIES: Route Update: No buffer space available'}
# 331 {'cat': 'monitor(snmp)', 'lt': 'snmpd[**]: LIBJSNMP_SA_PARTIAL_SEND_FRAG: Attempted to send ** bytes, actually sent ** bytes'}
# 332 {'cat': 'monitor(snmp)', 'lt': 'snmpd[**]: LIBJSNMP_SA_PARTIAL_SEND_REM: Queuing message remainder, ** bytes'}
# 333 {'cat': 'mgmt(ui_error)', 'lt': "mgd[**]: UI_READ_TIMEOUT: Timeout on read of peer 'snmp'"}
# 334 {'cat': 'mgmt(ui_error)', 'lt': "mgd[**]: UI_RECONN_READ_FAILED: Invalid response from peer 'snmp': ** Connection unexpectedly terminated"}
# 335 {'cat': 'interface(interface)', 'lt': '/kernel: **: promiscuous mode **'}
# 336 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [protocols bgp group ** neighbor **]"}
# 337 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' deactivate: [protocols bgp group ** neighbor **] "**'}
# 338 {'cat': 'system(ui)', 'lt': "mgd[**]: UI_LOAD_EVENT: User '**' is performing a 'rollback **'"}
# 339 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' rollback: **"}
# 340 {'cat': 'system(ui)', 'lt': 'mgd[**]: UI_LOAD_JUNOS_DEFAULT_FILE_EVENT: Loading the ** config from **'}
# 341 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [system root-authentication **]"}
# 342 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [system login user ** authentication **]"}
# 343 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [logical-systems ** protocols bgp group ** **]"}
# 344 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [logical-systems ** protocols ** area ** interface ** authentication md5 ** key]"}
# 345 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [protocols bgp group ** **]"}
# 346 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [protocols ospf area ** interface ** authentication md5 ** key]"}
# 347 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [security ipsec security-association OSPF3IPSEC manual direction bidirectional authentication key **]"}
# 348 {'cat': 'mgmt(config)', 'lt': 'mcsn[**]: MCSN_TASK_REINIT: Reinitializing'}
# 349 {'cat': 'system(None)', 'lt': 'ffp[**]: "dynamic-profiles": Profiles are being modified'}
# 350 {'cat': 'system(fpc)', 'lt': 'mspd[**]: Chassis/fpc configuration is empty'}
# 351 {'cat': 'system(unix)', 'lt': 'inetd[**]: Number of ssh connections at max limit (**)'}
# 352 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [policy-options prefix-list **]"}
# 353 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [policy-options prefix-list **]"}
# 354 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [policy-options prefix-list ** apply-path] <unconfigured> -> "protocols bgp group <*> neighbor <*:*>"'}
# 355 {'cat': 'system(ui)', 'lt': "mgd[**]: UI_LOAD_EVENT: User '**' is performing a 'rollback'"}
# 356 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' activate: [protocols bgp group ** neighbor **] "**'}
# 357 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_COMMIT: User '**' requested 'commit synchronize' operation (comment: none)"}
# 358 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' activate: [protocols pim **]"}
# 359 {'cat': 'mgmt(ui_error)', 'lt': 'rpd[**]: UI_CONFIGURATION_ERROR: Process: rpd, path: <none>, statement: <none>, Policy error: Policy ** referenced but not defined'}
# 360 {'cat': 'system(None)', 'lt': '/kernel: : port status changed'}
# 361 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <Bandwidth> index ** <Up Broadcast Multicast> address #** **'}
# 362 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <Bandwidth> ** index ** <Up Broadcast Multicast> address #** **'}
# 363 {'cat': 'interface(if_event)', 'lt': 'mcsn[**]: EVENT <Bandwidth> index ** <Up Broadcast Multicast> address #** **'}
# 364 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT <Bandwidth> index ** <Up Broadcast Multicast> address #** **'}
# 365 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT <Bandwidth> ** index ** <Up Broadcast Multicast> address #** **'}
# 366 {'cat': 'interface(agg)', 'lt': '/kernel: ae_bundlestate_ifd_change: bundle **: bundle IFD minimum links not met ** < **'}
# 367 {'cat': 'interface(agg)', 'lt': '/kernel: ae_bundlestate_ifd_change: bundle **: bundle IFD state changed to **'}
# 368 {'cat': 'system(cos)', 'lt': '/kernel: GENCFG: op ** (CoS) failed; err ** (Invalid)'}
# 369 {'cat': 'interface(if_event)', 'lt': 'mcsn[**]: EVENT <Bandwidth UpDown> index ** <Broadcast Multicast> address #** **'}
# 370 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <Bandwidth **> index ** <Broadcast Multicast> address #** **'}
# 371 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT <Bandwidth UpDown> index ** <Broadcast Multicast> address #** **'}
# 372 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT <Bandwidth> ** index ** <Broadcast Multicast> address #** **'}
# 373 {'cat': 'network(rsvp)', 'lt': '**:rpd[**]: RPD_RSVP_BACKUP_DOWN: Backup for protecting LSP ** down, using bypass Bypass->**, reason: Deleting protected LSP'}
# 374 {'cat': 'system(fpc)', 'lt': 'MQchip ** XE ** Throttle: Last ** seconds have seen interrupt throttling at least once per second'}
# 375 {'cat': 'igp(ospf)', 'lt': '**:rpd[**]: RPD_OSPF_NBRDOWN: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to InActiveTimer (event reason: neighbor was inactive and declared dead)'}
# 376 {'cat': 'network(rsvp)', 'lt': '**:rpd[**]: RPD_RSVP_BYPASS_DOWN: RSVP bypass Bypass->**>** for protecting interface ** went down, reason: RSVP session down'}
# 377 {'cat': 'network(rsvp)', 'lt': '**:rpd[**]: RPD_RSVP_BYPASS_DOWN: RSVP bypass Bypass->** for protecting interface ** went down, reason: RSVP session down'}
# 378 {'cat': 'network(rsvp)', 'lt': '**:rpd[**]: RPD_RSVP_BACKUP_DOWN: Backup for protecting LSP ** down, using bypass Bypass->**, reason: RSVP session down'}
# 379 {'cat': 'igp(ospf)', 'lt': 'rpd[**]: RPD_OSPF_NBRDOWN: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to InActiveTimer (event reason: neighbor was inactive and declared dead)'}
# 380 {'cat': 'system(None)', 'lt': 'NH id: **, child_nh ** does not exist'}
# 381 {'cat': 'network(pim)', 'lt': 'rpd[**]: RPD_PIM_NBRDOWN: Instance PIM.master: PIM neighbor ** (**) removed due to: the interface did not receive a hello message from the neighbor within the hold-time period (timeout)'}
# 382 {'cat': 'network(routing)', 'lt': '**:rpd[**]: RPD_KRT_Q_RETRIES: Route Update: No buffer space available'}
# 383 {'cat': 'interface(if_event)', 'lt': '**: rpd[**]: EVENT <Bandwidth UpDown> ** index ** <Up Broadcast Multicast> address #** **'}
# 384 {'cat': 'interface(if_event)', 'lt': 'mcsn[**]: EVENT <Bandwidth UpDown> index ** <Up Broadcast Multicast> address #** **'}
# 385 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT <Bandwidth UpDown> ** index ** <Up Broadcast Multicast> address #** **'}
# 386 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT Flags ** index ** ** -> (**) <Up Broadcast Multicast Localup>'}
# 387 {'cat': 'network(rsvp)', 'lt': '**:rpd[**]: RPD_RSVP_BYPASS_UP: RSVP bypass Bypass->** for protecting interface ** came up'}
# 388 {'cat': 'network(pfe)', 'lt': '/kernel: rt_pfe_veto: Too many delayed route/nexthop unrefs. Op **, rtsm_id **, msg type **'}
# 389 {'cat': 'network(pfe)', 'lt': '/kernel: rt_pfe_veto: Possible slowest client is ** States processed - ** States to be processed - **'}
# 390 {'cat': 'network(pfe)', 'lt': '/kernel: rt_pfe_veto: Possible second slowest client is ** States processed - ** States to be processed - **'}
# 391 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT <UpDown> ** index ** <Broadcast PointToPoint Multicast> address #** **'}
# 392 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT UpDown ** index ** <Broadcast PointToPoint Multicast Localup>'}
# 393 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT <UpDown> ** index ** <Up Broadcast PointToPoint Multicast> address #** **'}
# 394 {'cat': 'interface(if_event)', 'lt': 'rpd[**]: EVENT UpDown ** index ** <Up Broadcast PointToPoint Multicast>'}
# 395 {'cat': 'system(None)', 'lt': 'rpd[**]: task_process_events: no write/connect method for **+** socket **'}
# 396 {'cat': 'network(routing)', 'lt': 'rpd[**]: RPD_KRT_Q_RETRIES: Indirect Next Hop Update: No buffer space available'}
# 397 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 398 {'cat': 'vpn(vpls)', 'lt': '**: rpd[**]: [vpls_intf_create] nsr enabled: 0......'}
# 399 {'cat': 'system(pic)', 'lt': 'Slot **, PIC Slot **) Received COS message with major: ** minor: **'}
# 400 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on secondary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 401 {'cat': 'network(rsvp)', 'lt': '**:rpd[**]: RPD_RSVP_BYPASS_UP: RSVP bypass Bypass->**>** for protecting interface ** came up'}
# 402 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on secondary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 403 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on secondary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 404 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on secondary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 405 {'cat': 'network(pfe)', 'lt': 'CMT: PFE ASIC initialization complete'}
# ...
# 1684 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [interfaces ** unit ** family ** filter **]"}
# 1685 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' activate: [interfaces ** unit ** family ** filter **]"}
# 1686 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [firewall family ** filter ** term ** then routing-instance] "** -> "**"'}
# 1687 {'cat': 'mgmt(login)', 'lt': 'login[**]: ** LOGIN FAILURE FROM **'}
# 1688 {'cat': 'mgmt(login)', 'lt': 'login[**]: ** LOGIN FAILURE FROM **, **'}
# 1689 {'cat': 'mgmt(login)', 'lt': 'login[**]: LOGIN_ABORTED: Client aborted login'}
# 1690 {'cat': 'system(None)', 'lt': 'telnetd[**]: ttloop: peer died: Resource temporarily unavailable'}
# 1691 {'cat': 'igp(ospf)', 'lt': 'rpd[**]: RPD_OSPF_NBRDOWN: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to 1WayRcvd (event reason: neighbor is in one-way mode)'}
# 1692 {'cat': 'igp(ospf)', 'lt': '**:rpd[**]: RPD_OSPF_NBRDOWN: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to 1WayRcvd (event reason: neighbor is in one-way mode)'}
# 1693 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [routing-options rib-groups ** import-rib **]"}
# 1694 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' delete: [routing-options rib-groups ** import-rib] "**'}
# 1695 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [policy-options as-path-group ** as-path **]"}
# 1696 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [firewall family ** filter ** term **]"}
# 1697 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [policy-options as-path **]"}
# 1698 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [policy-options community **]"}
# 1699 {'cat': 'system(power)', 'lt': '[**]: ERR ** ** ** PS ** **:** ** is power off. **, ** is notconnect.'}
# 1700 {'cat': 'system(power)', 'lt': '[**]: ERR ** ** ** PS ** **:** **, **, ** is notconnect.'}
# 1701 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [firewall family ** filter ** term ** then count] <unconfigured> -> "**"'}
# 1702 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [firewall family ** filter ** term ** then **]"}
# 1703 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [logical-systems ** protocols mpls label-switched-path ** from] <**> -> "**"'}
# 1704 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [logical-systems ** protocols mpls label-switched-path ** to] <**> -> "**"'}
# 1705 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [logical-systems ** protocols mpls label-switched-path **] <unconfigured> -> "**"'}
# 1706 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** protocols mpls path ** **]"}
# 1707 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** protocols mpls ** ** primary **]"}
# 1708 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** protocols mpls path **]"}
# 1709 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [logical-systems ** protocols mpls path ** **] <unconfigured> -> "**"'}
# 1710 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** protocols rsvp interface **]"}
# 1711 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [logical-systems ** protocols rsvp interface **] <unconfigured> -> "**"'}
# 1712 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** protocols rsvp interface ** **]"}
# 1713 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** protocols mpls interface **]"}
# 1714 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [class-of-service interfaces ** unit ** rewrite-rules exp **]"}
# 1715 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 1716 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [snmp trap-group ** targets **]"}
# 1717 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [system syslog host ** kernel] <unconfigured> -> "**"'}
# 1718 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [system syslog host ** interactive-commands] <unconfigured> -> "**"'}
# 1719 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [snmp community ** clients **]"}
# 1720 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** protocols bgp group ** neighbor **]"}
# 1721 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [logical-systems ** protocols bgp group ** neighbor ** description] <unconfigured> -> "**"'}
# 1722 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [logical-systems ** protocols bgp group ** neighbor **] <**> -> "**"'}
# 1723 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' activate: [logical-systems ** protocols bgp group ** neighbor **]"}
# 1724 {'cat': 'egp(bgp)', 'lt': 'rpd[**]: bgp_read_v4_message:**: NOTIFICATION received from ** (** AS **): code ** (Open Message Error)'}
# 1725 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on secondary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 1726 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_SWITCH: MPLS LSP ** switch from secondary(**) to primary(**), Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**): lsp bandwidth ** bps'}
# 1727 {'cat': 'mgmt(pam)', 'lt': 'login: LOGIN_PAM_AUTHENTICATION_ERROR: PAM authentication error for user **[[B^[[**'}
# 1728 {'cat': 'mgmt(login)', 'lt': 'login: LOGIN_FAILED: Login failed for user **[[B^[[** from host **'}
# 1729 {'cat': 'mgmt(login)', 'lt': "login: LOGIN_FAILED_LIMIT: Specified number of login failures (**) for user '**[[B^[[**' reached from '**'"}
# 1730 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** protocols mpls label-switched-path ** secondary **]"}
# 1731 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' delete: [logical-systems ** protocols mpls path ** **] "**'}
# 1732 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [logical-systems ** protocols mpls path ** **]"}
# 1733 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [routing-options rib ** static route ** bfd-liveness-detection minimum-interval] <unconfigured> -> "**"'}
# 1734 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [routing-options rib ** static route ** bfd-liveness-detection multiplier] <unconfigured> -> "**"'}
# 1735 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [routing-options static route ** bfd-liveness-detection minimum-interval] <unconfigured> -> "**"'}
# 1736 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [routing-options static route ** bfd-liveness-detection multiplier] <unconfigured> -> "**"'}
# 1737 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' delete: [policy-options community com_65003:** members] "**:**'}
# 1738 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [policy-options as-path-group ** as-path **]"}
# 1739 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [firewall family ** filter ** term **]"}
# 1740 {'cat': 'interface(interface)', 'lt': '** unplugged'}
# 1741 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [interfaces **] "disable -> "**"'}
# 1742 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [protocols ospf export **]"}
# 1743 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_NEW: User \'**\' insert: [protocols ospf export export-ospf] before ""**""'}
# 1744 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [protocols ospf area ** interface **] <unconfigured> -> "disable"'}
# 1745 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [protocols ospf3 export **]"}
# 1746 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [protocols ospf3 area ** interface lo0.10] <unconfigured> -> "**"'}
# 1747 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [policy-options policy-statement ** term ** then **]"}
# 1748 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [policy-options policy-statement ** term ** then external type] <**> -> "**"'}
# 1749 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' delete: [routing-instances ** routing-options rib ** static route ** next-hop] "**'}
# 1750 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' delete: [routing-instances ** routing-options static route ** next-hop] "**'}
# 1751 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [routing-instances ** routing-options rib ** static route ** qualified-next-hop **]"}
# 1752 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [routing-instances ** routing-options static route ** qualified-next-hop **]"}
# 1753 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [logical-systems ** protocols mpls label-switched-path **] "node-link-protection -> "**"'}
# 1754 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [logical-systems ** protocols mpls path ** **] "strict -> "**"'}
# 1755 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [routing-options rib ** static route ** bfd-liveness-detection **]"}
# 1756 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [routing-options static route ** bfd-liveness-detection minimum-interval]"}
# 1757 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [routing-options static route ** bfd-liveness-detection multiplier]"}
# 1758 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [protocols ** area ** interface **]"}
# 1759 {'cat': 'network(rsvp)', 'lt': '**:rpd[**]: RPD_RSVP_NBRDOWN: RSVP neighbor ** down on interface **, neighbor seq number change'}
# 1760 {'cat': 'network(rsvp)', 'lt': '**:rpd[**]: RPD_RSVP_NBRDOWN: RSVP neighbor ** down on interface **, neighbor timeout'}
# 1761 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [routing-options rib inet6.0 static route **]"}
# 1762 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [routing-options static route **]"}
# 1763 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [protocols ** area ** interface **]"}
# 1764 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [logical-systems ** protocols ** area ** interface **]"}
# 1765 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [routing-instances ** routing-options rib ** static route **]"}
# 1766 {'cat': 'system(unix)', 'lt': 'inetd[**]: Number of telnet connections at max limit (**)'}
# 1767 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_SWITCH: MPLS LSP ** switch from primary(**) to secondary(**), Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**): lsp bandwidth ** bps'}
# 1768 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_SWITCH: MPLS LSP ** switch from primary(**) to secondary(**), Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**): lsp bandwidth ** bps'}
# 1769 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** ** on secondary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 1770 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_SWITCH: MPLS LSP ** switch from secondary(**) to primary(**), Route **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**): lsp bandwidth ** bps'}
# 1771 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_SWITCH: MPLS LSP ** switch from secondary(**) to primary(**), Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**): lsp bandwidth ** bps'}
# 1772 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_SWITCH: MPLS LSP ** switch from secondary(**) to primary(**), Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**): lsp bandwidth ** bps'}
# 1773 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [policy-options as-path-group ** as-path **] <unconfigured> -> "**+**+**+**"'}
# 1774 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [policy-options policy-statement ** term ** then as-path-prepend] <unconfigured> -> "** **"'}
# 1775 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [policy-options policy-statement ** term ** then as-path-prepend] <unconfigured> -> "** ** **"'}
# 1776 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [policy-options policy-statement ** term **]"}
# 1777 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [policy-options policy-statement ** term ** then as-path-prepend] <unconfigured> -> "**"'}
# 1778 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [policy-options policy-statement ** term ** then as-path-prepend] <unconfigured> -> "** ** ** **"'}
# 1779 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_SWITCH: MPLS LSP ** switch from primary(**) to secondary(**), Route **(flag=**) **(Label=**): lsp bandwidth ** bps'}
# 1780 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_SWITCH: MPLS LSP ** switch from primary(**) to secondary(**), Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**): lsp bandwidth ** bps'}
# 1781 {'cat': 'vpn(mpls)', 'lt': '**:rpd[**]: RPD_MPLS_LSP_CHANGE: MPLS LSP ** ** on primary(**) Route ** **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'}
# 1782 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [logical-systems ** protocols rsvp interface **]"}
# 1783 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [logical-systems ** protocols mpls interface **]"}
# 1784 {'cat': 'mgmt(config)', 'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [forwarding-options **]"}
# 1785 {'cat': 'network(storm)', 'lt': '[**]: EVT ** ** ** PORT ** ** **:** NIF ** Port **:multicast storm detected.'}
# 1786 {'cat': 'network(storm)', 'lt': '[**]: EVT ** ** ** PORT ** ** **:** NIF ** Port **:multicast storm recovered.'}
# 1787 {'cat': 'mgmt(config)', 'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [interfaces ** framing] <unconfigured> -> "**"'}
# 1788 {'cat': 'system(None)', 'lt': 'mic_ifd_attach: Calling ** for link ** MIC(**)'}

# %%
labeled_ltid = ['151', '153', '181', '43', '453', '376']

# %%
lt_per_cat.keys()
# Out:
# dict_keys(['system(cron)', 'network(lacp)', 'service(ntp)', 'monitor(syslog)', 'network(mtu)', 'mgmt(login)', 'system(ui)', 'mgmt(command)', 'mgmt(ssh)', 'network(l2)', 'system(unix)', 'network(storm)', 'system(pic)', 'network(pfe)', 'system(ppe)', 'mgmt(pam)', 'mgmt(su)', 'egp(bgp)', 'network(mld)', 'system(fpc)', 'network(arp)', 'interface(port)', 'mgmt(config)', 'interface(agg)', 'monitor(snmp)', 'interface(if_event)', 'interface(vlan)', 'mgmt(enable)', 'vpn(mpls)', 'network(stp)', 'igp(ospf)', 'network(rsvp)', 'vpn(l2vc)', 'vpn(vpls)', 'network(tcp)', 'system(fan)', 'mgmt(ftp)', 'network(sfp)', 'system(power)', 'system(system_conf)', 'network(socket)', 'system(tnp)', 'system(alarm)', 'system(gres)', 'network(pim)', 'egp(msdp)', 'interface(interface)', 'system(others)', 'system(config_apply)', 'mgmt(config_process)', 'network(routing)', 'mgmt(ui_error)', 'system(None)', 'system(cos)', 'system(ppm)', 'monitor(bfd)', 'system(lisence)', 'network(icmp)', 'system(csu)', 'system(boot)', 'system(pci)', 'interface(inet6)', 'network(lldp)', 'network(mcsnoop)'])

# %%
lt_per_cat.items()
# Out:
# dict_items([('system(cron)', ['/usr/sbin/cron[**]: (root) CMD (newsyslog)', '/usr/sbin/cron[**]: (**) CMD (adjkerntz -a)', '/usr/sbin/cron[**]: (**) CMD (/usr/sbin/check-support -l)', '** /usr/sbin/cron[**]: (**) CMD (newsyslog)', '** /usr/sbin/cron[**]: (**) CMD (adjkerntz -a)', '** /usr/sbin/cron[**]: (**) CMD (/usr/sbin/check-support -l)', '/usr/sbin/cron[**]: (root) CMD ( /usr/libexec/atrun)', '/usr/sbin/cron[**]: (*system*) RELOAD (/etc/crontab)']), ('network(lacp)', ['mib2d[**]: lacp info not found for ifl:**', 'mib2d[**]: cleared lacp info not found for ifl:**', 'ifinfo: lacp info not found for ifl:**', 'ifinfo: cleared lacp info not found for ifl:**', '/kernel: KERN_LACP_INTF_STATE_CHANGE: lacp_update_state_userspace: new state is ** cifd **', 'lacpd[**]: LACPD_TIMEOUT: **: lacp current while timer expired current Receive State: CURRENT']), ('service(ntp)', ['xntpd[**]: NTP Server Unreachable', 'xntpd[**]: kernel time sync enabled **', 'xntpd[**]: synchronized to **, stratum=**', 'xntpd[**]: ntpd exiting on signal **', 'xntpd[**]: ntpd ** ** ** ** ** ** ** (**)', 'xntpd[**]: precision = ** usec', 'xntpd[**]: Listening on interface **, **#**', 'xntpd[**]: kernel time sync status **', 'xntpd[**]: frequency initialized ** PPM from **', 'xntpd[**]: kernel time sync disabled **', 'xntpd[**]: time reset +** s', 'xntpd[**]: no servers reachable', '** xntpd[**]: NTP Server Unreachable', '** xntpd[**]: synchronized to **, stratum=**', '** xntpd: NTPD_CHANGED_TIME: time reset +** s', '** xntpd[**]: time reset +** s', '** xntpd: kernel time sync disabled **', '** xntpd: synchronized to **, stratum=**', '** xntpd: kernel time sync enabled **', '** xntpd: NTP Server Unreachable', 'xntpd[**]: mlockall(): Resource temporarily unavailable', '** xntpd[**]: ntpd exiting on signal **', '** xntpd[**]: ntpd 4.2.0-a ** ** ** ** ** ** (**)', '** xntpd[**]: precision = ** usec', '** xntpd[**]: Listening on interface **, **#**', '** xntpd[**]: kernel time sync status **', '** xntpd[**]: frequency initialized ** PPM from **', '** xntpd[**]: kernel time sync disabled **', '** xntpd[**]: kernel time sync enabled **', 'xntpd[**]: Connection re-established to **', 'xntpd: NTPD_CHANGED_TIME: time reset +** s', 'xntpd: synchronized to **, stratum=**', 'xntpd: kernel time sync enabled **', 'xntpd: ntpd exiting on signal **', 'ntpdate: NTPDATE_TIME_CHANGED: step time offset ** **']), ('monitor(syslog)', ['last message repeated ** times', 'SYSLOG: ** messages lost, message queue overflowed.', 'Slot **, PIC Slot **) SYSLOG: ** messages lost, message queue overflowed.', '** last message repeated ** times']), ('network(mtu)', ['/kernel: MTU for ** reduced to **', 'rpd[**]: EVENT <MTU> ** index ** <Up Broadcast PointToPoint Multicast> address #** **', 'rpd[**]: EVENT <MTU> ** index ** <Up Broadcast Multicast> address #** **', '**: rpd[**]: EVENT <MTU> ** index ** <Up Broadcast PointToPoint Multicast>', '**: rpd[**]: EVENT <MTU> ** index ** <Broadcast Multicast> address #** **', 'mcsn[**]: EVENT <MTU> index ** <Broadcast Multicast>', '**: rpd[**]: EVENT <MTU> index ** <Broadcast Multicast>', 'mcsn[**]: EVENT <MTU> index ** <Broadcast Multicast> address #** **', '**: rpd[**]: EVENT <MTU> index ** <Broadcast Multicast> address #** **', 'rpd[**]: EVENT <MTU> ** index ** <Broadcast Multicast> address #** **', 'rpd[**]: EVENT <MTU> index ** <Broadcast Multicast> address #** **', '**: rpd[**]: EVENT <MTU> index ** <Up Broadcast Multicast>', 'mcsn[**]: EVENT <MTU> index ** <Up Broadcast Multicast>', '**: rpd[**]: EVENT <MTU> index ** <Up Broadcast Multicast> address #** **', 'mcsn[**]: EVENT <MTU> index ** <Up Broadcast Multicast> address #** **', 'rpd[**]: EVENT <MTU> index ** <Up Broadcast Multicast>', 'rpd[**]: EVENT <MTU> index ** <Up Broadcast Multicast> address #** **', '**: rpd[**]: EVENT <MTU> ** index ** <Up Broadcast Multicast> address #** **', 'rpd[**]: EVENT <MTU> index ** <Broadcast Multicast>', 'rpd[**]: EVENT <MTU> ** index ** <Broadcast PointToPoint ...

# %% [markdown]
# ## LDA

# %% [markdown]
# ### full length

# %%
len(lt_per_cat)
# Out:
# 64

# %%
for k,v in lt_per_cat.items():
    if k == 'system(alarm)':
        print(len(v), v[0])
    if k == 'service(ntp)':
        print(len(v), v[0])
# Out:
# 35 xntpd[**]: NTP Server Unreachable
# 45 alarmd[**]: Alarm set: RE color=**, class=**, reason=Loss of communication with Backup RE

# %% [markdown]
# - eval_everyとchunksizeがかなり効いた...
# - minimum_probabilityも，下げる必要あり．各単語の値が打ち切られないくらいの値．
# - eta, alpha はあまり大きな影響なし．
# - 1回しか出てきてない単語のうち，表記揺れのもの(品詞が違う．success or successfull など)

# %%
tmp = []
eval_corpus = []
eval_corpus_ltids = []
for ltid, i in enumerate(corpus):
    if word_dict['ui'] not in [j[0] for j in i]: # uiを弾く(550番)
        tmp.append(tuple(sorted(i)))
        eval_corpus.append(i)
        eval_corpus_ltids.append(ltid)
    
print(len(tmp))
set_corpus = list(set(tmp))
# Out:
# 1246

# %%
lda.log_perplexity(corpus)

# %%
results =  [np.argmax(l) for l in lda.inference(eval_corpus)[0]]

inference_results = {}
for a,b in zip(eval_corpus, results):
    if b in inference_results:
        inference_results[b].append([inv_word_dict[c[0]] for c in a])
    else:
        inference_results[b] = [[inv_word_dict[c[0]] for c in a]]

# %%
for topic in range(lda.num_topics):
    print(topic, [inv_word_dict[i[0]] for i in lda.get_topic_terms(topic)])
# print('1', [inv_word_dict[i[0]] for i in lda.get_topic_terms(1)])
# Out:
# 0 ['status', 'rcp', 'exited', 'libjnx', 'pcie', 'normal', 'common', 'replicate', 'r', 'root']
# 1 ['info', 'received', 'down', 'pfeman', 'connect', 'resync', 'tnp.tftpd', 'tftpd', 'write', 'correctable']
# 2 ['rpd', 'to', 'bgp', 'peer', 'notification', 'sent', 'msdp', 'up', 'timeout', 'pim']
# 3 ['kernel', 'state', 'changed', 'ifl', 'bundle', 'local', 'bfdd', 'ready', 'cmsfpc', 'slave']
# 4 ['cleared', 'alarmd', 'class', 'color', 'pwr', 'supply', 'reasonfpc', 'reasonhost', 'reasonloss', 'reasonexcessive']
# 5 ['krt', 'limit', 'adding', 'if', 'update', 'retries', 'rt', 'eventd', 'after', 'route']
# 6 ['read', 'pio', 'jsr', 'trinity', 'sdrl', 'toe', 'unreplicate', 'handle;', 'u64', 'chip']
# 7 ['config', 'process', 'gumem', 'cfg', 'mask', 'error.', 'runlength', 'sample', 'ignoring', 'dyn']
# 8 ['instance', 'msg', 'ifd', 'iff', 'prl', 'ack', 'bd', 'edit', 'handle', 'mvlan']
# 9 ['link', 'sfp', 'chassism', 'low', 'mic', 'xcvr', 'fxp0', 'current', 'bias', 'laser']
# 10 ['found', 'lacp', 'ethernet', 'ppe', 'switch', 'bcm5389', 'while', 'timer', 'hw', 'lacpd']
# 11 ['from', 'for', 'login', 'sshd', 'by', 'user', 'host', 'licensecheck', 'disconnect', 'attempt']
# 12 ['alarm', 'craftd', 'set', 'major', 'pem', 'minor', 'errors', 'input', 'rev', 'bad']
# 13 ['usrsbincron', 'cmd', 'thread', 'started', 'newsyslog', 'service', 'ratelimitburst', 'etccrontab', '*system*', 'reload']
# 14 ['ucode', 'all', 'program', 'img', 'x', 'mgd', 'usrlibexecuipackage', 'disabled.', 'fifo', 'data']
# 15 ['address', 'vlan', 'evt', 'exceeded', 'up.', 'table', 'base', 'was', 'entries', 'configured']
# 16 ['neighbor', 'register', 'rsvp', 'jspec', 'bist', 'bypass', 'ospf', 'tnpv2', 'deleting', 'tnpv3']
# 17 ['is', 'err', 'configuration', 'power', 'ps', 'notconnect.', 'off.', 'empty', 'based', 'rewrite']
# 18 ['port', 'mac', 'nif', 'group', 'channel', 'storm', 'l2ald', 'detached', 'recovered.', 'detected.']
# 19 ['version', 'cannot', 'tnp.bootpd', 'exit', 'boot', 'this', 'bootpd', 'built', 'nh', 'child']
# 20 ['chassisd', 'trap', 'snmp', 'ifdev', 'and', 'cm', 'detach', 'other', 'initialized', 'setting']
# 21 ['pfe', 'complete', 'detected', 'cmtfpc', 'cmt', 'asic', 'type', 'initialization', 'cms', 'wedge']
# 22 ['access', 'incorrect', 'show', 'hostif', 'stream', '#', 'buffer', 'head', 'logout', '.']
# 23 ['ns', 'pfed', 'libjsnmp', 'log', 'ipc', 'dcd', 'rows', 'reg', 'warning', 'auth']
# 24 ['task', 'reinitializing', 'reinit', 'reconfigure', 'done', 'l2cp', 'eswd', 'machines', 'lldp', 'lldpd']
# 25 ['init', 'signal', 'pid', 'terminate', 'sent', 'bulkget', 'manager', 'due', 'sending', 'watchdog']
# 26 ['mpls', 'change', 'lsp', 'path', 'kern', 'arp', 'ip', 'profiles', 'are', 'dynamicprofiles']
# 27 ['error', 'login', 'failed', 'pci', 'id', 'password', 'pam', 'authentication', 'cap', 'source']
# 28 ['mcsn', 'stp', 'tcgeneration', 'bandwidth', 'updown', 'chg', 'opdelete', 'opadd', 'encapsulation', 'opchange']
# 29 ['at', 'inetd', 'device', 'number', 'mq', 'max', 'ddr3', 'passed', 'verify', 'retry']
# 30 ['connection', 're', 'as', 'src', 'pp', 'closed', 'established', 'made', 'l2alm', 'ppman']
# 31 ['entry', 'lu', 'create', 'mqchip', 'addr', 'queue', 'last', 'packet', 'seg', 'dest']
# 32 ['master', 'ok', 'op', 'cosd', 'tcp', 'socket', 'gencfg', 'ae', 'unsupported', 'pre']
# 33 ['pic', 'slot', 'message', 'the', 'active', 'fpc', 'with', 'request', 'cos', 'online']
# 34 ['evt', 'system', 'csu', 'software', 'many', 'administratively.', 'fan', 'enabled', 'fpga', 'standby']
# 35 ['on', 'destination', 'pfealiveness', 'turning', 'vccpd', 'fpc1', 'exit', 'off', 'su', 'builder']
# 36 ['luchip', 'snmpd', 'send', 'failure', 'in', 'sa', 'mib2d', 'libjsnmp', 'count', 'partial']
# 37 ['xntpd', 'time', 'reset', '+', 'recv', 'server', 'ntpd', 'reason', 'mpc', 'proto']
# 38 ['index', 'event', 'broadcast', 'multicast', 'up', 'mtu', 'chas', 'updown', 'no', 'add']
# 39 ['not', 'interface', 'of', 'rsp', 'delete', 'can', 'receive', 'jl2tpd', 'mode', 'cant']

# %%
for i,j in lda.show_topics(num_topics=lda.num_topics):
    print(i)
    print("\t", j)
# Out:
# 0
# 	 0.323*"rpd" + 0.108*"to" + 0.055*"bgp" + 0.053*"sent" + 0.035*"connection" + 0.028*"notification" + 0.024*"as" + 0.024*"mpls" + 0.018*"timeout" + 0.016*"change"
# 1
# 	 0.173*"evt" + 0.116*"port" + 0.073*"address" + 0.043*"mac" + 0.035*"nif" + 0.034*"access" + 0.026*"vlan" + 0.022*"group" + 0.022*"channel" + 0.020*"storm"
# 2
# 	 0.068*"at" + 0.050*"inetd" + 0.044*"device" + 0.043*"xcvr" + 0.035*"number" + 0.030*"mq" + 0.027*"max" + 0.020*"default" + 0.015*"ddr3" + 0.015*"passed"
# 3
# 	 0.209*"login" + 0.157*"error" + 0.094*"failed" + 0.071*"pci" + 0.030*"id" + 0.023*"password" + 0.015*"pam" + 0.015*"show" + 0.011*"authentication" + 0.010*"ftpd"
# 4
# 	 0.170*"init" + 0.100*"pid" + 0.096*"signal" + 0.063*"terminate" + 0.048*"bulkget" + 0.026*"starting" + 0.021*"sending" + 0.019*"socket" + 0.017*"due" + 0.015*"watchdog"
# 5
# 	 0.106*"cleared" + 0.079*"class" + 0.074*"alarmd" + 0.058*"color" + 0.057*"commit" + 0.032*"ucode" + 0.026*"program" + 0.026*"img" + 0.017*"unsupported" + 0.016*"processing"
# 6
# 	 0.053*"entry" + 0.044*"lu" + 0.044*"create" + 0.044*"mqchip" + 0.037*"addr" + 0.035*"queue" + 0.026*"last" + 0.026*"packet" + 0.025*"src" + 0.022*"dest"
# 7
# 	 0.071*"neighbor" + 0.062*"rsvp" + 0.050*"cmd" + 0.040*"pim" + 0.036*"usrsbincron" + 0.034*"bypass" + 0.031*"junoscript" + 0.028*"ospf" + 0.027*"nbrdown" + 0.021*"nbrup"
# 8
# 	 0.088*"ns" + 0.083*"down" + 0.064*"pfed" + 0.051*"libjsnmp" + 0.039*"log" + 0.037*"ipc" + 0.033*"dcd" + 0.028*"reg" + 0.028*"rows" + 0.025*"warning"
# 9
# 	 0.111*"peer" + 0.077*"xntpd" + 0.048*"time" + 0.041*"recv" + 0.038*"reset" + 0.034*"msdp" + 0.034*"+" + 0.019*"ntpd" + 0.018*"proto" + 0.017*"server"
# 10
# 	 0.268*"kernel" + 0.064*"state" + 0.040*"master" + 0.039*"re" + 0.037*"changed" + 0.037*"ifl" + 0.028*"ok" + 0.028*"op" + 0.024*"bundle" + 0.024*"local"
# 11
# 	 0.174*"ui" + 0.149*"mgd" + 0.061*"cfg" + 0.051*"audit" + 0.046*"file" + 0.041*"other" + 0.029*"logout" + 0.025*"auth" + 0.017*"invalid" + 0.013*"licensecheck"
# 12
# 	 0.095*"luchip" + 0.067*"pfe" + 0.050*"in" + 0.032*"complete" + 0.031*"detected" + 0.028*"cmtfpc" + 0.024*"many" + 0.023*"cmt" + 0.023*"asic" + 0.023*"count"
# 13
# 	 0.072*"version" + 0.072*"register" + 0.051*"jspec" + 0.039*"bist" + 0.029*"tnp.bootpd" + 0.027*"boot" + 0.026*"initializing" + 0.022*"bootpd" + 0.022*"built" + 0.018*"tcam"
# 14
# 	 0.104*"chas" + 0.093*"no" + 0.041*"handler" + 0.039*"limit" + 0.037*"exit" + 0.026*"vccpd" + 0.023*"command" + 0.021*"eventd" + 0.016*"enable" + 0.015*"timed"
# 15
# 	 0.171*"status" + 0.057*"exited" + 0.039*"rcp" + 0.031*"pcie" + 0.030*"libjnx" + 0.027*"normal" + 0.023*"common" + 0.021*"jl2tpd" + 0.020*"replicate" + 0.020*"r"
# 16
# 	 0.239*"mcsn" + 0.087*"stp" + 0.040*"if" + 0.033*"adding" + 0.033*"tcgeneration" + 0.018*"bd" + 0.017*"bandwidth" + 0.011*"snooping" + 0.011*"phy" + 0.009*"updown"
# 17
# 	 0.095*"not" + 0.081*"child" + 0.072*"rsp" + 0.068*"delete" + 0.068*"interface" + 0.029*"ready" + 0.025*"start" + 0.020*"cannot" + 0.018*"can" + 0.017*"this"
# 18
# 	 0.105*"sshd" + 0.079*"by" + 0.073*"config" + 0.049*"instance" + 0.030*"disconnect" + 0.026*"hostif" + 0.024*"disconnected" + 0.021*"stream" + 0.021*"receive" + 0.020*"setting"
# 19
# 	 0.161*"from" + 0.148*"user" + 0.122*"for" + 0.105*"is" + 0.043*"err" + 0.026*"power" + 0.026*"host" + 0.022*"port" + 0.017*"ps" + 0.013*"attempt"
# 20
# 	 0.132*"info" + 0.104*"received" + 0.090*"of" + 0.062*"pfeman" + 0.037*"connect" + 0.024*"resync" + 0.019*"tftpd" + 0.019*"tnp.tftpd" + 0.018*"write" + 0.018*"correctable"
# 21
# 	 0.104*"system" + 0.042*"csu" + 0.035*"all" + 0.035*"administratively." + 0.024*"enabled" + 0.024*"prl" + 0.021*"has" + 0.021*"fpga" + 0.021*"standby" + 0.018*"call"
# 22
# 	 0.151*"chassisd" + 0.068*"trap" + 0.044*"snmp" + 0.036*"configuration" + 0.031*"ifdev" + 0.026*"process" + 0.024*"cm" + 0.024*"and" + 0.019*"detach" + 0.016*"empty"
# 23
# 	 0.106*"link" + 0.044*"lacp" + 0.039*"msg" + 0.039*"sfp" + 0.038*"chassism" + 0.034*"low" + 0.034*"mic" + 0.026*"ae" + 0.024*"fxp0" + 0.023*"ifd"
# 24
# 	 0.136*"alarm" + 0.115*"set" + 0.102*"craftd" + 0.066*"major" + 0.051*"pem" + 0.047*"minor" + 0.034*"errors" + 0.029*"input" + 0.017*"rev" + 0.015*"bad"
# 25
# 	 0.201*"task" + 0.088*"reinitializing" + 0.052*"reinit" + 0.046*"found" + 0.041*"done" + 0.041*"reconfigure" + 0.031*"l2cp" + 0.021*"eswd" + 0.020*"ethernet" + 0.015*"switch"
# 26
# 	 0.098*"snmpd" + 0.062*"send" + 0.059*"failure" + 0.057*"mib2d" + 0.057*"sa" + 0.034*"libjsnmp" + 0.030*"cosd" + 0.029*"software" + 0.026*"partial" + 0.019*"type"
# 27
# 	 0.164*"pic" + 0.140*"slot" + 0.045*"message" + 0.045*"the" + 0.041*"fpc" + 0.038*"with" + 0.035*"active" + 0.027*"request" + 0.021*"cos" + 0.016*"online"
# 28
# 	 0.184*"event" + 0.167*"index" + 0.143*"broadcast" + 0.094*"multicast" + 0.074*"up" + 0.045*"mtu" + 0.040*"updown" + 0.034*"add" + 0.030*"pointtopoint" + 0.025*"bandwidth"
# 29
# 	 0.144*"on" + 0.107*"read" + 0.065*"pio" + 0.038*"trinity" + 0.035*"turning" + 0.035*"pfealiveness" + 0.035*"destination" + 0.023*"fpc1" + 0.017*"off" + 0.017*"toe"

# %%
for k,v in sorted(inference_results.items()):
    print(k,":", lda.print_topic(k))
    for vv in v:
        print('\t', " ".join(vv))
    print()
# Out:
# 0 : 0.180*"status" + 0.053*"rcp" + 0.053*"exited" + 0.041*"libjnx" + 0.038*"pcie" + 0.034*"normal" + 0.029*"common" + 0.027*"replicate" + 0.027*"r" + 0.023*"root"
# 	 inetd usrsbinsshd exited status
# 	 inetd usrsbinsshd exited status
# 	 bringup pcie common status
# 	 bringup pcie common link training took
#
# 	 libjnx exec wexit command exited pid status
# 	 licensecheck libjnx replicate rcp error r
# 	 init pid exited with status normal exit
# 	 inetd exited status
# 	 bringup pcie common status
# 	 bringup pcie common link training took
# 	 kernel init pid exited with status normal
#
# 1 : 0.151*"info" + 0.113*"received" + 0.092*"down" + 0.070*"pfeman" + 0.042*"connect" + 0.027*"resync" + 0.022*"tnp.tftpd" + 0.022*"tftpd" + 0.020*"write" + 0.020*"correctable"
# 	 pci info correctable counts
# 	 pci info correctable counts btlp bdllp rto
# 	 pci info correctable counts btlp
# 	 pci info correctable counts
# 	 pci info correctable counts btlp
# 	 pfeman start service bulkget
# 	 pfeman npc sent resync request to master
# 	 pfeman received resync complete.
# 	 bulkget start pfeman transaction
# 	 pfeman sent resync request to master
# 	 bulkget stop pfeman transaction
# 	 bulkget start pfeman transaction
# 	 rpd bgp connect start as no
# 	 pfeman npc sent resync request to master
# 	 pfeman received resync complete.
# 	 rpd bgp connect start as no
# 	 relayd libjunos sdk received sigterm shutting down
# 	 pfeman start service bulkget
# 	 tnp.tftpd tftpd connect info tftp read from
# 	 tnp.tftpd tftpd sendcomplete info sent blocks of
# 	 tnp.tftpd tftpd connect info tftp write from
# 	 tnp.tftpd tftpd recvcomplete info received blocks of
#
# 2 : 0.384*"rpd" + 0.135*"to" + 0.066*"bgp" + 0.051*"peer" + 0.034*"notification" + 0.027*"sent" + 0.020*"msdp" + 0.018*"up" + 0.017*"timeout" + 0.012*"pim"
# 	 rpd bgp read v4 message notification received
# 	 rpd bgp read v4 message notification received
# 	 rpd bgp pp recv notification sent to
# 	 rpd bgp pp recv notification sent to
# 	 rpd bgp ifachange group notification sent to
# 	 rpd bgp pp recv notification sent to
# 	 rpd bgp process open notification sent to
# 	 rpd pim nbrdown pim.master neighbor
# 	 rpd synchronized commit processing phase
# 	 rpd synchronized commit processing complete
# 	 rpd bgp pp timeout peer + proto
# 	 rpd bgp pp timeout notification sent to
# 	 rpd as shutting down peer due to
# 	 rpd bgp rt maxprefixes check common notification
# 	 rpd bgp read v4 message notification received
# 	 rpd as shutting down peer due to
# 	 rpd bgp pp recv notification sent to
# 	 rpd bgp pp recv notification sent to
# 	 rpd bgp read v4 message notification received
# 	 rpd bgp read message notification sent to
# 	 rpd bgp process caps notification sent to
# 	 rpd bgp read message notification received from
# 	 rpd msdp src active over limit
# 	 rpd msdp src active under limit
# 	 rpd msdp src active over thresh
# 	 rpd msdp src active under thresh
# 	 rpd msdp src active over limit
# 	 rpd msdp src active under limit
# 	 clksync failed to connect master
# 	 l2alm failed to connect master
# 	 rpd stp
# 	 rpd bgp read message notification received from
# 	 rpd bgp recv peer + proto received
# 	 rpd layer2 vc down state of
# 	 xntpd synchronized to stratum
# 	 rpd bgp read v4 message notification received
# 	 rpd layer2 vc up state of
# 	 rpd bgp hold timeout notification sent to
# 	 rpd bgp neighbor state changed
# 	 rpd bgp read v4 message notification received
# 	 rpd bgp pp recv rejecting connection from
# 	 rpd bgp pp recv notification sent to
# 	 rpd bgp read v4 message notification received
# 	 rpd bgp read v4 message notification received
# 	 rpd bgp read v4 message notification received
# 	 rpd bgp recv read from peer as
# 	 rpd bgp recv peer as received unexpected
# 	 rpd pim nbrup instance pim.master
# 	 rpd msdp peer up
# 	 rpd bgp pp recv notification sent to
# 	 rpd bgp recv peer + proto received
# 	 kernel if pfe peek peer info
# 	 rpd pim nbrdown instance pim.master
# 	 rpd pim nbrdown instance pim.master
# 	 xntpd synchronized to stratum
# 	 rpd bgp send sending bytes to as
# 	 rpd stp
# 	 rpd bgp read v4 message notification received
# 	 rpd bgp pp recv notification sent to
# 	 rpd bgp hold timeout notification sent to
# 	 rpd bgp neighbor state changed
# 	 clksync failed to connect master
# 	 kernel setting server address to
# 	 rpd synchronized commit processing phase
# 	 rpd bgp peer delete notification sent to
# 	 evt port mgmt error detected on the
# 	 rpd synchronized commit processing complete
# 	 rpd bgp read v4 message notification received
# 	 rpd hold timer
# 	 rpd bgp read message peer as notification
# 	 rpd bgp read message notification received from
# 	 rpd bgp recv read from peer +
# 	 rpd msdp src active over thresh
# 	 rpd msdp src active under thresh
# 	 xntpd synchronized to stratum
# 	 xntpd synchronized to stratum
# 	 rpd bgp pp recv notification sent to
# 	 rpd bgp process open notification sent to
# 	 rpd bgp peer mgmt clear notification sent
# 	 rpd msdp peer down
# 	 rpd bgp set peer if
#
# 3 : 0.371*"kernel" + 0.084*"state" + 0.048*"changed" + 0.048*"ifl" + 0.032*"bundle" + 0.032*"local" + 0.027*"bfdd" + 0.026*"ready" + 0.011*"cmsfpc" + 0.010*"slave"
# 	 kernel mtu for reduced to
# 	 kernel bundle ae6.202 ifl state changed
# 	 kernel leaves
# 	 kernel bundle ae6.107 ifl state changed
# 	 kernel joins
# 	 cmsfpc ready sending fpc mesg to
# 	 kernel clearing slave peer
# 	 kernel peer type index is not ready
# 	 kernel slave is not ready for gres
# 	 kernel peer type index is ready for
# 	 kernel slave is ready for gres
# 	 kernel port status changed
# 	 kernel ae bundlestate ifd change bundle
# 	 kernel ae bundlestate ifd change bundle
# 	 bfdd trap shop state up local
# 	 bfdd trap state up local discriminator
# 	 kernel mtu for reduced to
# 	 kernel local package initialization
# 	 kernel
# 	 kernel kern.securelevel
# 	 kernel
# 	 kernel starting local daemons
# 	 kernel
# 	 kernel tnp version is changed from to
# 	 kernel overwrite linkspeed with child speed
# 	 bfdd trap shop state down local
# 	 kernel leaves
# 	 kernel bundle ifl state changed to
# 	 kernel joins
#
# 4 : 0.174*"cleared" + 0.122*"alarmd" + 0.113*"class" + 0.096*"color" + 0.017*"pwr" + 0.017*"supply" + 0.016*"reasonfpc" + 0.016*"reasonhost" + 0.015*"reasonloss" + 0.013*"reasonexcessive"
# 	 alarmd alarm set fpc color class reasonfpc
# 	 alarmd alarm cleared fpc color class reasonfpc
# 	 alarmd alarm set re color class reasonhost
# 	 alarmd alarm cleared re color class reasonhost
# 	 alarmd alarm set re color class reasonexcessive
# 	 alarmd alarm cleared re color class reasonexcessive
# 	 alarmd alarm set re color class reasonloss
# 	 alarmd alarm cleared re color class reasonloss
# 	 alarmd alarm cleared re color class reasonhost
# 	 alarmd alarm cleared re color class reasonbackup
# 	 alarmd
# 	 alarmd resending alarm state
# 	 alarmd alarm set pwr supply color class
# 	 alarmd alarm cleared pwr supply color class
# 	 alarmd alarm set pwr supply color class
# 	 alarmd alarm set pwr supply color class
# 	 alarmd alarm cleared pwr supply color class
# 	 alarmd alarm cleared pwr supply color class
# 	 alarmd alarm set pwr supply color class
# 	 alarmd alarm cleared pwr supply color class
# 	 alarmd alarm set pwr supply color class
# 	 alarmd alarm cleared pwr supply color class
#
# 5 : 0.056*"krt" + 0.048*"limit" + 0.047*"adding" + 0.038*"if" + 0.035*"update" + 0.028*"retries" + 0.028*"rt" + 0.026*"eventd" + 0.024*"after" + 0.021*"route"
# 	 rpd received update from as family prefix
# 	 chas update mb pic port map debug
# 	 bulkget manager reconnection succeeded after tries
# 	 eventd policy limit exceeded unable to
# 	 rpd krt q retries route update
# 	 rpd krt q retries route update
# 	 kernel rt pfe veto too many delayed
# 	 kernel rt pfe veto possible slowest client
# 	 kernel rt pfe veto possible second slowest
# 	 rpd krt q retries indirect next
# 	 rpd krt q retries route update
# 	 rpd krt q retries indirect next
# 	 eventd sendto no route to host
# 	 rpd krt stp add if adding ifl
# 	 idpd idp commit completed policy
# 	 alarmd connecton succeeded after retries
# 	 craftd chassisd connection succeeded after retries
# 	 eventd sendto network is down
# 	 rpd krt vpls ifl modify unable
# 	 rsp enable login timed out after seconds.
#
# 6 : 0.157*"read" + 0.085*"pio" + 0.074*"jsr" + 0.057*"trinity" + 0.033*"sdrl" + 0.025*"toe" + 0.024*"unreplicate" + 0.022*"handle;" + 0.014*"u64" + 0.013*"chip"
# 	 rpd noblock fgets read from local failed
# 	 l2cp read acess profile config
# 	 luchip pio handle; jspec read u256
# 	 trinity pio errors occurred
# 	 trinity pio last error lu0 pci
# 	 creating trinity i2c dev for li i2
# 	 initialising lu toe
# 	 toe lu chip init complete!
# 	 kernel jsr sdrl reinjectreinject failed
# 	 kernel jsr sdrl unreplicate primary reinject error
# 	 kernel jsr sdrl unrepl socket error
# 	 kernel jsr unreplicate error sdrl
# 	 trinity pio last error mq0 pci
# 	 mq pio handle; read u64 failed
# 	 trinity pio errors occurred
# 	 trinity pio last error mq0 pci
# 	 creating trinity i2c dev for li i2
# 	 initialising lu toe
# 	 toe lu chip init complete!
# 	 luchip pio handle; read u64 failed
# 	 trinity pio last error pci read
# 	 l2cp read acess profile config
# 	 luchip rd nack ap toe read
# 	 luchip pio handle; jspec read u256
#
# 7 : 0.119*"config" + 0.056*"process" + 0.035*"gumem" + 0.027*"cfg" + 0.027*"mask" + 0.027*"error." + 0.025*"runlength" + 0.025*"sample" + 0.025*"ignoring" + 0.020*"dyn"
# 	 luchip gumem.ucode.instr read error.
# 	 rpd bgp process caps mismatch nlri with
# 	 rpd bgp process caps mismatch nlri with
# 	 lu process gumem cfg mask is
# 	 luchip program ucode img gumem mask
# 	 ignoring unsupported runlength config for sample class
# 	 fpc1 ignoring unsupported runlength config for sample
# 	 fpc11 ignoring unsupported runlength config for sample
# 	 rpd task process events no writeconnect method
# 	 chas phy qt2025 link down workaround resetting
# 	 rpd vpls dyn disassociate profilesession id
# 	 chassism phy cfg autoneg port if cfgduplex
# 	 rpd task process events no writeconnect method
# 	 rpd l2vpn dyn config repo flushsession db
# 	 ignoring unsupported runlength config for sample class
# 	 lu process gumem cfg mask is
# 	 luchip program ucode img gumem mask
# 	 evt config configuration access management error. process
# 	 evt config configuration access management error. process
# 	 luchip gumem.ucode.instr read error.
# 	 rpd bgp process caps mismatch nlri with
#
# 8 : 0.084*"instance" + 0.072*"msg" + 0.048*"ifd" + 0.041*"iff" + 0.035*"prl" + 0.026*"ack" + 0.025*"bd" + 0.021*"edit" + 0.020*"handle" + 0.020*"mvlan"
# 	 kernel jsr prl peer msg handler could
# 	 kernel if msg ifd bulk mup down
# 	 usrsbinsampled edit forwardingoptions sampling instance jflow config
# 	 kernel pcf8584wr target ack failure on byte
# 	 mcsn krt snooping decode bd msg
# 	 mcsn krt snooping decode bd msg rtbid
# 	 chas ifcm ifd remove vector is
# 	 chassism mvlan handle iffm rcvd iff msg
# 	 rpd read ddl top handle for logicalrouter
# 	 mcsn received iff message ifl op flag
# 	 mcsn krt ifstate iff message for without
# 	 kernel iff ifarequest addr err
# 	 rpd read ddl top handle for logicalrouter
# 	 kernel jsr prl recv ack msg received
# 	 kernel jsr prl call l4 input received
# 	 kernel jsr prl recv ack msg call
#
# 9 : 0.156*"link" + 0.058*"sfp" + 0.054*"chassism" + 0.049*"low" + 0.049*"mic" + 0.039*"xcvr" + 0.036*"fxp0" + 0.025*"current" + 0.017*"bias" + 0.017*"laser"
# 	 kernel fxp0 link media down
# 	 kernel fxp0 media down
# 	 kernel fxp0 link up
# 	 kernel ae link op lidx detached
# 	 kernel ae link op lidx attached
# 	 calling
# 	 mic sfp+ plugged in
# 	 mic link sfp laser bias current low
# 	 mic link sfp output power low
# 	 mic link sfp receive power low
# 	 chas link sfp receive power low
# 	 chas xcvr cache eeprom link pic
# 	 chas xcvr freeing itable entry for
# 	 chas xcvr inserted itable entry at
# 	 chas cm tsunami failed to uplink sfp
# 	 chassism link sfp laser bias current low
# 	 chassism link sfp output power low cleared
# 	 mic ifd attach calling for link
# 	 mic link sfp laser bias current low
# 	 mic link sfp output power low
# 	 mic link sfp receive power low
# 	 mic sfp+ plugged in
# 	 calling
# 	 kernel ae link op lidx detached
# 	 kernel ae link op lidx attached
#
# 10 : 0.099*"found" + 0.088*"lacp" + 0.044*"ethernet" + 0.043*"ppe" + 0.033*"switch" + 0.022*"bcm5389" + 0.022*"while" + 0.022*"timer" + 0.022*"hw" + 0.021*"lacpd"
# 	 mib2d lacp info not found for ifl
# 	 lacpd timeout lacp current while timer
# 	 mqchip init done. hw absent dram mode
# 	 ppe hw fault trap count pc
# 	 ppe hw fault trap count pc
# 	 mqchip init done. hw absent dram mode
# 	 mib2d cleared lacp info not found for
# 	 rpd vpls intf create nsr enabled 0......
# 	 ifinfo lacp info not found for ifl
# 	 ifinfo cleared lacp info not found for
# 	 kernel kern lacp intf state change
# 	 found the 1st bcm5389 ethernet switch
# 	 found the 2nd bcm5389 ethernet switch
#
# 11 : 0.203*"from" + 0.146*"for" + 0.086*"login" + 0.071*"sshd" + 0.043*"by" + 0.032*"user" + 0.032*"host" + 0.020*"licensecheck" + 0.019*"disconnect" + 0.016*"attempt"
# 	 sshd subsystem request for
# 	 login information user logged in
# 	 sshd accepted password for from port
# 	 sshd received disconnect from disconnected by
# 	 sshd received disconnect from disconnected by user
# 	 evt access login from .
# 	 login malformed user invalid username empty
# 	 sshd bad protocol version identification from
# 	 login failed for user from
# 	 connection attempt to tcp from
# 	 sshd protocol major versions differ for vs.
# 	 shutdown reboot by
# 	 licensecheck copy to from
# 	 licensecheck copy from member failed
# 	 login attempt for user from host
# 	 login information user logged in from
# 	 login attempt for user from host
# 	 sshd received disconnect from logout
# 	 login failure from
# 	 login failure from
# 	 evt access login from
# 	 sshd accepted password for from port
# 	 login from
# 	 login timed out attempt
# 	 sshd received disconnect from disconnected by user
# 	 login from
# 	 ftpd connection from
# 	 ftpd ftp login from as
# 	 ftpd ftp login failed from
# 	 ftpd ftp login failed from
# 	 sshd user authenticated successfully but no local
# 	 sshd accepted password for from port
# 	 sshd connection closed by
# 	 sshd failed password for from port
# 	 sshd received disconnect from disconnected by server
# 	 login information user logged in from
# 	 sshd fatal read from socket failed connection
# 	 sshd accepted password for from port ssh2
# 	 login attempt for user from host
# 	 login information user logged in from
# 	 shutdown halt by
#
# 12 : 0.156*"alarm" + 0.117*"craftd" + 0.092*"set" + 0.075*"major" + 0.058*"pem" + 0.054*"minor" + 0.039*"errors" + 0.034*"input" + 0.019*"rev" + 0.017*"bad"
# 	 craftd major alarm set fpc errors
# 	 craftd major alarm cleared fpc errors
# 	 mqchip jtag id major rev minor
# 	 craftd major alarm set host fxp0 ethernet
# 	 craftd major alarm cleared host fxp0 ethernet
# 	 luchip ppe 7 errors lmem data error
# 	 mqchip jtag id major rev minor
# 	 luchip hash prescaler timestamp set to
# 	 craftd minor alarm set excessive modem errors
# 	 craftd minor alarm cleared excessive modem errors
# 	 craftd minor alarm set loss of communication
# 	 craftd minor alarm cleared loss of communication
# 	 craftd major alarm cleared host ecc parity
# 	 craftd minor alarm cleared backup re active
# 	 ixchip jtag id major rev minor
# 	 luchip hash prescaler timestamp set to
# 	 craftd detected platform
# 	 craftd minor alarm set pem fan failed
# 	 craftd minor alarm cleared pem fan failed
# 	 craftd major alarm set pem not ok
# 	 chassisd pem input bad status failure
# 	 craftd major alarm set pem input failure
# 	 chassisd pem input bad failure
# 	 craftd major alarm cleared pem input failure
# 	 craftd major alarm cleared pem not ok
# 	 craftd minor alarm set pem absent
# 	 craftd minor alarm cleared pem absent
# 	 craftd major alarm set pem dipswitch feed
# 	 craftd major alarm cleared pem dipswitch feed
#
# 13 : 0.078*"usrsbincron" + 0.065*"cmd" + 0.051*"thread" + 0.038*"started" + 0.026*"newsyslog" + 0.020*"service" + 0.013*"ratelimitburst" + 0.013*"etccrontab" + 0.013*"*system*" + 0.013*"reload"
# 	 usrsbincron root cmd newsyslog
# 	 initiated pfeman service thread
# 	 pfe fabric probe thread started interval ms
# 	 ratelimitburst
# 	 usrsbincron root cmd usrlibexecatrun
# 	 usrsbincron *system* reload etccrontab
# 	 pfe fabric probe thread started interval ms
# 	 usrsbincron cmd adjkerntz a
# 	 usrsbincron cmd usrsbinchecksupport l
# 	 initiated pfeman service thread
# 	 usrsbincron cmd newsyslog
# 	 usrsbincron cmd adjkerntz a
# 	 usrsbincron cmd usrsbinchecksupport l
#
# 14 : 0.066*"ucode" + 0.055*"all" + 0.055*"program" + 0.055*"img" + 0.044*"x" + 0.033*"mgd" + 0.033*"usrlibexecuipackage" + 0.022*"disabled." + 0.022*"fifo" + 0.018*"data"
# 	 onboard nvram contains diagnostic information.
# 	 luchip program ucode img
# 	 luchip program ucode img ppe mask is
# 	 chas all lion cubs not detected
# 	 mgd usrlibexecuipackage x
# 	 mgd usrlibexecuipackage x validate
# 	 mgd usrlibexecuipackage x update novalidate
# 	 unplugged
# 	 onboard nvram contains diagnostic information.
# 	 forbes0 all fifo disabled.
# 	 forbes1 all fifo disabled.
# 	 luchip program ucode img entry
# 	 luchip program ucode img ppe mask is
# 	 luchip program ucode img success!!!
# 	 luchip errors ucode data error
#
# 15 : 0.205*"address" + 0.074*"vlan" + 0.056*"evt" + 0.033*"exceeded" + 0.030*"up." + 0.025*"table" + 0.017*"base" + 0.017*"was" + 0.017*"entries" + 0.014*"configured"
# 	 evt port up.
# 	 evt vlan status is down.
# 	 rpd as configured maximum prefixlimit threshold exceeded
# 	 evt port up.
# 	 err equipment hardware exceeded tolerance level of
# 	 evt equipment the temperature of hardware returned
# 	 evt vlan status is up.
# 	 evt vlan address table entries was beyond
# 	 evt vlan address table entries exceeded capacity.
# 	 cmlc attempt proto address
# 	 ia base address
# 	 ichip base address
# 	 rpd received table message with address family
# 	 rpd received table message with address family
# 	 cmlc attempt proto address
# 	 evt port mgmt up.
# 	 rpd as configured maximum accepted prefixlimit threshold
# 	 kernel subnet router anycast address not added
#
# 16 : 0.104*"neighbor" + 0.071*"register" + 0.058*"rsvp" + 0.050*"jspec" + 0.038*"bist" + 0.032*"bypass" + 0.028*"ospf" + 0.027*"tnpv2" + 0.027*"deleting" + 0.026*"tnpv3"
# 	 register mqchip rldram bist
# 	 register mqchip dmc bist
# 	 initializing mq jspec
# 	 rpd ospf nbrup neighbor realm
# 	 rpd ospf nbrup neighbor realm
# 	 mqchip pll lock status
# 	 register rldram bist
# 	 register luchip ddr bist
# 	 register luchip hostif
# 	 register mqchip dmc bist
# 	 initializing mq jspec
# 	 rpd ospf nbrdown neighbor realm
# 	 rpd rsvp nbrdown neighbor down
# 	 rpd ospf nbrdown neighbor realm
# 	 rpd ospf nbrup neighbor realm
# 	 rpd ospf nbrup neighbor realm
# 	 rpd ospf nbrup neighbor realm
# 	 rpd ospf nbrup neighbor realm
# 	 rpd ospf nbrdown neighbor realm
# 	 rpd ospf nbrdown neighbor realm
# 	 rpd rsvp nbrdown neighbor down
# 	 rpd rsvp nbrdown neighbor down
# 	 rpd rsvp nbrup neighbor up
# 	 kernel tnpv3 deleting active neighbor entry from
# 	 kernel tnpv3 adding neighbor to interface
# 	 rpd ospf nbrup neighbor realm
# 	 rpd ospf nbrup neighbor realm
# 	 rpd ospf nbrup neighbor realm
# 	 ix chip pre init sysif pll lock
# 	 initializing ix jspec
# 	 rpd rsvp backup down for
# 	 rpd ospf nbrdown neighbor realm
# 	 rpd rsvp bypass down
# 	 rpd rsvp bypass down
# 	 rpd rsvp backup down for
# 	 rpd ospf nbrdown neighbor realm
# 	 rpd rsvp bypass up
# 	 rpd rsvp bypass up
# 	 rpd rsvp backup down for
# 	 rpd rsvp bypass down
# 	 rpd rsvp backup down for
# 	 rpd rsvp bypass down
# 	 mqchip pll lock status
# 	 tcam bisttcam nl9k register request luchip
# 	 register luchip rldram bist
# 	 aser succesfully register jspec
# 	 fpga jspec register ver not match
# 	 register luchip ddr bist
# 	 register luchip tcam bist
# 	 register luchip hostif
# 	 kernel tnpv2 adding neighbor to interface
# 	 kernel tnpv2 deleting active neighbor entry from
#
# 17 : 0.221*"is" + 0.096*"err" + 0.059*"configuration" + 0.059*"power" + 0.037*"ps" + 0.022*"notconnect." + 0.015*"off." + 0.015*"empty" + 0.012*"based" + 0.012*"rewrite"
# 	 evt r8 ps is
# 	 qx is absent.
# 	 err ps is power off. notconnect.
# 	 err ps is notconnect.
# 	 err ps is power off.
# 	 mspd chassisfpc configuration is empty
# 	 kernel mld6 input src is not linklocal
# 	 qx is absent.
# 	 cosman fpc init fc based rewrite is
# 	 cos module init fc based rewrite is
# 	 kernel ipsec is inbound pkt valid socket
# 	 err fan is notconnect.
# 	 err ps is power off.
#
# 18 : 0.241*"port" + 0.078*"mac" + 0.062*"nif" + 0.042*"group" + 0.042*"channel" + 0.036*"storm" + 0.031*"l2ald" + 0.021*"detached" + 0.015*"recovered." + 0.015*"detected."
# 	 plx port rxe count
# 	 evt mac port from channel group denied
# 	 evt port nif storm detected.
# 	 evt port nif storm recovered.
# 	 l2ald mac limit reached ifbd
# 	 l2ald mac limit reset if resumed
# 	 evt mac port detached from channel group
# 	 evt e3 mac 20120014 0800000000000000 port detached
# 	 evt mac channel group disabled administratively.
# 	 evt mac channel group enabled administratively.
# 	 plx port soft error2 count
# 	 chas cm pic port map info
# 	 chas tx disable called for port enable
# 	 evt port nif multicast storm detected.
# 	 evt port nif multicast storm recovered.
# 	 l2ald mac move notification moves
# 	 evt mac port to channel group.
# 	 evt mac channel group is up.
# 	 evt port nif broadcast storm detected.
# 	 evt port nif broadcast storm recovered.
# 	 evt e3 mac 20120010 0800000000000000 port detached
# 	 evt port disabled administratively.
# 	 evt nif board connected.
# 	 evt r6 nif initialized.
# 	 evt mac channel group is down all
# 	 evt mac port removed from channel group.
# 	 chassism ethswitch eth devstop called for port
#
# 19 : 0.094*"version" + 0.047*"cannot" + 0.038*"tnp.bootpd" + 0.038*"exit" + 0.036*"boot" + 0.036*"this" + 0.028*"bootpd" + 0.028*"built" + 0.027*"nh" + 0.018*"child"
# 	 tnp.bootpd bootpd bootstring boot string x
# 	 spd this pic will be reset on
# 	 version by builder on utc
# 	 cannot locate jspec model for v2.2 using
# 	 kernel pmap helper loaded interface version syscall
# 	 nh id child does not exist
# 	 rpd cannot perform nh operation addandget nhop
# 	 version by builder on utc
# 	 cannot locate jspec model for sg using
# 	 spd this pic will be reset on
# 	 rsp this list cannot be set to
# 	 rpd cannot perform nh operation addandget nhop
# 	 tnp.bootpd bootpd version release built
# 	 tnp.bootpd bootpd bootstring boot string
# 	 rpd cannot perform nh operation addandget nhop
# 	 vccpd task exit version built
# 	 sfid task exit version built
#
# 20 : 0.182*"chassisd" + 0.081*"trap" + 0.053*"snmp" + 0.037*"ifdev" + 0.029*"and" + 0.029*"cm" + 0.023*"detach" + 0.018*"other" + 0.017*"initialized" + 0.016*"setting"
# 	 chassisd fru offline notice taking fpc
# 	 chassisd snmp trap7 trap generated
# 	 chassisd fru offline notice taking fpc
# 	 chassisd snmp trap7 trap generated
# 	 chassisd snmp trap10 trap generated
# 	 chassisd snmp trap10 trap generated
# 	 l2cp initialized 802.1x module and state machines
# 	 mib2d snmp trap link down ifindex ifadminstatus
# 	 mib2d snmp trap link up ifindex ifadminstatus
# 	 chassisd ipc connection dropped
# 	 chassisd snmp trap10 trap generated
# 	 forwarding layer initialized
# 	 cmt chassis has slots
# 	 chassisd snmp trap10 trap generated
# 	 cmx chassis has slots
# 	 chassisd snmp trap7 trap generated
# 	 receive cm setting with value
# 	 chassisd snmp trap10 trap generated
# 	 chassisd snmp trap10 trap generated
# 	 chassisd snmp trap7 trap generated
# 	 chassisd snmp trap7 trap generated
# 	 chassisd snmp trap10 trap generated
# 	 chassisd cm java chassis inet6 linklocal maca5
# 	 chassisd snmp trap7 trap generated
# 	 chassisd re console me storm
# 	 chassism mvlan change me mac addr setting
# 	 snmpd trap queued adding to
# 	 snmpd trap queue drained dq
# 	 chassisd blowers speed medium fans and
# 	 chassisd blowers speed fans and impellers
# 	 chassisd parse complete using new configuration
# 	 chassisd snmp trap10 trap generated
# 	 chassisd no response from the other routing
# 	 chassisd snmp trap7 trap generated
# 	 forwarding layer initialized
# 	 cmt chassis has slots
# 	 chassisd snmp trap7 trap generated
# 	 chassisd snmp trap10 trap generated
# 	 chassisd ifdev create notice pics
# 	 chassisd ifdev detach fpc
# 	 chassisd ifdev detach all pseudo
# 	 cospic mt init cosfpc vectors initialized
# 	 kernel asp peer initoverriding peertype module
# 	 chassisd ifdev create notice pseudos
# 	 chassisd snmp trap6 trap generated
# 	 chassisd snmp trap6 trap generated
# 	 l2cp initialized 802.1x module and state machines
# 	 chassisd snmp trap7 trap generated
# 	 chassisd snmp trap7 trap generated
# 	 chassisd ifdev detach pic
# 	 chassisd snmp trap10 trap generated
# 	 chassisd snmp trap10 trap generated
# 	 chassisd pic reset on switchover
# 	 mib2d snmp trap link down ifindex ifadminstatus
# 	 mib2d snmp trap link up ifindex ifadminstatus
# 	 snmpd trap queue drained dq
#
# 21 : 0.128*"pfe" + 0.060*"complete" + 0.059*"detected" + 0.058*"cmtfpc" + 0.043*"cmt" + 0.043*"asic" + 0.028*"type" + 0.026*"initialization" + 0.017*"cms" + 0.017*"wedge"
# 	 host loopbackhost loopback wedge detected in pfe
# 	 host loopbackclearing loopback wedge on pfe
# 	 cmtfpc max6657 init ok
# 	 cmtfpc restart normal connected to pfe man
# 	 cmtfpc create asic pio handles entered hostname
# 	 cmt cmtfpc asic init pfe mah
# 	 cmt pfe asic initialization complete
# 	 cms pfe asic initialization complete
# 	 cmtfpc last plane disable request processing pfe
# 	 cmt bypass asic attach to logic pic
# 	 cmt pfe asic initialization complete
# 	 cmtfpc max6657 init ok
# 	 cmtfpc restart normal connected to pfe man
# 	 cmtfpc create asic pio handles entered hostname
# 	 cmt cmtfpc asic init pfe mah
# 	 cmsfpc restart normal connected to pfe man
# 	 kernel dad complete duplicate found manual intervention
# 	 kernel pfe send failedindex type err
#
# 22 : 0.124*"access" + 0.068*"incorrect" + 0.057*"show" + 0.053*"hostif" + 0.048*"stream" + 0.020*"#" + 0.019*"buffer" + 0.019*"head" + 0.019*"logout" + 0.019*"."
# 	 evt access login incorrect show log.
# 	 registering mq hostif client
# 	 hostif show stream config id op
# 	 hostif show stream config head buffer id
# 	 hostif show stream config head buffer status
# 	 setting wo stream id update credit to
# 	 evt access login incorrect show run#
# 	 registering mq hostif client
# 	 hostif show stream config id op
# 	 hostif show stream config head buffer id
# 	 hostif show stream config head buffer status
# 	 setting wo stream id update credit to
# 	 evt access login incorrect ##
# 	 evt access logout from .
# 	 evt access login incorrect #
# 	 evt access login incorrect
# 	 evt access login incorrect esc
#
# 23 : 0.095*"ns" + 0.069*"pfed" + 0.057*"libjsnmp" + 0.042*"log" + 0.041*"ipc" + 0.036*"dcd" + 0.031*"rows" + 0.031*"reg" + 0.026*"warning" + 0.025*"auth"
# 	 pfed ifl getnext failed invalid argument
# 	 dcd warning aggregatedetheroptions linkspeed no kernel value!
# 	 dcd aggregatedetheroptions linkspeed set to kernel value
# 	 dcd config write failed interface configuration
# 	 pfed libjsnmp sa ipc reg rows ns
# 	 pfed libjsnmp ns log info
# 	 mib2d rtslib read failure check rtsock
# 	 mib2d libjsnmp sa ipc reg rows ns
# 	 mib2d libjsnmp ns log info
# 	 pfed rtslib sequence gap
# 	 pfed rtsock init completed.
# 	 pfed rtsock recovery completed.
# 	 pfed rtslib error idl idr decode
# 	 bfdd libjsnmp sa ipc reg rows ns
# 	 bfdd libjsnmp ns log info
# 	 idpd libjsnmp sa ipc reg rows ns
# 	 idpd license conn to li check success
# 	 idpd libjsnmp ns log info
# 	 kmd libjsnmp sa ipc reg rows ns
# 	 kmd libjsnmp ns log info
# 	 pfed libjsnmp ns log warning
# 	 appidd ai cache corruption check and recovery
# 	 craftd libjsnmp sa ipc reg rows ns
# 	 dcd warning aggregatedetheroptions linkspeed no kernel value!
# 	 kernel dad detected duplicate ipv6 address ns
# 	 dcd aggregatedetheroptions linkspeed set to kernel value
# 	 dcd warning identical local address is found
# 	 dcd parse warn incompatible cfg edit
# 	 snmpd auth failure nsa log community
# 	 pfed device getnext failed invalid argument
#
# 24 : 0.245*"task" + 0.107*"reinitializing" + 0.063*"reinit" + 0.050*"reconfigure" + 0.050*"done" + 0.038*"l2cp" + 0.025*"eswd" + 0.014*"machines" + 0.013*"lldp" + 0.013*"lldpd"
# 	 mcsn rpd task reinit reinitializing
# 	 mcsn task reconfigure reinitializing done
# 	 lldp task reinit reinitializing
# 	 lldp task reconfigure reinitializing done
# 	 l2cp initializing pnac state machines
# 	 l2cp initializing pnac state machines complete
# 	 l2cp l2cpd task reinit reinitialized
# 	 l2cp task reconfigure reinitializing done
# 	 mcsn task reinit reinitializing
# 	 mcsn task reconfigure reinitializing done
# 	 cfmd task reconfigure reinitializing done
# 	 mcsn task reinit reinitializing
# 	 eswd task reconfigure reinitializing done
# 	 cfmd task reinit reinitializing
# 	 eswd task reinit reinitializing
# 	 rpd task accounting
# 	 chas task sched slip sec scheduler
# 	 lldpd task reconfigure reinitializing done
# 	 mcsnoopd task reinit reinitializing
# 	 mcsnoopd task reconfigure reinitializing done
# 	 lldpd task reinit reinitializing
# 	 rpd task reinit reinitializing
# 	 rpd task reconfigure reinitializing done
# 	 rpd task state reconfig foreground parseconfig
# 	 rpd task connect + addr
# 	 mcsn task reinit reinitializing
# 	 rpd task state reconfig foreground parseconfig
# 	 l2cp initializing pnac state machines
# 	 l2cp initializing pnac state machines complete
# 	 rpd task reinit reinitializing
# 	 rpd task reconfigure reinitializing done
# 	 eswd stp state change info
# 	 l2cp l2cpd task reinit reinitialized
# 	 l2cp task reconfigure reinitializing done
#
# 25 : 0.181*"init" + 0.098*"signal" + 0.094*"pid" + 0.067*"terminate" + 0.059*"sent" + 0.051*"bulkget" + 0.024*"manager" + 0.018*"due" + 0.018*"sending" + 0.016*"watchdog"
# 	 starting luchip memory interface init
# 	 jnh init 4way mem pools no replicated
# 	 bulkget manager init ...
# 	 bulkget manager thread creating...
# 	 bulkget connecting to serverrouter
# 	 bulkget connected to serverrouter
# 	 chas task signal terminate termination no
# 	 sfid task signal terminate termination no
# 	 vccp task signal terminate termination no
# 	 bulkget disconnected socket closed abruptly
# 	 init pid started
# 	 bulkget reconnecting to serverrouter
# 	 init pid terminated by signal number
# 	 jnh init 4way mem pools no replicated
# 	 bulkget manager init ...
# 	 bulkget manager thread creating...
# 	 bulkget connecting to serverrouter
# 	 bulkget connected to serverrouter
# 	 smartd starting pid
# 	 init starting of initial processes complete
# 	 init pid terminate signal sent
# 	 init pid sending signal hup due to
# 	 starting luchip memory interface init
# 	 kernel init pid terminate signal sent
# 	 kernel init pid started
# 	 kernel init sntpsync pid sigterm sent
# 	 kernel init pid sending signal hup due
# 	 kernel init lacp pid sending signal usr1
# 	 kernel init pid terminated by signal number
# 	 cmg bouncing pic due to errors.
# 	 init tnpprocess pid terminate signal sent
# 	 init management pid terminate signal sent
# 	 init inetprocess pid terminate signal sent
# 	 init pid terminate signal sent
# 	 init chassismanager pid terminate signal sent
# 	 init softwareforwarding pid terminate signal sent
# 	 init virtualchassiscontrol pid terminate signal sent
# 	 sfid task signal terminate termination no
# 	 vccpd task signal terminate termination no
# 	 init packetforwardingengine pid terminate signal sent
# 	 init watchdog pid terminate signal sent
# 	 init chassiscontrol pid terminate signal sent
#
# 26 : 0.128*"mpls" + 0.087*"change" + 0.086*"lsp" + 0.041*"path" + 0.041*"kern" + 0.030*"arp" + 0.018*"ip" + 0.011*"profiles" + 0.011*"are" + 0.011*"dynamicprofiles"
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 kernel kern arp addr change nd6 info
# 	 rpd mpls path down
# 	 rpd mpls lsp down
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp switch
# 	 rpd mpls path up
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp change
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 ffp dynamicprofiles profiles are being modified
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 chassisd use of mpc3d16xgesfpp in ip services
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp down
# 	 rpd mpls lsp up
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp change
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp switch
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp change
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 rpd mpls lsp up
# 	 kernel kern arp addr change info overwritten
# 	 kernel kern arp duplicate addr ip
# 	 rpd mpls lsp change
#
# 27 : 0.199*"error" + 0.135*"login" + 0.119*"failed" + 0.094*"pci" + 0.040*"id" + 0.030*"password" + 0.020*"pam" + 0.015*"authentication" + 0.010*"cap" + 0.010*"source"
# 	 login pam authentication error
# 	 login failed limit specified number of
# 	 login pam error failure while authenticating
# 	 login on
# 	 login failed for user
# 	 login failure on exit
# 	 login failed limit specified number of
# 	 error vrf in egress acl
# 	 login pam authentication error failed password
# 	 login failed for user
# 	 login aborted client
# 	 login pam authentication error
# 	 login failed for user
# 	 login failed limit specified number of
# 	 login aborted client
# 	 kernel peer inputs soreceive error
# 	 login pam authentication error
# 	 login failed for user
# 	 login failed limit specified number of
# 	 kernel peer inputs soreceive error
# 	 pci error timestamp
# 	 pci error err dr
# 	 pci error err cap stat
# 	 pci error err cap0
# 	 pci error status
# 	 pci error status
# 	 pci error link status
# 	 pci error uncorrectable status
# 	 pci error advanced cap & ctl
# 	 pci error header log
# 	 pci error root status
# 	 pci error source id
#
# 28 : 0.310*"mcsn" + 0.113*"stp" + 0.043*"tcgeneration" + 0.034*"bandwidth" + 0.019*"updown" + 0.009*"chg" + 0.007*"opdelete" + 0.007*"opadd" + 0.007*"encapsulation" + 0.007*"opchange"
# 	 rpd stp handler index opdelete state tcgeneration
# 	 rpd stp handler index opchange state tcgeneration
# 	 rpd stp chg
# 	 mcsn stp handler index op state tcgeneration
# 	 mcsn stp
# 	 mcsn krt decode iflogical associated with l2
# 	 mcsn snp stp add ifbd adding bdid
# 	 rpd stp handler index opadd state tcgeneration
#
# 29 : 0.069*"at" + 0.067*"inetd" + 0.058*"device" + 0.047*"number" + 0.040*"mq" + 0.037*"max" + 0.020*"ddr3" + 0.020*"passed" + 0.020*"verify" + 0.020*"retry"
# 	 mq ddr3 ddrio verify passed at retry
# 	 v queue createqsize max buckets default
# 	 luchip ddr3 verify passed at retry
# 	 mq ddr3 ddrio verify passed at retry
# 	 kernel pcf8584wr group device
# 	 chas errno device
# 	 inetd number of telnet connections at max
# 	 inetd number of ssh connections at max
# 	 v queue createqsize max buckets default
# 	 luchip ddr3 verify passed at retry
# 	 kernel sglinkrd gbus error at device address
# 	 kernel sglinkrd sgls error at device illegal
# 	 inetd accept for software caused connection abort
#
# 30 : 0.125*"connection" + 0.094*"re" + 0.094*"as" + 0.041*"src" + 0.034*"pp" + 0.029*"closed" + 0.029*"established" + 0.020*"made" + 0.019*"l2alm" + 0.015*"ppman"
# 	 rpd bgp pp recv dropping as connection
# 	 kernel rdp keepalive expired connection dropped src
# 	 clksync established connection to master
# 	 clksync master re connection made
# 	 l2alm established connection to master
# 	 l2alm master re connection made
# 	 ppman established connection to ppmd
# 	 kernel pfe listener disconnect conn dropped
# 	 xntpd connection reestablished to
# 	 bulkget master re reconnection made
# 	 kernel pfe listener disconnect conn dropped
# 	 rpd bgp pp recv dropping as connection
# 	 kernel pic listener connect conn established mgmt
# 	 rpd as reseting pending active connection
# 	 rpd as reseting pending active connection
# 	 ppman disconnected; remote side closed
# 	 ppman established connection to ppmd
# 	 clksync established connection to master
# 	 clksync master re connection made
# 	 l2alm established connection to master
# 	 l2alm master re connection made
# 	 sp71 watchdog expired
#
# 31 : 0.076*"entry" + 0.053*"lu" + 0.053*"create" + 0.053*"mqchip" + 0.045*"addr" + 0.043*"queue" + 0.032*"last" + 0.032*"packet" + 0.027*"seg" + 0.027*"dest"
# 	 block addr
# 	 lu errors lmem addr error
# 	 mqchip fi reorder cell timeout
# 	 fpc1 mqchip fi reorder cell timeout
# 	 fpc11 mqchip fi reorder cell timeout
# 	 v queue create allocate vq size
# 	 v queue create allocate vq tb list
# 	 v queue create allocate vq entry pool
# 	 lu #; dest seg entry
# 	 lu #gumementries; dest seg entry
# 	 lu #kmaentries; dest seg entry
# 	 lu #kmbentries; dest seg entry
# 	 lu #cboentries; dest seg entry
# 	 block addr
# 	 mqchip fi reorder cell timeout
# 	 snmpd throttle queue drained trap
# 	 mqchip xe throttle last seconds have seen
# 	 mqchip li packet length error pt entry
# 	 v queue create allocate vq size
# 	 v queue create allocate vq tb list
# 	 v queue create allocate vq entry pool
# 	 lu #; dest seg entry
# 	 sm samples dropped due to high packet
# 	 snmpd throttle queue drained trap
#
# 32 : 0.092*"master" + 0.064*"ok" + 0.064*"op" + 0.040*"cosd" + 0.037*"tcp" + 0.035*"socket" + 0.033*"gencfg" + 0.029*"ae" + 0.027*"unsupported" + 0.027*"pre"
# 	 coscos classifier pre unbind action cos ifl
# 	 kernel gencfg op cos failed; err unknown
# 	 kernel tcp auth ok packet from wrong
# 	 kernel tcp auth ok packet from unexpectedly
# 	 cmtfpc max6697 init ok
# 	 svc thread create tcp socket
# 	 coscos classifier pre unbind action cos ifl
# 	 chas cm mpfe intr task pre terminate
# 	 bulkget master socket closed
# 	 kernel tcp auth ok packet from md5
# 	 kernel gencfg op cos failed; err invalid
# 	 cosd gencfg classifier def clk type
# 	 cosd gencfg write failed
# 	 cmtfpc max6697 init ok
# 	 svc thread create tcp socket
# 	 kernel rts rtcb op ok master perms
# 	 kernel mastership routing engine becoming master
# 	 kernel mastership routing engine became master
# 	 kernel tcp auth ok packet from missing
# 	 rpd received mc ae options tlv for
# 	 cosd gencfg write failed
# 	 mcsn received mc ae options tlv for
# 	 cosd class 8021p unsupported ieee802.1 classifier
# 	 rpd received mc ae options tlv for
# 	 chassism cm mpfe intr task pre terminate
#
# 33 : 0.174*"pic" + 0.148*"slot" + 0.048*"message" + 0.047*"the" + 0.045*"active" + 0.042*"fpc" + 0.041*"with" + 0.029*"request" + 0.022*"cos" + 0.018*"online"
# 	 message repeated times
# 	 fpc slot pic received cos message
# 	 pic init startup the manager fpc
# 	 pic init chassisid fpc maxfpc
# 	 pic system init total slot
# 	 pic system init will call periodic
# 	 pic system init sys ready
# 	 pfeman session manager active
# 	 sntpd initial time of day set.
# 	 cmtfpc npc online vector estd peering with
# 	 cmsfpc sfpc online vector estd peering with
# 	 slot pic sampledc initiating route record
# 	 chas cmtsunami pic online request
# 	 chas cmfpc advertise pic sent
# 	 slot pic idx af
# 	 slot pic ifl family
# 	 slot pic received cos message with
# 	 cmtfpc npc online vector estd peering with
# 	 syslog messages lost message queue overflowed.
# 	 slot pic syslog messages lost message
# 	 last message repeated times
# 	 pic init startup the manager fpc
# 	 pic init chassisid fpc maxfpc
# 	 pic system init total slot
# 	 pic system init will call periodic
# 	 pic system init sys ready
# 	 pfeman session manager active
# 	 sntpd initial time of day set.
# 	 cms pic offline fpc slot
# 	 slot pic version by builder on
# 	 slot pic monitor as reverse lookup
# 	 slot pic monitor label to fec
# 	 slot pic pfeman server addr soft
# 	 slot pic pfeman session manager active
# 	 slot pic system init total
# 	 slot pic system init will
# 	 slot pic system init
# 	 slot pic sntpd initial time of
# 	 slot pic pfeman sent resync request
# 	 slot pic pfeman got the resync
# 	 slot pic online and initial
# 	 last message repeated times
#
# 34 : 0.275*"evt" + 0.069*"system" + 0.032*"csu" + 0.030*"software" + 0.028*"many" + 0.026*"administratively." + 0.019*"fan" + 0.019*"enabled" + 0.016*"fpga" + 0.016*"standby"
# 	 evt access login refused for too many
# 	 evt port enabled administratively.
# 	 evt port enabled administratively.
# 	 evt software ntp lost synchronization with
# 	 evt software snmpd restarted.
# 	 evt software configuration was changed by netconf.
# 	 sshd disconnecting too many password failures for
# 	 evt r8 ps is normal.
# 	 evt software received many packets and loaded
# 	 evt software processed the packets in
# 	 evt port many failures occurred in receiving
# 	 clksyncd system has older acbc fpga image.
# 	 evt csu psp on other system changed
# 	 evt csu this system changed from standby
# 	 evt csu standby system activated administratively.
# 	 evt csu system status changed from simplex
# 	 evt r8 fan is normal.
# 	 evt port many failures occurred in sending
# 	 evt port auto negotiation failed.
# 	 evt port transceiver notconnected.
# 	 evt port transceiver connected.
# 	 err csu fatal error detected on other
# 	 evt csu other system recovered from fatal
#
# 35 : 0.218*"on" + 0.055*"destination" + 0.055*"pfealiveness" + 0.055*"turning" + 0.043*"vccpd" + 0.036*"fpc1" + 0.032*"exit" + 0.027*"off" + 0.024*"su" + 0.007*"builder"
# 	 evt port error detected on the port.
# 	 xntpd listening on interface #
# 	 pfealiveness turning destination off
# 	 fpc11 pfealiveness turning destination off
# 	 fpc1 pfealiveness turning destination off
# 	 cmt no lu on skipping...
# 	 pfealiveness turning destination on
# 	 fpc1 pfealiveness turning destination on
# 	 fpc11 pfealiveness turning destination on
# 	 pfealiveness turning destination off
# 	 vccp vccpd rawsock send sendmsg on ifl
# 	 vccp task exit vccpd version 10.4r2.6
# 	 su bad to on
# 	 su to on
# 	 su bad to on
# 	 pfealiveness turning destination on
# 	 kernel unlist request unilistnh index found on
# 	 su to on
# 	 cmt no lu on skipping...
# 	 xntpd listening on interface #
#
# 36 : 0.110*"luchip" + 0.099*"snmpd" + 0.063*"send" + 0.058*"failure" + 0.058*"in" + 0.058*"sa" + 0.058*"mib2d" + 0.032*"libjsnmp" + 0.026*"count" + 0.026*"partial"
# 	 snmpd send failure jnx netsnmp udp
# 	 snmpd send failure jnx netsnmp udp
# 	 snmpd send failure trap io
# 	 mib2d libjsnmp sa partial send frag attempted
# 	 mib2d libjsnmp sa partial send rem queuing
# 	 mib2d libjsnmp sa partial finish sms send
# 	 snmpd trap throttled queue send
# 	 plugged in
# 	 snmpd libjsnmp sa partial send frag attempted
# 	 snmpd libjsnmp sa partial send rem queuing
# 	 snmpd bind info source address for
# 	 snmpd send failure trap io
# 	 luchip idmem read error.
# 	 kernel pid corrected slot count 2
# 	 luchip idmem parity error in bank count
#
# 37 : 0.104*"xntpd" + 0.065*"time" + 0.052*"reset" + 0.046*"+" + 0.028*"recv" + 0.026*"server" + 0.026*"ntpd" + 0.026*"reason" + 0.026*"mpc" + 0.024*"proto"
# 	 xntpd kernel time sync disabled
# 	 mpc reset reason re initiated power on
# 	 xntpd mlockall resource temporarily unavailable
# 	 xntpd ntpd exiting on signal
# 	 xntpd ntpd 4.2.0a
# 	 xntpd precision usec
# 	 xntpd kernel time sync status
# 	 xntpd frequency initialized ppm from
# 	 xntpd kernel time sync disabled
# 	 xntpd kernel time sync enabled
# 	 mpc reset reason no reason?
# 	 mpc reset reason power on
# 	 pfed device getnext failed resource temporarily unavailable
# 	 mpc reason level3 watchdog level2
# 	 xntpd ntpd changed time reset +
# 	 xntpd kernel time sync enabled
# 	 xntpd ntpd exiting on signal
# 	 ntpdate time changed step offset
# 	 telnetd ttloop peer died resource temporarily unavailable
# 	 xntpd kernel time sync enabled
# 	 xntpd time reset + s
# 	 xntpd ntp server unreachable
# 	 ksyncd select control plane proto rhost
# 	 mpc reset reason power on
# 	 xntpd ntpd exiting on signal
# 	 xntpd ntpd
# 	 xntpd precision usec
# 	 xntpd kernel time sync status
# 	 xntpd frequency initialized ppm from
# 	 xntpd no servers reachable
# 	 xntpd ntp server unreachable
# 	 xntpd ntpd changed time reset +
# 	 xntpd time reset + s
# 	 xntpd kernel time sync disabled
# 	 xntpd kernel time sync enabled
# 	 xntpd ntp server unreachable
#
# 38 : 0.165*"index" + 0.141*"event" + 0.141*"broadcast" + 0.093*"multicast" + 0.059*"up" + 0.044*"mtu" + 0.038*"chas" + 0.038*"updown" + 0.034*"no" + 0.033*"add"
# 	 rpd event delete updown index broadcast multicast
# 	 rpd event flags index up broadcast multicast
# 	 rpd event snmp index up broadcast
# 	 rpd event updown index broadcast multicast
# 	 rpd event mtu index broadcast multicast
# 	 rpd event delete index broadcast multicast
# 	 rpd event add index up broadcast pointtopoint
# 	 rpd event snmp index up broadcast
# 	 rpd event flags index up broadcast pointtopoint
# 	 rpd event add index up broadcast pointtopoint
# 	 rpd event add index up broadcast pointtopoint
# 	 rpd event bandwidth index broadcast multicast address
# 	 mcsn event bandwidth index broadcast multicast address
# 	 rpd event bandwidth index broadcast multicast address
# 	 rpd event flags index up broadcast multicast
# 	 rpd event delete index broadcast multicast
# 	 mcsn event delete index broadcast multicast address
# 	 rpd event delete index broadcast multicast address
# 	 rpd event delete index broadcast multicast address
# 	 rpd event delete index broadcast multicast
# 	 rpd event delete index broadcast multicast
# 	 rpd event delete index broadcast multicast address
# 	 rpd event updown index broadcast multicast address
# 	 rpd event updown index broadcast multicast address
# 	 rpd event updown index broadcast multicast localup
# 	 rpd event updown index broadcast multicast localup
# 	 rpd event updown index broadcast multicast address
# 	 rpd event updown index broadcast multicast localup
# 	 mcsn event updown index broadcast multicast address
# 	 rpd event updown index broadcast pointtopoint multicast
# 	 rpd event delete index broadcast pointtopoint multicast
# 	 rpd event delete index broadcast pointtopoint multicast
# 	 rpd1866 event snmp index broadcast pointtopoint
# 	 rpd event add index broadcast pointtopoint multicast
# 	 rpd event updown index up broadcast pointtopoint
# 	 rpd event updown index broadcast multicast address
# 	 rpd stp handler index op state tcgeneration
# 	 rpd event updown index broadcast pointtopoint multicast
# 	 rpd event updown index broadcast pointtopoint multicast
# 	 mcsn event updown mtu index broadcast multicast
# 	 rpd event flags index broadcast pointtopoint multicast
# 	 rpd event delete index broadcast pointtopoint multicast
# 	 rpd event delete updown index broadcast pointtopoint
# 	 rpd event delete updown index broadcast pointtopoint
# 	 chas ifcm no handler for command subtype
# 	 rpd event updown index up broadcast multicast
# 	 rpd event updown index up broadcast multicast
# 	 rpd event updown index up broadcast multicast
# 	 rpd event updown index up broadcast multicast
# 	 mcsn event updown index up broadcast multicast
# 	 rpd event updown index up broadcast multicast
# 	 rpd event add index up broadcast loopback
# 	 rpd event instance index up broadcast loopback
# 	 rpd event mtu index up broadcast loopback
# 	 rpd event snmp index up broadcast
# 	 rpd event updown index up broadcast multicast
# 	 rpd event instance index up broadcast multicast
# 	 rpd event updown index up broadcast multicast
# 	 rpd event add index up broadcast pointtopoint
# 	 rpd event instance index up broadcast pointtopoint
# 	 rpd event mtu index up broadcast pointtopoint
# 	 rpd event flags index up broadcast pointtopoint
# 	 rpd event add index up broadcast pointtopoint
# 	 rpd event snmp index up broadcast
# 	 rpd event mtu index up broadcast pointtopoint
# 	 rpd event add index broadcast multicast address
# 	 rpd event snmp index broadcast multicast
# 	 rpd event instance index broadcast multicast address
# 	 rpd event mtu index broadcast multicast address
# 	 rpd event flags index broadcast multicast address
# 	 rpd event add index broadcast multicast
# 	 rpd event flags index broadcast multicast
# 	 rpd event bandwidth index up broadcast multicast
# 	 rpd event bandwidth index up broadcast multicast
# 	 mcsn event bandwidth index up broadcast multicast
# 	 rpd event bandwidth index up broadcast multicast
# 	 rpd event bandwidth index up broadcast multicast
# 	 mcsn event bandwidth updown index broadcast multicast
# 	 rpd event bandwidth index broadcast multicast address
# 	 rpd event bandwidth updown index broadcast multicast
# 	 rpd event bandwidth index broadcast multicast address
# 	 rpd event bandwidth updown index up broadcast
# 	 mcsn event bandwidth updown index up broadcast
# 	 rpd event bandwidth updown index up broadcast
# 	 rpd event flags index up broadcast multicast
# 	 rpd event updown index broadcast pointtopoint multicast
# 	 rpd event updown index broadcast pointtopoint multicast
# 	 rpd event updown index up broadcast pointtopoint
# 	 rpd event updown index up broadcast pointtopoint
# 	 mcsn event add bandwidth index up broadcast
# 	 rpd event add bandwidth index up broadcast
# 	 rpd event add bandwidth mtu encapsulation index
# 	 mcsn event add bandwidth mtu encapsulation index
# 	 mcsn event mtu index broadcast multicast
# 	 rpd event mtu index broadcast multicast
# 	 mcsn event add bandwidth mtu encapsulation index
# 	 rpd event add bandwidth mtu encapsulation index
# 	 rpd event add bandwidth mtu index broadcast
# 	 mcsn event add bandwidth mtu index broadcast
# 	 mcsn event mtu index broadcast multicast address
# 	 rpd event mtu index broadcast multicast address
# 	 rpd event add bandwidth index up broadcast
# 	 rpd event add index up broadcast multicast
# 	 rpd event add bandwidth mtu encapsulation index
# 	 rpd event add bandwidth mtu encapsulation index
# 	 rpd event add bandwidth mtu index broadcast
# 	 rpd event updown mtu index up broadcast
# 	 mcsn event updown mtu index up broadcast
# 	 mcsn event updown mtu index up broadcast
# 	 rpd event updown mtu index up broadcast
# 	 rpd event add index broadcast multicast
# 	 rpd event add index broadcast multicast address
# 	 rpd event mtu index broadcast multicast address
# 	 rpd event flags index broadcast multicast address
# 	 rpd event add index broadcast multicast
# 	 rpd event snmp index up broadcast
# 	 rpd event snmp index broadcast multicast
# 	 rpd event mtu index broadcast multicast address
# 	 rpd event snmp index up broadcast
# 	 rpd event mtu index up broadcast multicast
# 	 mcsn event mtu index up broadcast multicast
# 	 rpd event mtu index up broadcast multicast
# 	 mcsn event mtu index up broadcast multicast
# 	 rpd event mtu index up broadcast multicast
# 	 rpd event mtu index up broadcast multicast
# 	 rpd event add mtu encapsulation index broadcast
# 	 mcsn event add mtu encapsulation index broadcast
# 	 rpd event add mtu encapsulation index broadcast
# 	 rpd event address index broadcast multicast
# 	 rpd event add index up broadcast multicast
# 	 rpd event instance index up broadcast multicast
# 	 rpd event mtu index up broadcast multicast
# 	 rpd event add index up broadcast multicast
# 	 rpd event delete index broadcast multicast address
# 	 rpd event delete updown index broadcast multicast
# 	 rpd event delete updown index broadcast multicast
# 	 rpd event updown index broadcast multicast
# 	 rpd event updown index broadcast multicast
# 	 mcsn event updown index broadcast multicast
# 	 rpd event updown index up broadcast multicast
# 	 mcsn event updown index up broadcast multicast
# 	 rpd event updown index up broadcast multicast
# 	 mcsn event delete index broadcast multicast
# 	 rpd event delete index broadcast multicast
# 	 rpd event updown mtu index broadcast multicast
# 	 mcsn event updown mtu index broadcast multicast
# 	 rpd event delete index broadcast multicast
# 	 rpd event updown mtu index broadcast multicast
# 	 rpd event updown index broadcast pointtopoint multicast
# 	 rpd event flags index broadcast pointtopoint multicast
# 	 rpd event delete index broadcast pointtopoint multicast
# 	 rpd event mtu index broadcast multicast
# 	 rpd event add index broadcast pointtopoint multicast
# 	 rpd event instance index broadcast pointtopoint multicast
# 	 rpd event mtu index broadcast pointtopoint multicast
# 	 rpd event delete updown index broadcast pointtopoint
# 	 rpd1896 event delete updown index broadcast pointtopoint
# 	 rpd event delete updown index broadcast pointtopoint
# 	 rpd event mtu index up broadcast loopback
# 	 mcsn event mtu index up broadcast loopback
# 	 rpd event mtu index up broadcast loopback
# 	 rpd event delete updown index broadcast multicast
# 	 rpd event delete updown index broadcast multicast
# 	 rpd event add index up broadcast multicast
# 	 rpd event mtu index up broadcast multicast
# 	 rpd event flags index up broadcast multicast
# 	 rpd event add index up broadcast multicast
# 	 rpd event add index up broadcast multicast
#
# 39 : 0.110*"not" + 0.095*"interface" + 0.093*"of" + 0.088*"rsp" + 0.072*"delete" + 0.022*"can" + 0.020*"receive" + 0.017*"jl2tpd" + 0.016*"mode" + 0.016*"cant"
# 	 rsp interface cant set switchport trunk allowed
# 	 rsp ipv6 can not delete it because
# 	 rsp enable sorry
# 	 rsp interface cannot change vlan configuration referred
# 	 rsp interface this command is different from
# 	 rsp username can not delete it because
# 	 rsp the command execution failed because another
# 	 rsp interface the different kind of mode
# 	 rsp interface can not delete of
# 	 icmp init of periff rate to
# 	 rsp vlan cant delete configuration referred
# 	 rsp interface invalid line type.
# 	 init can not access no such file
# 	 jl2tpd main * not running
# 	 rsp cant execute.
# 	 kernel promiscuous mode
# 	 icmp init of periff rate to
# 	 sshd did not receive identification string from
# 	 rsp standby system is not inactive.
# 	 evt config the interface configuration commands of
# 	 rsp interface duplicate translatedtag.

# %%
for i,j in word_dict.items():
    
    if i not in word_cnt:
        cnt = "not shown"
    else:
        cnt = word_cnt[i] 
        
    print(i, cnt, lda.get_term_topics(j))

# %%
a = lda.get_document_topics(corpus, per_word_topics=True)
for i,j in zip(a, corpus_lt):
    print(j)
    print(i[0])
    for k in i[2]:
        print(inv_word_dict[k[0]], "\t", k[1])
    print()

# %%
inf_ltids = {}
for i, inf_cat in enumerate(results):
    if inf_cat in inf_ltids:
        inf_ltids[inf_cat].append(i)
    else:
        inf_ltids[inf_cat] = [i]

# %%
for inf_cat, ltids in inf_ltids.items():
    print("topic:", inf_cat)
    for i in ltids:
        print([inv_word_dict[c[0]] for c in corpus[i]])
    print()

# %%
lda.show_topics(num_topics=64, num_words=20)

# %%
compared_results = {}
for inf_cat, ltids in inf_ltids.items():
    for ltid in ltids:
        true_cat = raw_lt[str(ltid)]['cat']
        if true_cat in compared_results:
            compared_results[true_cat].append((ltid, inf_cat))
        else:
            compared_results[true_cat] = [(ltid, inf_cat)]

# %%
for cat, res in compared_results.items():
    plt.figure(figsize=(12,5))
    plt.title(cat)
    y = collections.Counter([r[1] for r in res])
    y = [y[i] if i in y else 0 for i in range(30)]
#     print(collections.Counter([r[1] for r in res]), y)
    plt.bar(np.arange(30), y)
    plt.show()

# %% [markdown]
# ### all split

# %%
all_corpus

# %%
all_words = list(set([word for cat, words in all_corpus.items() for word in words]))
word_dict = {w:i for i, w in enumerate(all_words)}
inv_word_dict = {v:k for k,v in word_dict.items()}

corpus = []
for cat, lts in lt_per_cat.items():
    for lt in lts:
        words = [remove_symbols(t) for t in lt.split()]
        split_words = []
        for w in words:
            if len(w.split()) > 1: # さらに分割できる場合
                split_words.extend(w.split())
            else:
                split_words.append(w)
        split_words = [t.lower() for t in split_words if t != '']
        
        split_words = split_words[:7]
        split_words = [t for t in split_words if t != 'ui']
        
        lt_word_id_cnt = collections.Counter([word_dict[w] for w in split_words])
        
        corpus.append([(tid, cnt) for tid, cnt in lt_word_id_cnt.items()])

# %%
lda = gensim.models.ldamodel.LdaModel(corpus=corpus, num_topics=30, id2word=inv_word_dict)

# %%
results =  [np.argmax(l) for l in lda.inference(corpus)[0]]
results = {ltid:r for ltid, r in enumerate(results)}

# %%
inf_ltids = {}
for ltid, inf_cat in results.items():
    if inf_cat in inf_ltids:
        inf_ltids[inf_cat].append(ltid)
    else:
        inf_ltids[inf_cat] = [ltid]

# %%
for inf_cat, ltids in inf_ltids.items():
    print("topic:", inf_cat)
    for i in ltids:
        print(len(ltids))
        break
#         print(raw_lt[str(i)]['lt'])
    print()

# %%
for inf_cat, ltids in inf_ltids.items():
    print("topic:", inf_cat)
    for i in ltids:
        print(raw_lt[str(i)]['lt'])
    print()

# %%
lda.show_topics(num_topics=30)

# %%
inf_ltids = {}
for ltid, inf_cat in results.items():
    if inf_cat in inf_ltids:
        inf_ltids[inf_cat].append(ltid)
    else:
        inf_ltids[inf_cat] = [ltid]

# %%
compared_results_3 = {}
for inf_cat, ltids in inf_ltids.items():
    for ltid in ltids:
        true_cat = raw_lt[str(ltid)]['cat']
        if true_cat in compared_results_3:
            compared_results_3[true_cat].append((ltid, inf_cat))
        else:
            compared_results_3[true_cat] = [(ltid, inf_cat)]

# %%
vec_per_topic = dict()
for tpid, vecs in lda.show_topics(formatted=False):
    tp_vec = np.zeros(len(word_dict), dtype=float)
    for vec in vecs:
        v = np.zeros(len(word_dict), dtype=float)
        v[word_dict[vec[0]]] = 1
        tp_vec += v*vec[1]
    vec_per_topic[tpid] = tp_vec
    
for a, b in itertools.combinations(vec_per_topic.keys(), 2):
    print(a, b)
    print(np.dot(vec_per_topic[a], vec_per_topic[b]))

# %%
for (cat, res), (cat2, res2), (cat3, res3)  in zip(sorted(compared_results.items()), sorted(compared_results_2.items()), sorted(compared_results_3.items())):
    plt.figure(figsize=(15, 4))
    plt.subplot(131)
    plt.title(cat)
    y = collections.Counter([r[1] for r in res])
    y = [y[i] if i in y else 0 for i in range(10)]
    plt.bar(np.arange(10), y)
    plt.subplot(132)
    plt.title(cat2)
    y = collections.Counter([r[1] for r in res2])
    y = [y[i] if i in y else 0 for i in range(10)]
    plt.bar(np.arange(10), y)
    plt.subplot(133)
    plt.title(cat3)
    y = collections.Counter([r[1] for r in res3])
    y = [y[i] if i in y else 0 for i in range(10)]
    plt.bar(np.arange(10), y)
    
    plt.show()

# %% [markdown]
# ### split

# %%
all_words = list(set([word for cat, words in all_corpus.items() for word in words]))
word_dict = {w:i for i, w in enumerate(all_words)}
inv_word_dict = {v:k for k,v in word_dict.items()}

corpus = []
for cat, lts in lt_per_cat.items():
    for lt in lts:
        words = [remove_symbols(t) for t in lt.split()]
        split_words = []
        for w in words:
            if len(w.split()) > 1: # さらに分割できる場合
                split_words.extend(w.split())
            else:
                split_words.append(w)
        split_words = [t.lower() for t in split_words if t != '']
        
        split_words = split_words[:7]
        
        lt_word_id_cnt = collections.Counter([word_dict[w] for w in split_words])
        
        corpus.append([(tid, cnt) for tid, cnt in lt_word_id_cnt.items()])

# %%
# lda = gensim.models.ldamodel.LdaModel(corpus=corpus, num_topics=10, id2word=inv_word_dict)

# %%
results =  [np.argmax(l) for l in lda.inference(corpus)[0]]
results = {ltid:r for ltid, r in enumerate(results)}

# %%
inf_ltids = {}
for ltid, inf_cat in results.items():
    if inf_cat in inf_ltids:
        inf_ltids[inf_cat].append(ltid)
    else:
        inf_ltids[inf_cat] = [ltid]

# %%
for inf_cat, ltids in inf_ltids.items():
    print("topic:", inf_cat)
    for i in ltids:
        print(raw_lt[str(i)]['lt'])
    print()

# %%
inf_ltids = {}
for ltid, inf_cat in results.items():
    if inf_cat in inf_ltids:
        inf_ltids[inf_cat].append(ltid)
    else:
        inf_ltids[inf_cat] = [ltid]

# %%
compared_results_2 = {}
for inf_cat, ltids in inf_ltids.items():
    for ltid in ltids:
        true_cat = raw_lt[str(ltid)]['cat']
        if true_cat in compared_results_2:
            compared_results_2[true_cat].append((ltid, inf_cat))
        else:
            compared_results_2[true_cat] = [(ltid, inf_cat)]

# %%
for (cat, res), (cat2, res2) in zip(compared_results.items(), compared_results_2.items()):
    plt.figure(figsize=(10, 4))
    plt.subplot(121)
    plt.title(cat)
    y = collections.Counter([r[1] for r in res])
    y = [y[i] if i in y else 0 for i in range(10)]
    plt.bar(np.arange(10), y)
    plt.subplot(122)
    plt.title(cat2)
    y = collections.Counter([r[1] for r in res2])
    y = [y[i] if i in y else 0 for i in range(10)]
    plt.bar(np.arange(10), y)
    
    plt.show()
