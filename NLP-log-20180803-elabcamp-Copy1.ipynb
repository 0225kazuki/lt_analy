# %% [markdown]
# - elab camp 用

# %%
import numpy as np
import pandas as pd
import json
import gensim
import collections
import matplotlib.pyplot as plt
import pprint
import itertools
import seaborn as sns
import networkx as nx
from IPython.display import display_svg
import tqdm
# %matplotlib inline

# %%
with open("./lt.json", "r") as f:
    raw_lt = json.load(f)

# %%
lt_per_cat = {}
for ltid, value in raw_lt.items():
    if value['cat'] not in lt_per_cat:
        lt_per_cat[value['cat']] = [value['lt']]
    else:
        lt_per_cat[value['cat']].append(value['lt'])

# %%
def remove_symbols(value):
    return value.replace("'",'').replace('>','').replace('<','').replace('=','').replace('(', '').replace(')', '').replace('[', '').replace(']', '').replace('**', '').replace(':', '').replace(',', '').replace("_", " ")

def string_to_corpus(lt, max_len=None):
    words = [remove_symbols(t) for t in lt.split()]
    split_words = []
    for w in words:
        if len(w.split()) > 1: # さらに分割できる場合
            split_words.extend(w.split())
        else:
            split_words.append(w)
    split_words = [t.lower() for t in split_words if t != '']
    if max_len != None:
        split_words = split_words[:max_len] # 前方のみ残す

    return split_words

# %%
all_corpus = dict()
for cat, lts in lt_per_cat.items():
    corpus = []
    for lt in lts:
        words = [remove_symbols(t) for t in lt.split()]
        split_words = []
        for w in words:
            if len(w.split()) > 1: # さらに分割できる場合
                split_words.extend(w.split())
            else:
                split_words.append(w)
        split_words = [t.lower() for t in split_words if t != '']
        corpus.extend(split_words)
    all_corpus[cat] = corpus

# %%
all_words = list(set([word for cat, words in all_corpus.items() for word in words]))
word_dict = {w:i for i, w in enumerate(all_words)}
inv_word_dict = {v:k for k,v in word_dict.items()}

corpus = []
for cat, lts in lt_per_cat.items():
    for lt in lts:
        words = [remove_symbols(t) for t in lt.split()]
        split_words = []
        for w in words:
            if len(w.split()) > 1: # さらに分割できる場合
                split_words.extend(w.split())
            else:
                split_words.append(w)
        split_words = [t.lower() for t in split_words if t != '']
        
        split_words = split_words[:7] # 前方のみ残す
        
        lt_word_id_cnt = collections.Counter([word_dict[w] for w in split_words])
        
        corpus.append([(tid, cnt) for tid, cnt in lt_word_id_cnt.items()])

# %%
# 単語のカウント
word_cnt = {}
for wid, cnt in sorted(collections.Counter([c[0] for s in corpus for c in s]).items(), key= lambda x: x[1])[::-1]:
    print(inv_word_dict[wid], cnt)
    word_cnt[inv_word_dict[wid]] = cnt
# Out:
# ui 543
# user 537
# mgd 505
# cfg 470
# audit 466
# rpd 374
# set 324
# other 257
# event 198
# index 174
# broadcast 162
# delete 136
# up 110
# multicast 104
# /kernel 92
# mpls 85
# lsp 83
# to 80
# evt 62
# from 61
# init 60
# updown 55
# login 55
# bgp 53
# for 51
# mtu 46
# chassisd 42
# alarm 41
# task 41
# file 41
# pic 41
# change 41
# trap 40
# error 40
# address 40
# read 39
# received 39
# mcsn 39
# sent 38
# port 38
# is 38
# add 36
# snmp 36
# notification 36
# on 36
# failed 34
# xntpd 34
# pointtopoint 32
# cmd 31
# class 30
# pid 29
# down 28
# deactivate 28
# status 28
# bandwidth 27
# - 27
# message 27
# neighbor 26
# signal 26
# state 26
# link 25
# cleared 25
# junoscript 24
# of 24
# connection 24
# info 24
# alarmd 23
# craftd 23
# generated 23
# luchip 23
# peer 23
# switch 22
# reinitializing 22
# used 22
# slot 22
# activate 21
# pci 21
# not 21
# color 20
# pfe 20
# recv 19
# master 19
# terminate 19
# bulkget 18
# chas 18
# pfeman 18
# system 18
# config 18
# sshd 18
# libjsnmp 17
# as 17
# no 17
# time 17
# re 16
# secret 16
# active 16
# rsp 16
# interface 16
# realm 15
# ospf 15
# snmpd 15
# lu 15
# fpc 15
# with 15
# major 15
# by 15
# failure 15
# rsvp 14
# mac 14
# entry 14
# pp 14
# err 14
# in 14
# queue 14
# changed 14
# kernel 14
# create 13
# register 13
# process 13
# cmtfpc 13
# ns 13
# the 13
# send 13
# reinit 13
# access 13
# ifl 13
# pem 12
# power 12
# nbrdown 12
# stp 12
# op 12
# minor 12
# id 12
# pio 12
# mqchip 12
# l2cp 12
# child 12
# at 12
# reset 12
# mib2d 12
# ok 11
# nbrup 11
# flags 11
# trap10 11
# krt 11
# new 11
# done 11
# reconfigure 11
# v4 11
# sa 11
# limit 11
# timeout 11
# msdp 10
# supply 10
# pwr 10
# sfp 10
# instance 10
# trap7 10
# commit 10
# hostif 10
# configuration 10
# pfed 10
# addr 10
# manager 10
# complete 10
# version 10
# start 10
# low 9
# mic 9
# encapsulation 9
# ae 9
# update 9
# jspec 9
# src 9
# errors 9
# cmt 9
# connect 9
# request 9
# starting 9
# auth 9
# host 9
# + 9
# sync 9
# found 9
# stream 8
# v 8
# jsr 8
# channel 8
# ucode 8
# bist 8
# trinity 8
# group 8
# destination 8
# turning 8
# pfealiveness 8
# thread 8
# log 8
# asic 8
# nif 8
# local 8
# show 8
# number 8
# logout 8
# loopback 8
# last 8
# synchronized 8
# enabled 8
# /usr/sbin/cron 8
# retries 7
# tcp 7
# handler 7
# cannot 7
# msg 7
# chassism 7
# dcd 7
# img 7
# program 7
# lu-chip 7
# mq 7
# detected 7
# ipc 7
# resync 7
# ready 7
# cos 7
# bypass 7
# established 7
# storm 7
# and 7
# initializing 7
# socket 7
# disconnect 7
# load 7
# exited 7
# password 7
# invalid 7
# attempt 7
# initialized 7
# ntpd 7
# lacp 7
# csu 6
# cm 6
# clksync 6
# vq 6
# allocate 6
# ps 6
# vlan 6
# operation 6
# administratively. 6
# mask 6
# seg 6
# dest 6
# packet 6
# input 6
# proto 6
# count 6
# device 6
# if 6
# rows 6
# reg 6
# software 6
# due 6
# sending 6
# inetd 6
# machines 6
# many 6
# incorrect 6
# server 6
# counts 5
# correctable 5
# gencfg 5
# setting 5
# reason 5
# mpc 5
# l2alm 5
# unsupported 5
# ifdev 5
# q 5
# fxp0 5
# backup 5
# tc-generation 5
# bfdd 5
# partial 5
# made 5
# serverrouter 5
# adding 5
# ifd 5
# bundle 5
# detached 5
# link-speed 5
# rename 5
# processing 5
# up. 5
# error. 5
# toe 5
# pre 5
# common 5
# ppe 5
# connected 5
# dropped 5
# route 5
# online 5
# initial 5
# will 5
# this 5
# no- 5
# termination 5
# normal 5
# bad 5
# receive 5
# disconnected 5
# accepted 5
# performing 5
# authenticated 5
# exit 5
# pam 5
# client 5
# disabled 5
# exiting 5
# classifier 4
# cosd 4
# sdrl 4
# command 4
# buffer 4
# head 4
# -x 4
# can 4
# write 4
# tftpd 4
# tnp.tftpd 4
# all 4
# sample 4
# run-length 4
# ignoring 4
# notice 4
# has 4
# chassis 4
# nh 4
# pcie 4
# bringup 4
# under 4
# thresh 4
# over 4
# pim.master 4
# pim 4
# ethernet 4
# fan 4
# prl 4
# ftpd 4
# exceeded 4
# idpd 4
# after 4
# drained 4
# ifadminstatus 4
# ifindex 4
# iff 4
# lidx 4
# aggregated-ether-options 4
# insert 4
# requested 4
# duplicate 4
# cell 4
# reorder 4
# fi 4
# mode 4
# absent 4
# gumem 4
# retry 4
# passed 4
# verify 4
# ddr3 4
# occurred 4
# handle; 4
# li 4
# check 4
# caps 4
# su 4
# hw 4
# fpc1 4
# fpc11 4
# off 4
# type 4
# service 4
# warning 4
# vector 4
# npc 4
# initialization 4
# rt 4
# decode 4
# call 4
# mgmt 4
# conn 4
# vccpd 4
# max 4
# started 4
# family 4
# table 4
# module 4
# pnac 4
# closed 4
# default 4
# routing 4
# restart 4
# dbase 4
# cleanup 4
# authentication 4
# specified 4
# logged 4
# information 4
# stratum 4
# ntp 4
# current 4
# kern 4
# btlp 3
# reboot 3
# license-check 3
# ppman 3
# /usr/libexec/ui/package 3
# / 3
# because 3
# standby 3
# ack 3
# calling 3
# initiated 3
# list 3
# shutting 3
# detach 3
# slots 3
# nhop 3
# addandget 3
# perform 3
# eventd 3
# plugged 3
# response 3
# reasonhost 3
# bootpd 3
# tnp.bootpd 3
# slave 3
# using 3
# notconnect. 3
# r8 3
# off. 3
# output 3
# bias 3
# laser 3
# ftp 3
# speed 3
# vpls 3
# path 3
# enable 3
# succeeded 3
# transaction 3
# handle 3
# tlv 3
# options 3
# mc 3
# value 3
# eswd 3
# copy 3
# l2ald 3
# arp 3
# mq-chip 3
# rldram 3
# timestamp 3
# throttle 3
# rev 3
# jtag 3
# lock 3
# pll 3
# chip 3
# nlri 3
# mismatch 3
# hold 3
# getnext 3
# cmsfpc 3
# man 3
# peering 3
# estd 3
# veto 3
# rtsock 3
# rtslib 3
# xcvr 3
# sntpd 3
# session 3
# builder 3
# offline 3
# total 3
# listener 3
# be 3
# recovered. 3
# detected. 3
# vccp 3
# watchdog 3
# built 3
# sfid 3
# management 3
# fatal 3
# string 3
# failures 3
# engine 3
# mastership 3
# cant 3
# empty 3
# too 3
# lost 3
# times 3
# repeated 3
# unavailable 3
# temporarily 3
# resource 3
# # 3
# unreachable 3
# root 3
# mcsnoopd 2
# lldpd 2
# cap 2
# shutdown 2
# rate 2
# per-iff 2
# icmp 2
# shop 2
# ppmd 2
# action 2
# unbind 2
# coscos 2
# rewrite 2
# based 2
# fc 2
# failed; 2
# me 2
# ifcm 2
# itable 2
# map 2
# bd 2
# snooping 2
# pcf8584wr 2
# phy 2
# unreplicate 2
# disable 2
# libjnx 2
# hardware 2
# equipment 2
# different 2
# media 2
# credit 2
# wo 2
# block 2
# taking 2
# fru 2
# it 2
# plx 2
# called 2
# intr 2
# mpfe 2
# threshold 2
# prefix-limit 2
# maximum 2
# configured 2
# edit 2
# blocks 2
# tftp 2
# boot 2
# bootstring 2
# expired 2
# ipv6 2
# dad 2
# sglinkrd 2
# bcm5389 2
# disabled. 2
# fifo 2
# model 2
# locate 2
# mah 2
# absent. 2
# qx 2
# set. 2
# day 2
# information. 2
# diagnostic 2
# contains 2
# nvram 2
# on-board 2
# utc 2
# i2 2
# dev 2
# i2c 2
# creating 2
# hostname 2
# entered 2
# handles 2
# svc 2
# pool 2
# tb 2
# size 2
# buckets 2
# createqsize 2
# cmlc 2
# max6657 2
# max6697 2
# fpga 2
# plane 2
# sigterm 2
# sendto 2
# layer 2
# forwarding 2
# replicated 2
# pools 2
# mem 2
# 4way 2
# jnh 2
# method 2
# write/connect 2
# events 2
# reconn 2
# next 2
# indirect 2
# unable 2
# policy 2
# parseconfig 2
# foreground 2
# reconfig 2
# took 2
# training 2
# logical-router 2
# top 2
# ddl 2
# sfp+ 2
# gres 2
# modem 2
# excessive 2
# reasonexcessive 2
# reasonfpc 2
# feed 2
# dipswitch 2
# communication 2
# loss 2
# reasonloss 2
# tnpv2 2
# deleting 2
# tnpv3 2
# could 2
# soreceive 2
# inputs 2
# parse 2
# normal. 2
# fans 2
# blowers 2
# dyn 2
# vc 2
# layer2 2
# was 2
# entries 2
# referred 2
# udp 2
# netsnmp 2
# jnx 2
# trap6 2
# io 2
# kmd 2
# source 2
# connecting 2
# creating... 2
# ... 2
# queuing 2
# rem 2
# attempted 2
# frag 2
# reconnection 2
# dq 2
# mvlan 2
# 0800000000000000 2
# e3 2
# bundlestate 2
# group. 2
# joins 2
# attached 2
# leaves 2
# value! 2
# cfmd 2
# lldp 2
# rollback 2
# phase 2
# ip 2
# ifbd 2
# base 2
# dram 2
# done. 2
# ddrio 2
# registering 2
# dmc 2
# gumem.ucode.instr 2
# u256 2
# parity 2
# idmem 2
# skipping... 2
# #; 2
# complete! 2
# initialising 2
# ddr 2
# tcam 2
# memory 2
# prescaler 2
# hash 2
# ix 2
# mq-0 2
# u64 2
# open 2
# pending 2
# reseting 2
# dropping 2
# data 2
# pc 2
# fault 2
# lmem 2
# loaded 2
# packets 2
# wedge 2
# argument 2
# complete. 2
# slowest 2
# possible 2
# ms 2
# interval 2
# probe 2
# fabric 2
# recovery 2
# completed. 2
# cache 2
# soft 2
# monitor 2
# cms 2
# sys 2
# periodic 2
# max-fpc 2
# chassisid 2
# startup 2
# attach 2
# spd 2
# /usr/sbin/sshd 2
# hup 2
# connections 2
# terminated 2
# connected. 2
# transceiver 2
# reinitialized 2
# l2cpd 2
# profile 2
# acess 2
# 802.1x 2
# protocol 2
# identification 2
# unauthenticated 2
# junos 2
# entering 2
# username 2
# aborted 2
# out 2
# timed 2
# . 2
# reduced 2
# messages 2
# syslog 2
# s 2
# ppm 2
# frequency 2
# listening 2
# usec 2
# precision 2
# timer 2
# while 2
# intf 2
# ifinfo 2
# -l 2
# /usr/sbin/check-support 2
# -a 2
# adjkerntz 2
# newsyslog 2
# maca5 1
# linklocal 1
# inet6 1
# java 1
# rto 1
# bdllp 1
# header 1
# ctl 1
# & 1
# advanced 1
# uncorrectable 1
# cap0- 1
# stat 1
# dr 1
# rebooted 1
# halt 1
# halted 1
# recovered 1
# simplex 1
# activated 1
# psp 1
# member 1
# -r 1
# rcp 1
# replicate 1
# success 1
# license 1
# discriminator 1
# side 1
# remote 1
# disconnected; 1
# unknown 1
# ieee-802.1 1
# 8021p 1
# cosman 1
# clk 1
# def 1
# died 1
# ttloop 1
# telnetd 1
# such 1
# console 1
# cfg-duplex 1
# autoneg 1
# acl 1
# egress 1
# vrf 1
# tx 1
# -no-validate 1
# validate 1
# uplink 1
# tsunami 1
# errno 1
# scheduler 1
# sec 1
# slip 1
# sched 1
# cubs 1
# lion 1
# subtype 1
# inserted 1
# remove 1
# freeing 1
# debug 1
# mb 1
# syscall 1
# helper 1
# pmap 1
# accounting 1
# l2 1
# associated 1
# iflogical 1
# rtbid 1
# type. 1
# line 1
# byte 1
# target 1
# resetting 1
# workaround 1
# qt2025 1
# jflow 1
# sampling 1
# forwarding-options 1
# /usr/sbin/sampled 1
# level2 1
# level3 1
# unrepl 1
# reinject 1
# primary 1
# reinjectreinject 1
# error2 1
# kind 1
# wexit 1
# exec 1
# rate-limit-burst 1
# cmx 1
# mesg 1
# v2.2 1
# ia 1
# reason? 1
# netconf. 1
# another 1
# execution 1
# prefix 1
# returned 1
# temperature 1
# level 1
# tolerance 1
# synchronization 1
# fgets 1
# noblock 1
# keepalive 1
# rdp 1
# rxe 1
# translated-tag. 1
# added 1
# anycast 1
# router 1
# subnet 1
# devstop 1
# eth 1
# ethswitch 1
# commands 1
# initialized. 1
# r6 1
# board 1
# recvcomplete 1
# l4 1
# incompatible 1
# warn 1
# identical 1
# sendcomplete 1
# switchover 1
# errors. 1
# bouncing 1
# cmg 1
# sp-7/1 1
# modify 1
# inactive. 1
# failed. 1
# negotiation 1
# auto 1
# extend 1
# increase 1
# mmap 1
# cli 1
# manual 1
# valid 1
# pkt 1
# inbound 1
# ipsec 1
# high 1
# samples 1
# sm 1
# pseudos 1
# 2- 1
# corrected 1
# network 1
# overwrite 1
# sntpsync 1
# illegal 1
# sgls 1
# gbus 1
# perms 1
# rtcb 1
# rts 1
# daemons 1
# kern.securelevel 1
# package 1
# vectors 1
# cosfpc 1
# mt 1
# cospic 1
# 2nd 1
# 1st 1
# forbes1 1
# forbes0 1
# sg 1
# match 1
# ver 1
# succesfully 1
# aser 1
# corruption 1
# ai 1
# appidd 1
# processes 1
# image. 1
# acbc 1
# older 1
# clksyncd 1
# rhost 1
# control 1
# select 1
# ksyncd 1
# smartd 1
# sdk 1
# libjunos 1
# relayd 1
# completed 1
# idp 1
# pseudo 1
# db 1
# flushsession 1
# repo 1
# l2vpn 1
# pics 1
# services 1
# mpc-3d-16xge-sfpp 1
# use 1
# unilistnh 1
# unlist 1
# exist 1
# does 1
# modified 1
# being 1
# are 1
# profiles 1
# "dynamic-profiles" 1
# ffp 1
# unplugged 1
# promiscuous 1
# became 1
# becoming 1
# resending 1
# connecton 1
# platform 1
# reasonbackup 1
# ecc 1
# release 1
# tnp 1
# mup 1
# bulk 1
# peertype 1
# initoverriding 1
# asp 1
# clearing 1
# impellers 1
# medium 1
# unexpectedly 1
# wrong 1
# missing 1
# md5 1
# 0...... 1
# nsr 1
# profilesession 1
# disassociate 1
# bdid 1
# snp 1
# opdelete 1
# opadd 1
# chg 1
# opchange 1
# seconds. 1
# sorry 1
# capacity. 1
# beyond 1
# allowed 1
# trunk 1
# switchport 1
# down. 1
# rpd1896 1
# localup 1
# rpd1866 1
# restarted. 1
# community 1
# nsa 1
# bind 1
# throttled 1
# sms 1
# finish 1
# tries 1
# re-connecting 1
# abruptly 1
# stop 1
# queued 1
# rcvd 1
# iffm 1
# 20120014 1
# ae6.107 1
# ae6.202 1
# removed 1
# ifarequest 1
# 20120010 1
# without 1
# ifstate 1
# flag 1
# skipped 1
# container 1
# synchronize 1
# receiving 1
# port. 1
# nd6 1
# moves 1
# move 1
# resumed 1
# reached 1
# overwritten 1
# ichip 1
# #cbo-entries; 1
# #kmb-entries; 1
# #kma-entries; 1
# #gumem-entries; 1
# lu-0 1
# bank 1
# ap 1
# nack 1
# rd 1
# success!!! 1
# nl9k 1
# bisttcam 1
# seen 1
# have 1
# seconds 1
# xe 1
# chassis/fpc 1
# mspd 1
# ixchip 1
# sysif 1
# pt 1
# length 1
# link-local 1
# mld6 1
# maxprefixes 1
# ifachange 1
# clear 1
# unexpected 1
# rejecting 1
# bytes 1
# 7 1
# processed 1
# sfpc 1
# loopbackclearing 1
# loopbackhost 1
# failedindex 1
# second 1
# delayed 1
# peek 1
# idr 1
# idl 1
# gap 1
# sequence 1
# advertise 1
# cmfpc 1
# cmtsunami 1
# eeprom 1
# record 1
# initiating 1
# sampledc 1
# got 1
# fec 1
# label 1
# lookup 1
# reverse 1
# logic 1
# af 1
# idx 1
# telnet 1
# 10.4r2.6 1
# sendmsg 1
# rawsock 1
# chassis-control 1
# packet-forwarding-engine 1
# virtual-chassis-control 1
# software-forwarding 1
# chassis-manager 1
# inet-process 1
# tnp-process 1
# abort 1
# caused 1
# accept 1
# usr1 1
# ssh 1
# notconnected. 1
# running 1
# * 1
# main 1
# jl2tpd 1
# vs. 1
# differ 1
# versions 1
# subsystem 1
# ssh2 1
# did 1
# disconnecting 1
# but 1
# successfully 1
# signaled 1
# toggle 1
# execute. 1
# daemon 1
# restarting 1
# ## 1
# authenticating 1
# run# 1
# malformed 1
# refused 1
# log. 1
# esc 1
# overflowed. 1
# offset 1
# step 1
# ntpdate 1
# re-established 1
# 4.2.0-a 1
# mlockall 1
# reachable 1
# servers 1
# lacpd 1
# /etc/crontab 1
# reload 1
# *system* 1
# /usr/libexec/atrun 1

# %%
raw_lt
# Out:
# {'0': {'cat': 'system(cron)',
#   'lt': '/usr/sbin/cron[**]: (root) CMD (newsyslog)'},
#  '1': {'cat': 'network(lacp)',
#   'lt': 'mib2d[**]: lacp info not found for ifl:**'},
#  '2': {'cat': 'network(lacp)',
#   'lt': 'mib2d[**]: cleared lacp info not found for ifl:**'},
#  '3': {'cat': 'system(cron)',
#   'lt': '/usr/sbin/cron[**]: (**) CMD (adjkerntz -a)'},
#  '4': {'cat': 'service(ntp)', 'lt': 'xntpd[**]: NTP Server Unreachable'},
#  '5': {'cat': 'monitor(syslog)', 'lt': 'last message repeated ** times'},
#  '6': {'cat': 'network(mtu)', 'lt': '/kernel: MTU for ** reduced to **'},
#  '7': {'cat': 'mgmt(login)',
#   'lt': 'login: LOGIN_INFORMATION: User ** logged in from host ** on device **'},
#  '8': {'cat': 'system(ui)',
#   'lt': "mgd[**]: UI_AUTH_EVENT: Authenticated user '**' at permission level '**'"},
#  '9': {'cat': 'system(ui)',
#   'lt': "mgd[**]: UI_LOGIN_EVENT: User '**' login, class '**' [**], ssh-connection '', client-mode 'cli'"},
#  '10': {'cat': 'system(ui)',
#   'lt': "mgd[**]: UI_CHILD_START: Starting child '**'"},
#  '11': {'cat': 'system(ui)',
#   'lt': "mgd[**]: UI_CHILD_STATUS: Cleanup child '**', PID **, status **"},
#  '12': {'cat': 'system(ui)',
#   'lt': "mgd[**]: UI_LOGOUT_EVENT: User '**' logout"},
#  '13': {'cat': 'mgmt(command)',
#   'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '(unauthenticated user)' used JUNOScript client to run command 'request-authentication user=** logname=** host=** agent=mgd current-directory=/var/tmp pid=** ppid=**'"},
#  '14': {'cat': 'system(ui)',
#   'lt': "mgd[**]: UI_LOGIN_EVENT: User '**' login, class '**' **[**], ssh-connection '', client-mode 'junoscript'"},
#  '15': {'cat': 'mgmt(command)',
#   'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to ** command 'show system **'"},
#  '16': {'cat': 'mgmt(command)',
#   'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to ** command '**'"},
#  '17': {'cat': 'service(ntp)', 'lt': 'xntpd[**]: kernel time sync enabled **'},
#  '18': {'cat': 'mgmt(login)',
#   'lt': '[**]: EVT ** ** ** ACCESS ** **:** Login ** from ** (**)**'},
#  '19': {'cat': 'mgmt(login)',
#   'lt': '[**]: EVT ** ** ** ACCESS ** **:** Logout ** from ** (**).'},
#  '20': {'cat': 'mgmt(ssh)',
#   'lt': 'sshd[**]: Accepted password for ** from ** port ** **'},
#  '21': {'cat': 'system(ui)',
#   'lt': "mgd[**]: UI_LOGIN_EVENT: User '**' login, class '**' [**], ssh-connection '** ** ** **', client-mode 'cli'"},
#  '22': {'cat': 'network(l2)',
#   'lt': 'jl2tpd: jl2tpd: main: *** jl2tpd not running in active mode***'},
#  '23': {'cat': 'mgmt(ssh)',
#   'lt': 'sshd[**]: Received disconnect from **: **: disconnected by user'},
#  '24': {'cat': 'system(unix)', 'lt': 'inetd[**]: **[**]: exited, status **'},
#  '25': {'cat': 'mgmt(command)',
#   'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to run command 'get-software-information level=**'"},
#  '26': {'cat': 'network(storm)',
#   'lt': '[**]: EVT ** ** ** PORT ** ** **:** NIF ** Port **:broadcast storm detected.'},
#  '27': {'cat': 'network(storm)',
#   'lt': '[**]: EVT ** ** ** PORT ** ** **:** NIF ** Port **:broadcast storm recovered.'},
#  '28': {'cat': 'network(mtu)',
#   'lt': 'rpd[**]: EVENT <MTU> ** index ** <Up Broadcast PointToPoint Multicast> address #** **'},
#  '29': {'cat': 'system(pic)', 'lt': 'Slot **, PIC Slot **) idx ** af **'},
#  '30': {'cat': 'system(pic)', 'lt': 'Slot **, PIC Slot **) ifl family **'},
#  '31': {'cat': 'network(pfe)',
#   'lt': 'pfed: PFED: rtslib sequence gap ** - **'},
#  '32': {'cat': 'network(pfe)', 'lt': 'pfed: PFED: rtsock init completed.'},
#  '33': {'cat': 'network(pfe)',
#   'lt': 'pfed: PFED: rtsock recovery ** completed.'},
#  '34': {'cat': 'system(ppe)',
#   'lt': '[**]: EVT ** ** ** SOFTWARE ** **:** Received many packets and loaded into the queue to CPU.'},
#  '35': {'cat': 'system(ppe)',
#   'lt': '[**]: EVT ** ** ** SOFTWARE ** **:** Processed the packets in the queue to CPU.'},
#  '36': {'cat': 'mgmt(pam)',
#   'lt': 'login: LOGIN_PAM_AUTHENTICATION_ERROR: PAM authentication error for user **'},
#  '37': {'cat': 'mgmt(login)',
#   'lt': 'login: LOGIN_FAILED: Login failed for user ** from host **'},
#  '38': {'cat': 'mgmt(login)',
#   'lt': "login: LOGIN_FAILED_LIMIT: Specified number of login failures (**) for user '**' reached from '**'"},
#  '39': {'cat': 'network(pfe)',
#   'lt': 'pfed: rtslib: ERROR IDL IDR Decode Error **(Invalid Buffer Size)'},
#  '40': {'cat': 'service(ntp)',
#   'lt': 'xntpd[**]: synchronized to **, stratum=**'},
#  '41': {'cat': 'system(cron)',
#   'lt': '/usr/sbin/cron[**]: (**) CMD (/usr/sbin/check-support -l)'},
#  '42': {'cat': 'mgmt(su)', 'lt': 'su: ** to ** on **'},
#  '43': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_send: sending ** bytes to ** (** AS **) blocked (no spooling requested): Resource temporarily unavailable'},
#  '44': {'cat': 'network(lacp)',
#   'lt': 'ifinfo: lacp info not found for ifl:**'},
#  '45': {'cat': 'network(lacp)',
#   'lt': 'ifinfo: cleared lacp info not found for ifl:**'},
#  '46': {'cat': 'mgmt(command)',
#   'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to run command 'get-virtual-chassis-adjacency-information verbosity_level=**'"},
#  '47': {'cat': 'mgmt(command)',
#   'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to run command 'get-virtual-chassis-database-information verbosity_level=**'"},
#  '48': {'cat': 'mgmt(command)',
#   'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to run command 'get-virtual-chassis-route-information verbosity_level=**'"},
#  '49': {'cat': 'mgmt(command)',
#   'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to run command 'get-virtual-chassis-port-statistics verbosity_level=**'"},
#  '50': {'cat': 'mgmt(ssh)',
#   'lt': "sshd: User '**' authenticated successfully but no local login-id configured."},
#  '51': {'cat': 'mgmt(ssh)',
#   'lt': 'sshd[**]: Accepted password for ** from ** port **'},
#  '52': {'cat': 'mgmt(ssh)', 'lt': 'sshd[**]: Connection closed by **'},
#  '53': {'cat': 'network(mld)',
#   'lt': '/kernel: mld6_input: src ** is not link-local (grp=**)'},
#  '54': {'cat': 'system(fpc)',
#   'lt': 'MQCHIP(**) LI Packet length error, pt entry **'},
#  '55': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_hold_timeout:**: NOTIFICATION sent to ** (** AS **): code ** (Hold Timer Expired Error), Reason: holdtime expired for ** (** AS **), socket buffer sndcc: ** rcvcc: ** TCP state: **, snd_una: ** snd_nxt: ** snd_wnd: ** rcv_nxt: ** rcv_adv: **, hold timer **'},
#  '56': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: RPD_BGP_NEIGHBOR_STATE_CHANGED: BGP peer ** (** AS **) changed state from ** to ** (event **)'},
#  '57': {'cat': 'network(arp)',
#   'lt': '/kernel: KERN_ARP_ADDR_CHANGE: ** info overwritten for ** from ** to **'},
#  '58': {'cat': 'mgmt(login)',
#   'lt': '[**]: EVT ** ** ** ACCESS ** **:** Login incorrect **'},
#  '59': {'cat': 'mgmt(ssh)',
#   'lt': 'sshd[**]: Failed password for ** from ** port ** **'},
#  '60': {'cat': 'interface(port)',
#   'lt': '[**]: EVT ** ** ** PORT ** ** **:** Port disabled administratively.'},
#  '61': {'cat': 'system(ui)',
#   'lt': "mgd[**]: UI_DBASE_LOGIN_EVENT: User '**' entering configuration mode"},
#  '62': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_COMMIT: User '**' requested 'commit' operation (comment: none)"},
#  '63': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [interfaces ** unit **]"},
#  '64': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' activate: [interfaces ** unit **]"},
#  '65': {'cat': 'interface(agg)',
#   'lt': 'dcd[**]: ** : Warning: aggregated-ether-options link-speed no kernel value! default to **'},
#  '66': {'cat': 'system(pic)',
#   'lt': 'spd[**]: **: This PIC will be reset on graceful switchover'},
#  '67': {'cat': 'network(l2)',
#   'lt': 'l2cp[**]: Initializing PNAC state machines'},
#  '68': {'cat': 'network(l2)',
#   'lt': 'l2cp[**]: Initializing PNAC state machines complete'},
#  '69': {'cat': 'network(l2)',
#   'lt': 'l2cp[**]: Initialized 802.1X module and state machines'},
#  '70': {'cat': 'network(l2)', 'lt': 'l2cp[**]: Read acess profile () config'},
#  '71': {'cat': 'mgmt(config)',
#   'lt': 'rpd[**]: Synchronized commit processing phase ** **'},
#  '72': {'cat': 'service(ntp)', 'lt': 'xntpd[**]: ntpd exiting on signal **'},
#  '73': {'cat': 'service(ntp)',
#   'lt': 'xntpd[**]: ntpd ** ** ** ** ** ** ** (**)'},
#  '74': {'cat': 'service(ntp)', 'lt': 'xntpd[**]: precision = ** usec'},
#  '75': {'cat': 'service(ntp)',
#   'lt': 'xntpd[**]: Listening on interface **, **#**'},
#  '76': {'cat': 'service(ntp)', 'lt': 'xntpd[**]: kernel time sync status **'},
#  '77': {'cat': 'service(ntp)',
#   'lt': 'xntpd[**]: frequency initialized ** PPM from **'},
#  '78': {'cat': 'mgmt(config)',
#   'lt': 'rpd[**]: RPD_TASK_REINIT: Reinitializing'},
#  '79': {'cat': 'mgmt(config)',
#   'lt': 'rpd[**]: task_reconfigure reinitializing done'},
#  '80': {'cat': 'mgmt(config)',
#   'lt': 'rpd[**]: Synchronized commit processing complete'},
#  '81': {'cat': 'interface(agg)',
#   'lt': 'dcd[**]: ** : aggregated-ether-options link-speed set to kernel value of **'},
#  '82': {'cat': 'interface(agg)',
#   'lt': '/kernel: ae_link_op: link ** (lidx=**) detached from bundle **'},
#  '83': {'cat': 'interface(agg)', 'lt': '/kernel: ** leaves **'},
#  '84': {'cat': 'interface(agg)',
#   'lt': '/kernel: bundle **: bundle IFL state changed to **'},
#  '85': {'cat': 'monitor(snmp)',
#   'lt': 'mib2d[**]: SNMP_TRAP_LINK_DOWN: ifIndex **, ifAdminStatus **(**), ifOperStatus **(**), ifName **'},
#  '86': {'cat': 'interface(agg)',
#   'lt': '**: rpd[**]: Received MC_AE_OPTIONS TLV for intf device **; mc_ae_id **, status **'},
#  '87': {'cat': 'interface(agg)',
#   'lt': 'mcsn[**]: Received MC_AE_OPTIONS TLV for intf device **; mc_ae_id **, status **'},
#  '88': {'cat': 'interface(agg)',
#   'lt': '/kernel: ae_link_op: link ** (lidx=**) attached to bundle **'},
#  '89': {'cat': 'interface(agg)', 'lt': '/kernel: ** joins **'},
#  '90': {'cat': 'monitor(snmp)',
#   'lt': 'mib2d[**]: SNMP_TRAP_LINK_UP: ifIndex **, ifAdminStatus **(**), ifOperStatus **(**), ifName **'},
#  '91': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT Delete UpDown ** index ** ** -> ** <Broadcast Multicast Localup>'},
#  '92': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT <Delete UpDown> ** index ** <Broadcast Multicast> address #** **'},
#  '93': {'cat': 'interface(agg)',
#   'lt': 'rpd[**]: Received MC_AE_OPTIONS TLV for intf device **; mc_ae_id **, status **'},
#  '94': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT <Add> ** index ** <Up Broadcast Multicast> address #** **'},
#  '95': {'cat': 'network(mtu)',
#   'lt': 'rpd[**]: EVENT <MTU> ** index ** <Up Broadcast Multicast> address #** **'},
#  '96': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT <Flags> ** index ** <Up Broadcast Multicast> address #** **'},
#  '97': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT Add ** index ** ** -> ** <Up Broadcast Multicast Localup>'},
#  '98': {'cat': 'network(l2)',
#   'lt': 'l2cp[**]: L2CPD_TASK_REINIT: Reinitialized'},
#  '99': {'cat': 'mgmt(config)',
#   'lt': 'l2cp[**]: task_reconfigure reinitializing done'},
#  '100': {'cat': 'mgmt(config)',
#   'lt': 'mcsn[**]: RPD_TASK_REINIT: Reinitializing'},
#  '101': {'cat': 'mgmt(config)',
#   'lt': 'mcsn[**]: task_reconfigure reinitializing done'},
#  '102': {'cat': 'service(ntp)',
#   'lt': 'xntpd[**]: kernel time sync disabled **'},
#  '103': {'cat': 'system(ui)',
#   'lt': "mgd[**]: UI_DBASE_LOGOUT_EVENT: User '**' exiting configuration mode"},
#  '104': {'cat': 'monitor(snmp)',
#   'lt': 'rpd[**]: EVENT <SNMP Index> ** index ** <Up Broadcast Multicast> address #** **'},
#  '105': {'cat': 'interface(port)',
#   'lt': '[**]: EVT ** ** ** PORT ** ** **:** Port enabled administratively.'},
#  '106': {'cat': 'system(ui)',
#   'lt': "mgd[**]: UI_CHILD_EXITED: Child exited: PID **, status **, command '**'"},
#  '107': {'cat': 'interface(port)',
#   'lt': '[**]: EVT ** ** ** PORT ** ** **:** Port up.'},
#  '108': {'cat': 'interface(port)',
#   'lt': '[**]: EVT ** ** ** PORT ** ** **:** Error detected on the port.'},
#  '109': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [interfaces ** unit **]"},
#  '110': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [class-of-service interfaces ** unit **]"},
#  '111': {'cat': 'interface(vlan)',
#   'lt': '[**]: EVT ** ** ** VLAN ** **:** VLAN (**) Status is Down.'},
#  '112': {'cat': 'mgmt(enable)', 'lt': '[**]: RSP ** ** **(**):enable: Sorry'},
#  '113': {'cat': 'network(storm)',
#   'lt': '[**]: EVT ** ** ** PORT ** ** **:** NIF ** Port **:storm detected.'},
#  '114': {'cat': 'network(storm)',
#   'lt': '[**]: EVT ** ** ** PORT ** ** **:** NIF ** Port **:storm recovered.'},
#  '115': {'cat': 'interface(vlan)',
#   'lt': '[**]: RSP ** ** **(**):interface : Cannot change vlan configuration referred by flow configuration.[**]'},
#  '116': {'cat': 'network(arp)',
#   'lt': 'l2ald[**]: L2ALD_MAC_LIMIT_REACHED_IFBD: Limit on learned MAC addresses reached for ** flags [0x **] state [0x **]; current count is **'},
#  '117': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <Flags> ** index ** <Up Broadcast Multicast> address #** **'},
#  '118': {'cat': 'network(arp)',
#   'lt': 'l2ald[**]: L2ALD_MAC_LIMIT_RESET_IF: Resumed adding MAC addresses learned by ** flags [0x **] state [0x **]; current count is **'},
#  '119': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [interfaces ** unit **]"},
#  '120': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [interfaces ** unit ** vlan-id] <unconfigured> -> "**"'},
#  '121': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [interfaces ** unit ** family **]"},
#  '122': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [interfaces ** unit ** family ** mtu] <unconfigured> -> "**"'},
#  '123': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [interfaces ** unit ** family ** address **]"},
#  '124': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [class-of-service interfaces ** unit ** classifiers **] <unconfigured> -> "**"'},
#  '125': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [class-of-service interfaces ** unit ** rewrite-rules **] <unconfigured> -> "**"'},
#  '126': {'cat': 'interface(vlan)',
#   'lt': '[**]: EVT ** ** ** VLAN ** **:** VLAN (**) Status is Up.'},
#  '127': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_read_v4_message:**: NOTIFICATION received from ** (** AS **): code ** (Hold Timer Expired Error), socket buffer sndcc: ** rcvcc: ** TCP state: **, snd_una: ** snd_nxt: ** snd_wnd: ** rcv_nxt: ** rcv_adv: **, hold timer **'},
#  '128': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_process_caps: mismatch NLRI with ** (** AS **): peer: <** **>(**) us: <**>(**)'},
#  '129': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_read_message:**: NOTIFICATION sent to **+** (proto): code ** (Message Header Error) subcode ** (bad length) value **'},
#  '130': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' delete: [protocols bgp group ** neighbor **] "**'},
#  '131': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [protocols bgp group ** neighbor **] <**> -> "**"'},
#  '132': {'cat': 'system(ppe)', 'lt': 'LU ** ** Errors lmem addr error'},
#  '133': {'cat': 'system(ppe)',
#   'lt': 'PPE PPE HW Fault Trap: Count **, PC **, 0x0056: ipv4_input_set_proto_and_ports'},
#  '134': {'cat': 'mgmt(ssh)',
#   'lt': 'sshd[**]: Disconnecting: Too many password failures for **'},
#  '135': {'cat': 'vpn(mpls)',
#   'lt': '**:rpd[**]: RPD_MPLS_PATH_DOWN: MPLS path ** down on LSP **'},
#  '136': {'cat': 'vpn(mpls)',
#   'lt': '**:rpd[**]: RPD_MPLS_LSP_DOWN: MPLS LSP ** down on primary(**)'},
#  '137': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <UpDown> index ** <Broadcast Multicast> address #** **'},
#  '138': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <UpDown> ** index ** <Broadcast Multicast> address #** **'},
#  '139': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT UpDown ** index ** ** -> ** <Broadcast Multicast Localup>'},
#  '140': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT UpDown ** index ** <Broadcast Multicast Localup>'},
#  '141': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT <UpDown> ** index ** <Broadcast Multicast> address #** **'},
#  '142': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT UpDown ** index ** ** -> ** <Broadcast Multicast Localup>'},
#  '143': {'cat': 'interface(if_event)',
#   'lt': 'mcsn[**]: EVENT <UpDown> index ** <Broadcast Multicast> address #** **'},
#  '144': {'cat': 'network(stp)',
#   'lt': '**: rpd[**]: STP handler: index=**, op=change, state=**, tc-generation=**'},
#  '145': {'cat': 'network(stp)', 'lt': '**: rpd[**]: STP Chg'},
#  '146': {'cat': 'network(stp)',
#   'lt': 'mcsn[**]: STP handler: index=**, op=**, state=**, tc-generation=**'},
#  '147': {'cat': 'network(stp)', 'lt': 'mcsn[**]: STP **'},
#  '148': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT <UpDown> index ** <Broadcast Multicast> address #** **'},
#  '149': {'cat': 'network(stp)',
#   'lt': 'rpd[**]: STP handler: index=**, op=**, state=**, tc-generation=**'},
#  '150': {'cat': 'network(stp)', 'lt': 'rpd[**]: STP **'},
#  '151': {'cat': 'igp(ospf)',
#   'lt': '**:rpd[**]: RPD_OSPF_NBRDOWN: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to KillNbr (event reason: interface went down)'},
#  '152': {'cat': 'network(rsvp)',
#   'lt': '**:rpd[**]: RPD_RSVP_NBRDOWN: RSVP neighbor ** down on interface **, triggered by IGP neighbor down event'},
#  '153': {'cat': 'igp(ospf)',
#   'lt': 'rpd[**]: RPD_OSPF_NBRDOWN: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to KillNbr (event reason: interface went down)'},
#  '154': {'cat': 'vpn(l2vc)',
#   'lt': '**:rpd[**]: RPD_LAYER2_VC_DOWN: State of Layer ** VC (VPN : **, local-site : **, remote-site : **) changed from ** to **'},
#  '155': {'cat': 'vpn(vpls)',
#   'lt': '**: rpd[**]: vpls_dyn_disassociate_profile:session ID **'},
#  '156': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT Delete UpDown ** index ** <Broadcast PointToPoint Multicast Localup>'},
#  '157': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <Delete UpDown> ** index ** <Broadcast PointToPoint Multicast>'},
#  '158': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <UpDown> ** index ** <Up Broadcast Multicast> address #** **'},
#  '159': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT UpDown ** index ** ** -> ** <Up Broadcast Multicast>'},
#  '160': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <UpDown> index ** <Up Broadcast Multicast> address #** **'},
#  '161': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT UpDown ** index ** <Up Broadcast Multicast>'},
#  '162': {'cat': 'interface(if_event)',
#   'lt': 'mcsn[**]: EVENT <UpDown> index ** <Up Broadcast Multicast> address #** **'},
#  '163': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT <UpDown> ** index ** <Up Broadcast Multicast> address #** **'},
#  '164': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT UpDown ** index ** ** -> ** <Up Broadcast Multicast>'},
#  '165': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT <UpDown> index ** <Up Broadcast Multicast> address #** **'},
#  '166': {'cat': 'igp(ospf)',
#   'lt': '**:rpd[**]: RPD_OSPF_NBRUP: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to 2WayRcvd (event reason: neighbor detected this router)'},
#  '167': {'cat': 'igp(ospf)',
#   'lt': 'rpd[**]: RPD_OSPF_NBRUP: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to 2WayRcvd (event reason: neighbor detected this router)'},
#  '168': {'cat': 'igp(ospf)',
#   'lt': '**:rpd[**]: RPD_OSPF_NBRUP: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to LoadDone (event reason: OSPF loading completed)'},
#  '169': {'cat': 'igp(ospf)',
#   'lt': 'rpd[**]: RPD_OSPF_NBRUP: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to LoadDone (event reason: OSPF loading completed)'},
#  '170': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <Add> ** index ** <Up Broadcast PointToPoint Multicast>'},
#  '171': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <Instance> ** index ** <Up Broadcast PointToPoint Multicast>'},
#  '172': {'cat': 'network(mtu)',
#   'lt': '**: rpd[**]: EVENT <MTU> ** index ** <Up Broadcast PointToPoint Multicast>'},
#  '173': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <Flags> ** index ** <Up Broadcast PointToPoint Multicast>'},
#  '174': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT Add ** index ** <Up Broadcast PointToPoint Multicast Localup>'},
#  '175': {'cat': 'monitor(snmp)',
#   'lt': '**: rpd[**]: EVENT <SNMP Index> ** index ** <Up Broadcast PointToPoint Multicast>'},
#  '176': {'cat': 'vpn(mpls)',
#   'lt': '**:rpd[**]: RPD_MPLS_PATH_UP: MPLS path ** up on LSP ** path bandwidth ** bps'},
#  '177': {'cat': 'vpn(mpls)',
#   'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(Label=**) lsp bandwidth ** bps'},
#  '178': {'cat': 'vpn(l2vc)',
#   'lt': '**:rpd[**]: RPD_LAYER2_VC_UP: State of Layer ** VC (VPN : **, local-site : **, remote-site : **) changed to UP'},
#  '179': {'cat': 'vpn(mpls)',
#   'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'},
#  '180': {'cat': 'egp(bgp)',
#   'lt': '**: rpd[**]: bgp_hold_timeout:**: NOTIFICATION sent to ** (** AS **): code ** (Hold Timer Expired Error), Reason: holdtime expired for ** (** AS **), socket buffer sndcc: ** rcvcc: ** TCP state: **, snd_una: ** snd_nxt: ** snd_wnd: ** rcv_nxt: ** rcv_adv: **, hold timer **'},
#  '181': {'cat': 'egp(bgp)',
#   'lt': '**:rpd[**]: RPD_BGP_NEIGHBOR_STATE_CHANGED: BGP peer ** (** AS **) changed state from ** to ** (event **)'},
#  '182': {'cat': 'monitor(snmp)',
#   'lt': 'snmpd[**]: SNMPD_TRAP_QUEUED: Adding trap to ** to ** queue, ** traps in queue'},
#  '183': {'cat': 'egp(bgp)',
#   'lt': '**: rpd[**]: bgp_read_v4_message:**: NOTIFICATION received from ** (** AS **): code ** (Hold Timer Expired Error), socket buffer sndcc: ** rcvcc: ** TCP state: **, snd_una: ** snd_nxt: ** snd_wnd: ** rcv_nxt: ** rcv_adv: **, hold timer **'},
#  '184': {'cat': 'vpn(mpls)',
#   'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'},
#  '185': {'cat': 'vpn(mpls)',
#   'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'},
#  '186': {'cat': 'vpn(mpls)',
#   'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'},
#  '187': {'cat': 'vpn(mpls)',
#   'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'},
#  '188': {'cat': 'network(rsvp)',
#   'lt': '**:rpd[**]: RPD_RSVP_NBRUP: RSVP neighbor ** up on interface **'},
#  '189': {'cat': 'vpn(mpls)',
#   'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'},
#  '190': {'cat': 'vpn(mpls)',
#   'lt': '**:rpd[**]: RPD_MPLS_LSP_UP: MPLS LSP ** up on primary(**) Route **(flag=**) **(flag=** Label=**) **(flag=**) **(flag=** Label=**) **(flag=**) **(Label=**) **(flag=**) **(Label=**) lsp bandwidth ** bps'},
#  '191': {'cat': 'monitor(snmp)',
#   'lt': 'snmpd[**]: SNMPD_TRAP_QUEUE_DRAINED: trap_dq_send_traps: traps queued to ** sent successfully'},
#  '192': {'cat': 'monitor(snmp)', 'lt': 'BULKGET: Master socket closed'},
#  '193': {'cat': 'monitor(snmp)', 'lt': 'bulkget_stop_pfeman_transaction'},
#  '194': {'cat': 'monitor(snmp)',
#   'lt': 'BULKGET disconnected: BULKGET socket closed abruptly'},
#  '195': {'cat': 'system(unix)',
#   'lt': 'init: ** (PID **) exited with status=** Normal Exit'},
#  '196': {'cat': 'system(unix)', 'lt': 'init: ** (PID **) started'},
#  '197': {'cat': 'network(pfe)',
#   'lt': 'pfed: LIBJSNMP_SA_IPC_REG_ROWS: ns_subagent_register_mibs: registering ** rows'},
#  '198': {'cat': 'network(pfe)',
#   'lt': 'pfed: LIBJSNMP_NS_LOG_INFO: INFO: ns_subagent_open_session: NET-SNMP version ** AgentX subagent connected'},
#  '199': {'cat': 'monitor(snmp)',
#   'lt': 'BULKGET: re-connecting to serverRouter'},
#  '200': {'cat': 'monitor(snmp)',
#   'lt': 'Bulkget manager reconnection succeeded after ** tries'},
#  '201': {'cat': 'monitor(snmp)', 'lt': 'BULKGET master RE reconnection made'},
#  '202': {'cat': 'monitor(snmp)', 'lt': 'bulkget_start_pfeman_transaction'},
#  '203': {'cat': 'monitor(snmp)',
#   'lt': 'mib2d[**]: MIB2D_RTSLIB_READ_FAILURE: check_rtsock_rc: failed in reading ifls: ** (Invalid argument)'},
#  '204': {'cat': 'system(ui)',
#   'lt': "mgd[**]: UI_RESTART_EVENT: User '**' restarting daemon 'Management Information Base II process'"},
#  '205': {'cat': 'system(unix)',
#   'lt': 'init: ** (PID **) terminated by signal number **'},
#  '206': {'cat': 'monitor(snmp)',
#   'lt': 'mib2d[**]: LIBJSNMP_SA_IPC_REG_ROWS: ns_subagent_register_mibs: registering ** rows'},
#  '207': {'cat': 'monitor(snmp)',
#   'lt': 'mib2d[**]: LIBJSNMP_NS_LOG_INFO: INFO: ns_subagent_open_session: NET-SNMP version ** AgentX subagent connected'},
#  '208': {'cat': 'monitor(snmp)',
#   'lt': 'mib2d[**]: LIBJSNMP_SA_PARTIAL_SEND_FRAG: Attempted to send ** bytes, actually sent ** bytes'},
#  '209': {'cat': 'monitor(snmp)',
#   'lt': 'mib2d[**]: LIBJSNMP_SA_PARTIAL_SEND_REM: Queuing message remainder, ** bytes'},
#  '210': {'cat': 'monitor(snmp)',
#   'lt': 'mib2d[**]: LIBJSNMP_SA_PARTIAL_FINISH: sms_send_finished: Received socket error: Invalid argument'},
#  '211': {'cat': 'monitor(snmp)',
#   'lt': 'snmpd[**]: SNMPD_TRAP_THROTTLED: trap_queue_send_trap_throttled: traps throttled after ** traps'},
#  '212': {'cat': 'monitor(snmp)',
#   'lt': 'snmpd[**]: SNMPD_THROTTLE_QUEUE_DRAINED: trap_throttle_timer_handler: cleared all throttled traps'},
#  '213': {'cat': 'network(arp)',
#   'lt': 'l2ald[**]: L2ALD_MAC_MOVE_NOTIFICATION: MAC Moves detected in the system'},
#  '214': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [routing-options rib ** static route ** next-hop **]"},
#  '215': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [policy-options prefix-list ** **]"},
#  '216': {'cat': 'mgmt(login)', 'lt': 'login: ** LOGIN ** FROM **'},
#  '217': {'cat': 'mgmt(login)',
#   'lt': 'login: LOGIN_TIMED_OUT: Login attempt timed out after ** seconds'},
#  '218': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [protocols bgp group ** neighbor **]"},
#  '219': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [protocols bgp group ** neighbor ** description] <unconfigured> -> "**"'},
#  '220': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [protocols bgp group ** neighbor ** **]"},
#  '221': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [protocols bgp group ** neighbor ** export **]"},
#  '222': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [protocols bgp group ** neighbor ** peer-as] <unconfigured> -> "**"'},
#  '223': {'cat': 'mgmt(login)',
#   'lt': '[**]: EVT ** ** ** ACCESS ** **:** Login incorrect **#**'},
#  '224': {'cat': 'system(ui)', 'lt': "[**]: RSP ** ** **(**):Can't execute."},
#  '225': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_pp_recv: rejecting connection from ** (** AS **), peer in state **'},
#  '226': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_pp_recv:**: NOTIFICATION sent to **+** (proto): code ** (Cease) subcode ** (Connection Rejected)'},
#  '227': {'cat': 'network(tcp)',
#   'lt': '/kernel: tcp_auth_ok: Packet from **:** ** MD5 digest'},
#  '228': {'cat': 'system(fan)',
#   'lt': 'chassisd[**]: CHASSISD_BLOWERS_SPEED_MEDIUM: Fans and impellers being set to intermediate speed'},
#  '229': {'cat': 'system(fan)',
#   'lt': 'chassisd[**]: CHASSISD_BLOWERS_SPEED: Fans and impellers are now running at normal speed'},
#  '230': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_read_v4_message:**: NOTIFICATION received from ** (** AS **): code ** (Cease) subcode ** (** **)'},
#  '231': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' delete: [protocols bgp group ** neighbor ** export] ""**"'},
#  '232': {'cat': 'mgmt(login)', 'lt': 'login: ** LOGIN ** FROM **, **'},
#  '233': {'cat': 'mgmt(login)',
#   'lt': 'login: LOGIN_ABORTED: Client aborted login'},
#  '234': {'cat': 'mgmt(ftp)', 'lt': 'ftpd[**]: connection from ** (**)'},
#  '235': {'cat': 'mgmt(ftp)', 'lt': 'ftpd[**]: FTP LOGIN FROM ** as **'},
#  '236': {'cat': 'mgmt(ftp)', 'lt': 'ftpd[**]: FTP LOGIN FAILED FROM **'},
#  '237': {'cat': 'mgmt(ftp)', 'lt': 'ftpd[**]: FTP LOGIN FAILED FROM **, **'},
#  '238': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' delete: [interfaces **] "**'},
#  '239': {'cat': 'network(sfp)',
#   'lt': 'MIC(**) link ** SFP laser bias current low ** **'},
#  '240': {'cat': 'network(sfp)',
#   'lt': 'MIC(**) link ** SFP output power low ** **'},
#  '241': {'cat': 'network(sfp)',
#   'lt': 'MIC(**) link ** SFP receive power low ** **'},
#  '242': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [interfaces **] <unconfigured> -> "**"'},
#  '243': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_read_v4_message:**: NOTIFICATION received from ** (** AS **): code ** (Cease) subcode ** (Other Configuration Change)'},
#  '244': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_read_v4_message:**: NOTIFICATION received from ** (** AS **): code ** (Cease) subcode ** (invalid)'},
#  '245': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_recv: read from peer ** (** AS **) failed: Connection reset by peer'},
#  '246': {'cat': 'system(power)',
#   'lt': '[**]: ERR ** ** ** PS ** **:** **, ** is power off.'},
#  '247': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_recv: peer ** (** AS **): received unexpected EOF'},
#  '248': {'cat': 'system(power)',
#   'lt': '[**]: EVT ** ** R8 PS ** **:** **, **, **, ** is normal.'},
#  '249': {'cat': 'interface(agg)',
#   'lt': '[**]: EVT ** ** ** MAC ** **:** Port(**) ** to Channel Group(**).'},
#  '250': {'cat': 'interface(agg)',
#   'lt': '[**]: EVT ** ** ** MAC ** **:** Channel Group(**) is Up.'},
#  '251': {'cat': 'mgmt(su)', 'lt': 'su: BAD SU ** to ** on **'},
#  '252': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [logical-systems ** interfaces ** unit **]"},
#  '253': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [logical-systems ** routing-instances **]"},
#  '254': {'cat': 'system(system_conf)',
#   'lt': 'chassisd[**]: CHASSISD_PARSE_COMPLETE: Using new configuration'},
#  '255': {'cat': 'mgmt(config)',
#   'lt': '**:rpd[**]: RPD_TASK_REINIT: Reinitializing'},
#  '256': {'cat': 'mgmt(config)',
#   'lt': '**: rpd[**]: task_reconfigure reinitializing done'},
#  '257': {'cat': 'network(l2)',
#   'lt': '**: rpd[**]: **: received table message with address family ** op **'},
#  '258': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [chassis redundancy **]"},
#  '259': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' deactivate: [routing-options] "**'},
#  '260': {'cat': 'network(socket)',
#   'lt': '/kernel: peer_inputs: soreceive() error **'},
#  '261': {'cat': 'network(pfe)',
#   'lt': '/kernel: pfe_listener_disconnect: conn dropped: listener idx=**, tnpaddr=**, reason: none'},
#  '262': {'cat': 'network(socket)', 'lt': '/kernel: clearing slave peer'},
#  '263': {'cat': 'system(tnp)',
#   'lt': '/kernel: TNPv3: deleting active neighbor entry ** from **'},
#  '264': {'cat': 'monitor(snmp)',
#   'lt': 'chassisd[**]: CHASSISD_SNMP_TRAP10: SNMP trap generated: Fru Offline (jnxFruContentsIndex **, jnxFruL1Index **, jnxFruL2Index **, jnxFruL3Index **, jnxFruName Routing Engine **, jnxFruType **, jnxFruSlot **, jnxFruOfflineReason **, jnxFruLastPowerOff **, jnxFruLastPowerOn **)'},
#  '265': {'cat': 'system(alarm)',
#   'lt': 'alarmd[**]: Alarm set: RE color=**, class=**, reason=Loss of communication with Backup RE'},
#  '266': {'cat': 'system(alarm)',
#   'lt': 'craftd[**]: Minor alarm set, Loss of communication with Backup RE'},
#  '267': {'cat': 'system(gres)',
#   'lt': 'chassisd[**]: No response from the other routing engine for the last ** seconds.'},
#  '268': {'cat': 'system(tnp)',
#   'lt': '/kernel: TNPv3: adding neighbor ** to interface **'},
#  '269': {'cat': 'monitor(snmp)',
#   'lt': 'chassisd[**]: CHASSISD_SNMP_TRAP7: SNMP trap generated: Fru Online (jnxFruContentsIndex **, jnxFruL1Index **, jnxFruL2Index **, jnxFruL3Index **, jnxFruName Routing Engine **, jnxFruType **, jnxFruSlot **)'},
#  '270': {'cat': 'system(alarm)',
#   'lt': 'alarmd[**]: Alarm cleared: RE color=**, class=**, reason=Loss of communication with Backup RE'},
#  '271': {'cat': 'system(alarm)',
#   'lt': 'craftd[**]: Minor alarm cleared, Loss of communication with Backup RE'},
#  '272': {'cat': 'system(ui)',
#   'lt': "mgd[**]: UI_MASTERSHIP_EVENT: Toggle routing engine mastership by '**'"},
#  '273': {'cat': 'network(pim)',
#   'lt': 'rpd[**]: RPD_PIM_NBRUP: Instance PIM.master: PIM new neighbor ** interface **'},
#  '274': {'cat': 'egp(msdp)',
#   'lt': 'rpd[**]: RPD_MSDP_PEER_UP: MSDP peer ** peer-group ** into ** state'},
#  '275': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_pp_recv:**: NOTIFICATION sent to ** (** AS **): code ** (Cease) subcode ** (Connection collision resolution), Reason: dropping ** (** AS **), connection collision prefers **+** (proto)'},
#  '276': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_pp_recv: dropping ** (** AS **), connection collision prefers **+** (proto)'},
#  '277': {'cat': 'network(pfe)',
#   'lt': 'PFE[**] Fabric Probe Thread Started, interval = ** ms'},
#  '278': {'cat': 'network(pfe)',
#   'lt': 'PFE[**]Aliveness Turning Destination ** on'},
#  '279': {'cat': 'interface(interface)', 'lt': '** plugged in'},
#  '280': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_recv: peer **+** (proto): received unexpected EOF'},
#  '281': {'cat': 'system(alarm)',
#   'lt': 'alarmd[**]: Alarm cleared: RE color=**, class=**, reason=Host ** ECC ** parity error'},
#  '282': {'cat': 'system(alarm)',
#   'lt': 'craftd[**]: Major alarm cleared, Host ** ECC ** parity error'},
#  '283': {'cat': 'mgmt(command)',
#   'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to run command 'get-software-information'"},
#  '284': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' activate: [chassis redundancy **]"},
#  '285': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' activate: [routing-options] "**'},
#  '286': {'cat': 'system(others)',
#   'lt': 'rpd[**]: Read ddl top handle ** for logical-router **'},
#  '287': {'cat': 'system(config_apply)',
#   'lt': 'rpd[**]: task state: <ReConfig Foreground ParseConfig>'},
#  '288': {'cat': 'system(pic)',
#   'lt': '/kernel: pic_listener_connect: conn established: mgmt addr=**,'},
#  '289': {'cat': 'network(pfe)',
#   'lt': '/kernel: if_pfe_peek_peer_info: peer_type **, peer_index **'},
#  '290': {'cat': 'system(gres)',
#   'lt': '/kernel: Peer ** (type ** index **) is not ready for GRES (reinserted)'},
#  '291': {'cat': 'system(gres)', 'lt': '/kernel: Slave is not ready for GRES'},
#  '292': {'cat': 'system(gres)',
#   'lt': '/kernel: Peer ** (type ** index **) is ready for GRES'},
#  '293': {'cat': 'system(gres)', 'lt': '/kernel: Slave is ready for GRES'},
#  '294': {'cat': 'service(ntp)', 'lt': 'xntpd[**]: time reset +** s'},
#  '295': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** interfaces ** unit **]"},
#  '296': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [logical-systems ** interfaces ** unit ** vlan-id] <unconfigured> -> "**"'},
#  '297': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** interfaces ** unit ** family **]"},
#  '298': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [logical-systems ** interfaces ** unit ** family ** mtu] <unconfigured> -> "**"'},
#  '299': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** interfaces ** unit ** family ** address **]"},
#  '300': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** routing-instances ** interface **]"},
#  '301': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <Add> ** index ** <Broadcast Multicast> address #** **'},
#  '302': {'cat': 'monitor(snmp)',
#   'lt': '**: rpd[**]: EVENT <SNMP Index> ** index ** <Broadcast Multicast> address #** **'},
#  '303': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <Instance> ** index ** <Broadcast Multicast> address #** **'},
#  '304': {'cat': 'network(mtu)',
#   'lt': '**: rpd[**]: EVENT <MTU> ** index ** <Broadcast Multicast> address #** **'},
#  '305': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <Flags> ** index ** <Broadcast Multicast> address #** **'},
#  '306': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT Add ** index ** ** -> ** <Broadcast Multicast>'},
#  '307': {'cat': 'system(fpc)',
#   'lt': 'MQ(**): pio_handle(**); pio_read_u64() failed: **(generic failure)! addr=**'},
#  '308': {'cat': 'system(fpc)', 'lt': 'trinity_pio: ** PIO errors occurred'},
#  '309': {'cat': 'system(fpc)',
#   'lt': 'trinity_pio: Last error: ** MQ-0 Trinity PCI ** Write I2C ** ** **'},
#  '310': {'cat': 'mgmt(command)',
#   'lt': "mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to run command 'get-checksum-information path=**'"},
#  '311': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [protocols pim **]"},
#  '312': {'cat': 'system(alarm)',
#   'lt': 'alarmd[**]: Alarm cleared: RE color=**, class=**, reason=Backup RE Active'},
#  '313': {'cat': 'system(alarm)',
#   'lt': 'craftd[**]: Minor alarm cleared, Backup RE Active'},
#  '314': {'cat': 'network(pim)',
#   'lt': 'rpd[**]: RPD_PIM_NBRDOWN: Instance PIM.master: PIM neighbor ** (**) removed due to: the interface is purged'},
#  '315': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT Flags ** index ** ** -> (**) <Broadcast Multicast>'},
#  '316': {'cat': 'egp(bgp)',
#   'lt': '**: rpd[**]: task_connect: task **+** addr **+**: No route to host'},
#  '317': {'cat': 'egp(bgp)',
#   'lt': '**: rpd[**]: bgp_connect_start: connect ** (** AS **): No route to host'},
#  '318': {'cat': 'igp(ospf)',
#   'lt': '**:rpd[**]: RPD_OSPF_NBRUP: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to ExchangeDone (event reason: DBD exchange of slave completed)'},
#  '319': {'cat': 'igp(ospf)',
#   'lt': 'rpd[**]: RPD_OSPF_NBRUP: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to ExchangeDone (event reason: DBD exchange of ** completed)'},
#  '320': {'cat': 'mgmt(config_process)',
#   'lt': "eventd[**]: EVENTD_POLICY_LIMIT_EXCEEDED: Unable to execute policy '**' because current number of policies (**) exceeds system limit (**)"},
#  '321': {'cat': 'igp(ospf)',
#   'lt': '**:rpd[**]: RPD_OSPF_NBRUP: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to ExchangeDone (event reason: ** exchange of ** completed)'},
#  '322': {'cat': 'system(pic)',
#   'lt': 'CMT: Bypass ASIC attach to logic PIC (**:**)'},
#  '323': {'cat': 'system(fpc)', 'lt': 'ix_chip_pre_init: SYSIF PLL lock OK!'},
#  '324': {'cat': 'system(others)', 'lt': 'bringup_pcie_common: PCIe status **'},
#  '325': {'cat': 'system(others)',
#   'lt': 'bringup_pcie_common: PCIe link training took **'},
#  '326': {'cat': 'system(fpc)',
#   'lt': 'IXCHIP(**): jtag id ** major rev ** minor rev **'},
#  '327': {'cat': 'system(fpc)', 'lt': 'Initializing IX[**] JSPEC'},
#  '328': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: ** (** AS **): reseting pending active connection'},
#  '329': {'cat': 'egp(bgp)',
#   'lt': '**: rpd[**]: ** (** AS **): reseting pending active connection'},
#  '330': {'cat': 'network(routing)',
#   'lt': 'rpd[**]: RPD_KRT_Q_RETRIES: Route Update: No buffer space available'},
#  '331': {'cat': 'monitor(snmp)',
#   'lt': 'snmpd[**]: LIBJSNMP_SA_PARTIAL_SEND_FRAG: Attempted to send ** bytes, actually sent ** bytes'},
#  '332': {'cat': 'monitor(snmp)',
#   'lt': 'snmpd[**]: LIBJSNMP_SA_PARTIAL_SEND_REM: Queuing message remainder, ** bytes'},
#  '333': {'cat': 'mgmt(ui_error)',
#   'lt': "mgd[**]: UI_READ_TIMEOUT: Timeout on read of peer 'snmp'"},
#  '334': {'cat': 'mgmt(ui_error)',
#   'lt': "mgd[**]: UI_RECONN_READ_FAILED: Invalid response from peer 'snmp': ** Connection unexpectedly terminated"},
#  '335': {'cat': 'interface(interface)',
#   'lt': '/kernel: **: promiscuous mode **'},
#  '336': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' deactivate: [protocols bgp group ** neighbor **]"},
#  '337': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' deactivate: [protocols bgp group ** neighbor **] "**'},
#  '338': {'cat': 'system(ui)',
#   'lt': "mgd[**]: UI_LOAD_EVENT: User '**' is performing a 'rollback **'"},
#  '339': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' rollback: **"},
#  '340': {'cat': 'system(ui)',
#   'lt': 'mgd[**]: UI_LOAD_JUNOS_DEFAULT_FILE_EVENT: Loading the ** config from **'},
#  '341': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [system root-authentication **]"},
#  '342': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [system login user ** authentication **]"},
#  '343': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [logical-systems ** protocols bgp group ** **]"},
#  '344': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [logical-systems ** protocols ** area ** interface ** authentication md5 ** key]"},
#  '345': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [protocols bgp group ** **]"},
#  '346': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [protocols ospf area ** interface ** authentication md5 ** key]"},
#  '347': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_SET_SECRET: User '**' set: [security ipsec security-association OSPF3IPSEC manual direction bidirectional authentication key **]"},
#  '348': {'cat': 'mgmt(config)',
#   'lt': 'mcsn[**]: MCSN_TASK_REINIT: Reinitializing'},
#  '349': {'cat': 'system(None)',
#   'lt': 'ffp[**]: "dynamic-profiles": Profiles are being modified'},
#  '350': {'cat': 'system(fpc)',
#   'lt': 'mspd[**]: Chassis/fpc configuration is empty'},
#  '351': {'cat': 'system(unix)',
#   'lt': 'inetd[**]: Number of ssh connections at max limit (**)'},
#  '352': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [policy-options prefix-list **]"},
#  '353': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [policy-options prefix-list **]"},
#  '354': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [policy-options prefix-list ** apply-path] <unconfigured> -> "protocols bgp group <*> neighbor <*:*>"'},
#  '355': {'cat': 'system(ui)',
#   'lt': "mgd[**]: UI_LOAD_EVENT: User '**' is performing a 'rollback'"},
#  '356': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' activate: [protocols bgp group ** neighbor **] "**'},
#  '357': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_COMMIT: User '**' requested 'commit synchronize' operation (comment: none)"},
#  '358': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' activate: [protocols pim **]"},
#  '359': {'cat': 'mgmt(ui_error)',
#   'lt': 'rpd[**]: UI_CONFIGURATION_ERROR: Process: rpd, path: <none>, statement: <none>, Policy error: Policy ** referenced but not defined'},
#  '360': {'cat': 'system(None)', 'lt': '/kernel: : port status changed'},
#  '361': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <Bandwidth> index ** <Up Broadcast Multicast> address #** **'},
#  '362': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <Bandwidth> ** index ** <Up Broadcast Multicast> address #** **'},
#  '363': {'cat': 'interface(if_event)',
#   'lt': 'mcsn[**]: EVENT <Bandwidth> index ** <Up Broadcast Multicast> address #** **'},
#  '364': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT <Bandwidth> index ** <Up Broadcast Multicast> address #** **'},
#  '365': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT <Bandwidth> ** index ** <Up Broadcast Multicast> address #** **'},
#  '366': {'cat': 'interface(agg)',
#   'lt': '/kernel: ae_bundlestate_ifd_change: bundle **: bundle IFD minimum links not met ** < **'},
#  '367': {'cat': 'interface(agg)',
#   'lt': '/kernel: ae_bundlestate_ifd_change: bundle **: bundle IFD state changed to **'},
#  '368': {'cat': 'system(cos)',
#   'lt': '/kernel: GENCFG: op ** (CoS) failed; err ** (Invalid)'},
#  '369': {'cat': 'interface(if_event)',
#   'lt': 'mcsn[**]: EVENT <Bandwidth UpDown> index ** <Broadcast Multicast> address #** **'},
#  '370': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <Bandwidth **> index ** <Broadcast Multicast> address #** **'},
#  '371': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT <Bandwidth UpDown> index ** <Broadcast Multicast> address #** **'},
#  '372': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT <Bandwidth> ** index ** <Broadcast Multicast> address #** **'},
#  '373': {'cat': 'network(rsvp)',
#   'lt': '**:rpd[**]: RPD_RSVP_BACKUP_DOWN: Backup for protecting LSP ** down, using bypass Bypass->**, reason: Deleting protected LSP'},
#  '374': {'cat': 'system(fpc)',
#   'lt': 'MQchip ** XE ** Throttle: Last ** seconds have seen interrupt throttling at least once per second'},
#  '375': {'cat': 'igp(ospf)',
#   'lt': '**:rpd[**]: RPD_OSPF_NBRDOWN: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to InActiveTimer (event reason: neighbor was inactive and declared dead)'},
#  '376': {'cat': 'network(rsvp)',
#   'lt': '**:rpd[**]: RPD_RSVP_BYPASS_DOWN: RSVP bypass Bypass->**>** for protecting interface ** went down, reason: RSVP session down'},
#  '377': {'cat': 'network(rsvp)',
#   'lt': '**:rpd[**]: RPD_RSVP_BYPASS_DOWN: RSVP bypass Bypass->** for protecting interface ** went down, reason: RSVP session down'},
#  '378': {'cat': 'network(rsvp)',
#   'lt': '**:rpd[**]: RPD_RSVP_BACKUP_DOWN: Backup for protecting LSP ** down, using bypass Bypass->**, reason: RSVP session down'},
#  '379': {'cat': 'igp(ospf)',
#   'lt': 'rpd[**]: RPD_OSPF_NBRDOWN: OSPF neighbor ** (realm ** ** area **) state changed from ** to ** due to InActiveTimer (event reason: neighbor was inactive and declared dead)'},
#  '380': {'cat': 'system(None)', 'lt': 'NH id: **, child_nh ** does not exist'},
#  '381': {'cat': 'network(pim)',
#   'lt': 'rpd[**]: RPD_PIM_NBRDOWN: Instance PIM.master: PIM neighbor ** (**) removed due to: the interface did not receive a hello message from the neighbor within the hold-time period (timeout)'},
#  '382': {'cat': 'network(routing)',
#   'lt': '**:rpd[**]: RPD_KRT_Q_RETRIES: Route Update: No buffer space available'},
#  '383': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT <Bandwidth UpDown> ** index ** <Up Broadcast Multicast> address #** **'},
#  '384': {'cat': 'interface(if_event)',
#   'lt': 'mcsn[**]: EVENT <Bandwidth UpDown> index ** <Up Broadcast Multicast> address #** **'},
#  '385': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT <Bandwidth UpDown> ** index ** <Up Broadcast Multicast> address #** **'},
#  '386': {'cat': 'interface(if_event)',
#   'lt': 'rpd[**]: EVENT Flags ** index ** ** -> (**) <Up Broadcast Multicast Localup>'},
#  '387': {'cat': 'network(rsvp)',
#   'lt': '**:rpd[**]: RPD_RSVP_BYPASS_UP: RSVP bypass Bypass->** for protecting interface ** came up'},
#  '388': {'cat': 'network(pfe)',
# ...
#   'lt': 'rpd[**]: bgp_read_message: peer ** (** AS **): Notification arrived, expected Open'},
#  '871': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_read_message:**: NOTIFICATION received from ** (** AS **): code ** (Cease) subcode ** (Connection Rejected)'},
#  '872': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' delete: [protocols bgp group ** export] ""**"'},
#  '873': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [policy-options as-path-group **]"},
#  '874': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [policy-options as-path-group ** as-path **] <unconfigured> -> "**+**"'},
#  '875': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [policy-options as-path-group ** as-path **] <unconfigured> -> "**+**+**"'},
#  '876': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [policy-options policy-statement ** term ** then community delete **]"},
#  '877': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [policy-options policy-statement ** then] "reject -> "**"'},
#  '878': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [policy-options policy-statement ** term **]"},
#  '879': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [policy-options policy-statement ** term ** then local-preference] <unconfigured> -> "**"'},
#  '880': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' delete: [policy-options policy-statement ** term ** then local-preference] "**'},
#  '881': {'cat': 'system(None)',
#   'lt': 'tnp.tftpd[**]: TFTPD_CONNECT_INFO: TFTP write from address ** port ** file **'},
#  '882': {'cat': 'system(None)',
#   'lt': "tnp.tftpd[**]: TFTPD_RECVCOMPLETE_INFO: Received ** blocks of ** size for file '**'"},
#  '883': {'cat': 'system(fpc)',
#   'lt': 'LUCHIP(**) ** Errors ucode data error **'},
#  '884': {'cat': 'system(unix)',
#   'lt': 'inetd[**]: accept (for **): Software caused connection abort'},
#  '885': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_recv: read from peer **+** (proto) failed: Connection reset by peer'},
#  '886': {'cat': 'system(csu)',
#   'lt': '[**]: ERR ** ** ** CSU ** **:** Fatal error detected on other ** This system (CSU2) is active.'},
#  '887': {'cat': 'system(csu)',
#   'lt': '[**]: EVT ** ** ** CSU ** **:** Other system recovered from fatal error. This system (**) is active.'},
#  '888': {'cat': 'system(None)',
#   'lt': '[**]: EVT ** ** ** NIF NIF:** ** **:** NIF board connected.'},
#  '889': {'cat': 'system(None)',
#   'lt': '[**]: EVT ** ** R6 NIF NIF:** ** **:** NIF initialized.'},
#  '890': {'cat': 'system(None)',
#   'lt': '[**]: EVT ** ** ** CONFIG ** **:** The interface configuration commands of ** changed, because ** board connected.'},
#  '891': {'cat': 'interface(agg)',
#   'lt': '[**]: EVT ** ** ** MAC ** **:** Channel Group(**) is Down - All port detached.'},
#  '892': {'cat': 'interface(agg)',
#   'lt': '[**]: EVT ** ** ** MAC ** **:** Port(**) removed from Channel Group(**).'},
#  '893': {'cat': 'network(mtu)',
#   'lt': '**: rpd[**]: EVENT <MTU> index ** <Up Broadcast Loopback Multicast>'},
#  '894': {'cat': 'network(mtu)',
#   'lt': 'mcsn[**]: EVENT <MTU> index ** <Up Broadcast Loopback Multicast>'},
#  '895': {'cat': 'network(mtu)',
#   'lt': 'rpd[**]: EVENT <MTU> index ** <Up Broadcast Loopback Multicast>'},
#  '896': {'cat': 'service(ntp)', 'lt': 'xntpd[**]: no servers reachable'},
#  '897': {'cat': 'system(cos)',
#   'lt': 'cosd[**]: COSD_CLASS_8021P_UNSUPPORTED: ieee-802.1 classifier is not valid on interface **'},
#  '898': {'cat': 'egp(msdp)',
#   'lt': 'rpd[**]: RPD_MSDP_SRC_ACTIVE_OVER_THRESH: Number of MSDP source-active messages about instance "**" exceeded configured threshold'},
#  '899': {'cat': 'egp(msdp)',
#   'lt': 'rpd[**]: RPD_MSDP_SRC_ACTIVE_UNDER_THRESH: Number of MSDP source-active messages about instance "**" no longer exceeded configured threshold'},
#  '900': {'cat': 'monitor(syslog)', 'lt': '** last message repeated ** times'},
#  '901': {'cat': 'mgmt(ssh)',
#   'lt': '** sshd[**]: Accepted password for ** from ** port ** ssh2'},
#  '902': {'cat': 'system(ui)',
#   'lt': "** mgd[**]: UI_AUTH_EVENT: Authenticated user '**' at permission level '**'"},
#  '903': {'cat': 'system(ui)',
#   'lt': "** mgd[**]: UI_LOGIN_EVENT: User '**' login, class '**' [**], ssh-connection '** ** ** **', client-mode 'cli'"},
#  '904': {'cat': 'system(ui)',
#   'lt': "** mgd[**]: UI_LOGOUT_EVENT: User '**' logout"},
#  '905': {'cat': 'system(cron)',
#   'lt': '** /usr/sbin/cron[**]: (**) CMD (newsyslog)'},
#  '906': {'cat': 'service(ntp)', 'lt': '** xntpd[**]: NTP Server Unreachable'},
#  '907': {'cat': 'service(ntp)',
#   'lt': '** xntpd[**]: synchronized to **, stratum=**'},
#  '908': {'cat': 'service(ntp)',
#   'lt': '** xntpd: NTPD_CHANGED_TIME: time reset +** s'},
#  '909': {'cat': 'service(ntp)', 'lt': '** xntpd[**]: time reset +** s'},
#  '910': {'cat': 'service(ntp)',
#   'lt': '** xntpd: kernel time sync disabled **'},
#  '911': {'cat': 'service(ntp)',
#   'lt': '** xntpd: synchronized to **, stratum=**'},
#  '912': {'cat': 'service(ntp)', 'lt': '** xntpd: kernel time sync enabled **'},
#  '913': {'cat': 'mgmt(command)',
#   'lt': "** mgd[**]: UI_JUNOSCRIPT_CMD: User '(unauthenticated user)' used JUNOScript client to run command 'request-authentication user=** logname=** host=** agent=mgd current-directory=/var/tmp pid=** ppid=**'"},
#  '914': {'cat': 'system(ui)',
#   'lt': "** mgd[**]: UI_LOGIN_EVENT: User '**' login, class '**' **[**], ssh-connection '', client-mode 'junoscript'"},
#  '915': {'cat': 'mgmt(command)',
#   'lt': "** mgd[**]: UI_JUNOSCRIPT_CMD: User '**' used JUNOScript client to run command '**'"},
#  '916': {'cat': 'system(ui)',
#   'lt': "** mgd[**]: UI_CHILD_START: Starting child '**'"},
#  '917': {'cat': 'system(ui)',
#   'lt': "** mgd[**]: UI_CHILD_STATUS: Cleanup child '**', PID **, status **"},
#  '918': {'cat': 'system(ui)',
#   'lt': "** mgd[**]: UI_DBASE_LOGIN_EVENT: User '**' entering configuration mode"},
#  '919': {'cat': 'mgmt(config)',
#   'lt': "** mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [snmp interface **]"},
#  '920': {'cat': 'mgmt(config)',
#   'lt': "** mgd[**]: UI_COMMIT: User '**' requested 'commit' operation (comment: none)"},
#  '921': {'cat': 'system(ui)',
#   'lt': "** mgd[**]: UI_DBASE_LOGOUT_EVENT: User '**' exiting configuration mode"},
#  '922': {'cat': 'system(cron)',
#   'lt': '** /usr/sbin/cron[**]: (**) CMD (adjkerntz -a)'},
#  '923': {'cat': 'system(cron)',
#   'lt': '** /usr/sbin/cron[**]: (**) CMD (/usr/sbin/check-support -l)'},
#  '924': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [protocols bgp group **]"},
#  '925': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [policy-options policy-statement **]"},
#  '926': {'cat': 'mgmt(login)',
#   'lt': '** login: Login attempt for user ** from host **'},
#  '927': {'cat': 'mgmt(login)',
#   'lt': '** login[**]: LOGIN_INFORMATION: User ** logged in from host ** on device **'},
#  '928': {'cat': 'system(ui)',
#   'lt': "** mgd[**]: UI_LOGIN_EVENT: User '**' login, class '**' [**], ssh-connection '', client-mode 'cli'"},
#  '929': {'cat': 'system(boot)',
#   'lt': "** mgd[**]: UI_REBOOT_EVENT: System halted by '**'"},
#  '930': {'cat': 'system(boot)', 'lt': '** shutdown: halt by **:'},
#  '931': {'cat': 'system(unix)',
#   'lt': '** init: tnp-process (PID **) terminate signal sent'},
#  '932': {'cat': 'system(unix)',
#   'lt': '** init: management (PID **) terminate signal sent'},
#  '933': {'cat': 'system(unix)',
#   'lt': '** init: inet-process (PID **) terminate signal sent'},
#  '934': {'cat': 'system(unix)',
#   'lt': '** init: ** (PID **) terminate signal sent'},
#  '935': {'cat': 'system(unix)',
#   'lt': '** init: chassis-manager (PID **) terminate signal sent'},
#  '936': {'cat': 'system(None)',
#   'lt': '** chassism[**]: cm_mpfe_intr_task_pre_terminate: doing ifd_walk to force the link down'},
#  '937': {'cat': 'system(unix)',
#   'lt': '** init: software-forwarding (PID **) terminate signal sent'},
#  '938': {'cat': 'system(None)',
#   'lt': '** chassism[**]: ethswitch_eth_devstop: called for port **'},
#  '939': {'cat': 'system(unix)',
#   'lt': '** init: virtual-chassis-control (PID **) terminate signal sent'},
#  '940': {'cat': 'system(unix)',
#   'lt': '** sfid[**]: TASK_SIGNAL_TERMINATE: termination signal no- ** received'},
#  '941': {'cat': 'system(unix)',
#   'lt': '** vccpd[**]: TASK_SIGNAL_TERMINATE: termination signal no- ** received'},
#  '942': {'cat': 'system(unix)',
#   'lt': '** vccpd[**]: TASK_EXIT: Exit vccpd[**] version ** built by builder on ** ** **, caller **'},
#  '943': {'cat': 'system(unix)',
#   'lt': '** init: packet-forwarding-engine (PID **) terminate signal sent'},
#  '944': {'cat': 'network(socket)',
#   'lt': '** /kernel: peer_inputs: soreceive() error **'},
#  '945': {'cat': 'system(unix)',
#   'lt': '** init: watchdog (PID **) terminate signal sent'},
#  '946': {'cat': 'system(unix)',
#   'lt': '** init: chassis-control (PID **) terminate signal sent'},
#  '947': {'cat': 'system(unix)',
#   'lt': '** sfid[**]: TASK_EXIT: Exit sfid[**] version built by on , caller **'},
#  '948': {'cat': 'network(stp)',
#   'lt': '** eswd[**]: ESWD_STP_STATE_CHANGE_INFO: STP state for interface ** context id ** changed from ** to **'},
#  '949': {'cat': 'monitor(snmp)',
#   'lt': '** snmpd[**]: SNMPD_THROTTLE_QUEUE_DRAINED: trap_throttle_timer_handler: cleared all throttled traps'},
#  '950': {'cat': 'service(ntp)', 'lt': '** xntpd: NTP Server Unreachable'},
#  '951': {'cat': 'monitor(snmp)',
#   'lt': '** snmpd[**]: SNMPD_TRAP_QUEUE_DRAINED: trap_dq_send_traps: traps queued to ** sent successfully'},
#  '952': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_pp_recv:**: NOTIFICATION sent to **+** (proto): code ** (Open Message Error) subcode ** (bad peer AS number), Reason: no group for **+** (proto) from AS ** found (peer as mismatch), dropping him'},
#  '953': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_process_open:**: NOTIFICATION sent to ** (** AS **): code ** (Open Message Error) subcode ** (bad peer AS number), Reason: peer ** (** AS **) claims **, ** configured'},
#  '954': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [protocols bgp group ** neighbor ** peer-as] "** -> "**"'},
#  '955': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_peer_mgmt_clear:**: NOTIFICATION sent to ** (** AS **): code ** (Cease) subcode ** (Administratively Reset), Reason: Management session cleared BGP neighbor'},
#  '956': {'cat': 'system(fpc)',
#   'lt': 'LUCHIP(**) RD_NACK ** AP[**] TOE Read **'},
#  '957': {'cat': 'system(fpc)',
#   'lt': 'LUCHIP(**) IDMEM Parity error in Bank **, Count **, IDMEM Bank ** Offset ** IDMEM[**]**'},
#  '958': {'cat': 'mgmt(enable)',
#   'lt': '[**]: RSP ** ** **(**):enable: Login timed out after ** seconds.'},
#  '959': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [logical-systems ** routing-instances ** **]"},
#  '960': {'cat': 'interface(if_event)',
#   'lt': '**: rpd[**]: EVENT Add ** index ** ** -> ** <Up Broadcast Multicast Localup>'},
#  '961': {'cat': 'system(None)',
#   'lt': '/kernel: Subnet router anycast address not added for interface address ** prefix length **'},
#  '962': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' activate: [forwarding-options sampling instance ** family ** output flow-server **]"},
#  '963': {'cat': 'system(pci)', 'lt': 'PCI ERROR: **:**:**:** Timestamp **'},
#  '964': {'cat': 'system(pci)', 'lt': 'PCI ERROR: **:**:**:** err_dr : **'},
#  '965': {'cat': 'system(pci)',
#   'lt': 'PCI ERROR: **:**:**:** err_cap_stat : **'},
#  '966': {'cat': 'system(pci)',
#   'lt': 'PCI ERROR: **:**:**:** err_cap[0->**] : ** ** ** **'},
#  '967': {'cat': 'system(pci)',
#   'lt': 'PCI ERROR: **:**:**:** (**) Status : **'},
#  '968': {'cat': 'system(pci)',
#   'lt': 'PCI ERROR: **:**:**:** (**) ** status : **'},
#  '969': {'cat': 'system(pci)',
#   'lt': 'PCI ERROR: **:**:**:** (**) Link status : **'},
#  '970': {'cat': 'system(pci)',
#   'lt': 'PCI ERROR: **:**:**:** (**) Uncorrectable error status : **'},
#  '971': {'cat': 'system(pci)',
#   'lt': 'PCI ERROR: **:**:**:** (**) Advanced error cap & ctl : **'},
#  '972': {'cat': 'system(pci)',
#   'lt': 'PCI ERROR: **:**:**:** (**) Header log ** : **'},
#  '973': {'cat': 'system(pci)',
#   'lt': 'PCI ERROR: **:**:**:** (**) Root error status : **'},
#  '974': {'cat': 'system(pci)',
#   'lt': 'PCI ERROR: **:**:**:** (**) Error source ID : **'},
#  '975': {'cat': 'monitor(snmp)',
#   'lt': 'snmpd[**]: SNMPD_AUTH_FAILURE: nsa_log_community: unauthorized SNMP community from ** to ** community name (**)'},
#  '976': {'cat': 'system(None)',
#   'lt': '[**]: EVT ** ** ** CONFIG ** **:** Configuration access management error. process information:pid **:time ** ** ** ** **'},
#  '977': {'cat': 'egp(msdp)',
#   'lt': 'rpd[**]: RPD_MSDP_PEER_DOWN: MSDP peer ** peer-group ** out of Established state'},
#  '978': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_OTHER: User \'**\' delete: [routing-options static route ** preference] "**'},
#  '979': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [routing-options static route ** preference]"},
#  '980': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [routing-options aggregate route **]"},
#  '981': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' delete: [routing-options static route **]"},
#  '982': {'cat': 'network(pfe)',
#   'lt': 'pfed: device getnext failed: Invalid argument'},
#  '983': {'cat': 'system(fpc)',
#   'lt': 'LUCHIP(**): pio_handle(**); jspec_pio_read_u256 failed: **(generic failure)! gumem[%d].ucode.instr[%d]-addr=**'},
#  '984': {'cat': 'system(fpc)',
#   'lt': 'LUCHIP(**) GUMEM[**].ucode.instr[**] read error.'},
#  '985': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_process_caps: mismatch NLRI with ** (** AS **): peer: <** ** **>(**) us: <**>(**)'},
#  '986': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [policy-options policy-statement ** term ** from community **]"},
#  '987': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [policy-options policy-statement ** term ** then] <unconfigured> -> "**"'},
#  '988': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [policy-options policy-statement ** term ** from ** ** orlonger next] <unconfigured> -> "**"'},
#  '989': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [policy-options policy-statement ** term ** from prefix-list **]"},
#  '990': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [policy-options policy-statement ** term ** then metric] <**> -> "**"'},
#  '991': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [protocols bgp group ** family ** unicast prefix-limit maximum] <unconfigured> -> "**"'},
#  '992': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [protocols bgp group ** family ** unicast prefix-limit teardown]"},
#  '993': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [protocols bgp group ** family ** unicast prefix-limit teardown] <unconfigured> -> "**"'},
#  '994': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [protocols bgp group ** family ** unicast prefix-limit teardown **]"},
#  '995': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [protocols bgp group ** family ** unicast prefix-limit teardown idle-timeout] <unconfigured> -> "**"'},
#  '996': {'cat': 'mgmt(config)',
#   'lt': 'mgd[**]: UI_CFG_AUDIT_SET: User \'**\' set: [protocols bgp group ** peer-as] <**> -> "**"'},
#  '997': {'cat': 'mgmt(config)',
#   'lt': "mgd[**]: UI_CFG_AUDIT_OTHER: User '**' set: [protocols bgp group ** neighbor ** import **]"},
#  '998': {'cat': 'egp(bgp)',
#   'lt': 'rpd[**]: bgp_set_peer_if: BGP peer ** (** AS **) interface not found. Leaving peer idled'},
#  '999': {'cat': 'system(None)',
#   'lt': '[**]: RSP ** ** **(**):interface : Duplicate translated-tag.[**]'},
#  ...}

# %%
# LTレベルの共起
cor_df = pd.DataFrame(index=np.arange(len(word_dict)), columns=np.arange(len(word_dict)), dtype=int)
cor_df = cor_df.fillna(0)

for s in corpus:
    for a,b in itertools.combinations(s, 2):
        ida = int(a[0])
        idb = int(b[0])
        cor_df[ida][idb] += 1
        cor_df[idb][ida] += 1

cor_list = []
for a,b in itertools.combinations(np.arange(len(word_dict)), 2):
    if cor_df[a][b] != 0 :
        cor_list.append([(a, b) , cor_df[a][b]])
        
for i in tqdm.tqdm(sorted(cor_list, key=lambda x:x[1], reverse=True)):
    a,b = i[0]
    print(inv_word_dict[a], inv_word_dict[b], i[1])
    print("\t simpson:", i[1]/min(word_cnt[inv_word_dict[a]], word_cnt[inv_word_dict[b]]))
    print("\t jaccard:", i[1]/(word_cnt[inv_word_dict[a]] + word_cnt[inv_word_dict[b]] - i[1]))
    print()

# %%
G = nx.DiGraph()
nx.set_node_attributes

for i in sorted(cor_list, key=lambda x:x[1], reverse=True):
    if i[1] > 9: # 共起が10回以上
        a,b = i[0]
        simpson = i[1]/min(word_cnt[inv_word_dict[a]], word_cnt[inv_word_dict[b]])
        jaccard = i[1]/(word_cnt[inv_word_dict[a]] + word_cnt[inv_word_dict[b]] - i[1])
        
        print(simpson)
        if simpson > 0.7:
            if a not in G.nodes:
                G.add_node(inv_word_dict[a])

            if b not in G.nodes:
                G.add_node(inv_word_dict[b])

            src = inv_word_dict[a] if np.argmin([word_cnt[inv_word_dict[a]], word_cnt[inv_word_dict[b]]]) == 0 else inv_word_dict[b]
            dst = inv_word_dict[a] if src == inv_word_dict[b] else inv_word_dict[b]
            G.add_edge(src, dst, weight=jaccard)

# %%
json_data = nx.node_link_data(G)
f = open("nx.json", "w")
json.dump(json_data, f, ensure_ascii=False, indent=4, sort_keys=True, separators=(',', ': '))
f.close()

# %%
plt.figure(figsize=(13, 13))
nx.draw_networkx(G, pos=nx.shell_layout(G))
plt.show()

# %% [markdown]
# ## LDA
#
# - __getItem__での結果は，inference(collect_stats=True)の結果をノーマライズしたものっぽい

# %%
for cat, lts in lt_per_cat.items():
    print(cat)

# %%
tmp = []
eval_corpus = []
eval_corpus_ltids = []
for ltid, i in enumerate(corpus):
    if word_dict['ui'] not in [j[0] for j in i]: # uiを弾く(550番)
        tmp.append(tuple(sorted(i)))
        eval_corpus.append(i)
        eval_corpus_ltids.append(ltid)
    
print(len(tmp))
set_corpus = list(set(tmp))

# %%
lda = gensim.models.ldamodel.LdaModel(
                                      #corpus=corpus, 
                                      corpus=set_corpus,
                                      chunksize=2,
                                      num_topics=40, 
                                      id2word=inv_word_dict, 
                                      minimum_probability=1e-8, 
                                      #gamma_threshold=1e-5,
#                                       eval_every=1,
                                      iterations=400,
#                                       alpha='auto', 
#                                       eta='auto', 
                                      decay=1.0,
                                      passes=1,
#                                      update_every=0,
#                                       random_state=10,
                                      per_word_topics=True)

# %%
inf_topic_words = {}
for topic in range(lda.num_topics):
    print(topic, [inv_word_dict[i[0]] for i in lda.get_topic_terms(topic)])
    inf_topic_words[topic] = [inv_word_dict[i[0]] for i in lda.get_topic_terms(topic)]

# %%
t = []
for lt in lt_per_cat["service(ntp)"]:                
    c = list(collections.Counter([word_dict[w] for w in string_to_corpus(lt, max_len=7)]).items())
    topic_dist, word_topic, word_topic_dist = lda[c]
    inf_topic = np.argmax(np.array([t[1] for t in topic_dist]))
    t.append(inf_topic)
    
for k,v in collections.Counter(t).items():
    print(k,"\t",v)
    
print("alarm")
t = []
for lt in lt_per_cat["system(alarm)"]:
    c = list(collections.Counter([word_dict[w] for w in string_to_corpus(lt, max_len=7)]).items())
    topic_dist, word_topic, word_topic_dist = lda[c]
    inf_topic = np.argmax(np.array([t[1] for t in topic_dist]))
    t.append(inf_topic)
    
for k,v in collections.Counter(t).items():
    print(k,"\t",v)

# %%
results = []
for cs in range(1, 20):
    for i in range(10):
        lda = gensim.models.ldamodel.LdaModel(
                                              corpus=set_corpus,
                                              chunksize=cs,
                                              num_topics=50, 
                                              id2word=inv_word_dict, 
                                              minimum_probability=1e-8, 
                                              iterations=800,
                                              decay=1.0,
                                              passes=1,
                                              per_word_topics=True)

        res = []
        for lt in lt_per_cat["service(ntp)"]:                
            c = list(collections.Counter([word_dict[w] for w in string_to_corpus(lt, max_len=7)]).items())
            topic_dist, word_topic, word_topic_dist = lda[c]
            inf_topic = np.argmax(np.array([t[1] for t in topic_dist]))
            res.append(inf_topic)
        results.append((cs, i, res))

# %%
for cs,i,r in results:
    e = entropy(list(collections.Counter(r).values()))
    if e < 0.8:
        print("ChunkSize=", cs, "\t", i)
        print("\t", collections.Counter(r))
        print("\t entropy:", entropy(list(collections.Counter(r).values())))
        print()

# %%
results =  [np.argmax(l) for l in lda.inference(eval_corpus)[0]]

inference_results = {}
for a,b in zip(eval_corpus, results):
    if b in inference_results:
        inference_results[b].append([inv_word_dict[c[0]] for c in a])
    else:
        inference_results[b] = [[inv_word_dict[c[0]] for c in a]]

# %% [markdown]
# ### eval
#
# - 外れたやつについて，調査

# %%
for a,b in lt_per_cat.items():
    print(a, len(b))

# %%
for i in range(len(word_dict)):
    print(inv_word_dict[i], lda.get_term_topics(i))

# %%
word_dict['unreachable']

# %%
# inf_per_cat = {}
for cat,lts in lt_per_cat.items():
    
    if cat == "service(ntp)" or cat == "system(alarm)" or cat == "egp(bgp)" or cat == "network(mtu)":
        print(cat)
#     inf_per_cat[cat] = []
        for lt in lts:
            c = list(collections.Counter([word_dict[w] for w in string_to_corpus(lt, max_len=7)]).items())
            topic_dist, word_topic, word_topic_dist = lda[c]
            inf_topic = np.argmax(np.array([t[1] for t in topic_dist]))
#             inf_per_cat[cat].append(inf_topic)
            print("\t", inf_topic, ",", lt)
    #         print()

# %%
lt_vecs = {}
for cat,lts in lt_per_cat.items():
    for lt in lts:
        c = list(collections.Counter([word_dict[w] for w in string_to_corpus(lt, max_len=7)]).items())
        topic_dist, word_topic, word_topic_dist = lda[c]
        topic_vec = np.array([t[1] for t in  topic_dist])
        lt_vecs[lt] = topic_vec

# %%
from sklearn.manifold import TSNE

x = np.array(list(lt_vecs.values()))
tsne = TSNE(
    n_components=3, #ここが削減後の次元数です．
    init='random',
    random_state=101,
    method='barnes_hut',
    n_iter=800,
    verbose=2
).fit_transform(x)

# %%
lt_cat = {vv:k.split('(')[0]  for k,v in  lt_per_cat.items() for vv in v}
cats = [lt_cat[k] for k in list(lt_vecs.keys())]

# %%
import plotly.offline as offline
import plotly.graph_objs as go
offline.init_notebook_mode()

from sklearn import preprocessing

le = preprocessing.LabelEncoder()
colors = le.fit_transform(cats)

# 3Dの散布図が作れるScatter3dを使います．
trace1 = go.Scatter3d(
    x=tsne[:,0], # それぞれの次元をx, y, zにセットするだけです．
    y=tsne[:,1],
    z=tsne[:,2],
    mode='markers',
    text=list(lt_vecs.keys()),
    marker=dict(
        sizemode='diameter',
        color = colors,
        colorscale = 'Portland',
        colorbar=dict(
            title='Colorbar',
            tickvals = np.arange(len(le.classes_)),
            ticktext = le.classes_
        ),
        line=dict(color='rgb(255, 255, 255)'),
        opacity=0.9,
        size=2 # ごちゃごちゃしないように小さめに設定するのがオススメです．
    )
)

data=[trace1]
layout=dict(height=1000, width=900, title='Log Template Vectors')
fig=dict(data=data, layout=layout)
offline.iplot(fig, filename='tsne_example')

# %%
from sklearn.manifold import TSNE

x = np.array(list(lt_vecs.values()))
tsne2d = TSNE(
    n_components=2, #ここが削減後の次元数です．
    init='random',
    random_state=101,
    method='barnes_hut',
    n_iter=1000,
    verbose=2
).fit_transform(x)

# %%
lt_cat = {vv:k.split('(')[0]  for k,v in  lt_per_cat.items() for vv in v}
cats = [lt_cat[k] for k in list(lt_vecs.keys())]

# %%
import plotly.offline as offline
import plotly.graph_objs as go
offline.init_notebook_mode()

le = preprocessing.LabelEncoder()
colors = le.fit_transform(cats)

trace2 = go.Scatter(
    x=tsne2d[:,0],
    y=tsne2d[:,1],
    mode='markers',
    text=list(lt_vecs.keys()),
    marker=dict(
        sizemode='diameter',
        color = colors,
        colorscale = 'Portland',
        colorbar=dict(
            title='Colorbar',
            tickvals = np.arange(len(le.classes_)),
            ticktext = le.classes_
        ),
        line=dict(color='rgb(255, 255, 255)'),
        opacity=0.9,
        size=5
    )
)

data=[trace2]
layout=dict(height=800, width=800, title='Log Template Vectors')
fig=dict(data=data, layout=layout)
offline.iplot(fig, filename='tsne_example')

# %%
vecs_df = pd.DataFrame(columns=["lt","v"], index=np.arange(len(lt_vecs)))

# %%
i = 0
for k,v in lt_vecs.items():
    vecs_df['lt'][i] = k
    vecs_df['v'][i] = list(v)
    i+=1

# %%
for cat,lts in lt_per_cat.items():
    
    for lt in lts:
        c = list(collections.Counter([word_dict[w] for w in string_to_corpus(lt, max_len=7)]).items())
        topic_dist, word_topic, word_topic_dist = lda[c]
        inf_topic = np.argmax(np.array([t[1] for t in topic_dist]))
        
        vecs_df.loc[vecs_df['lt']==lt, 'gt'] = cat
        vecs_df.loc[vecs_df['lt']==lt, 'tm'] = inf_topic

# %%
set(vecs_df["tm"])

# %%
tmp = vecs_df[vecs_df["gt"]=="system(alarm)"]

for i in tmp.iterrows():
    print(i[1]['lt'])
    plt.figure(figsize=(10, 5))
    plt.plot(i[1]['v'])
    plt.show()

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cos_mat = cosine_similarity(np.array(list(vecs_df["v"].values)), np.array(list(vecs_df["v"].values)))

# %%
for i in range(len(cos_mat)):
    print(vecs_df['lt'][i])
    print("top 10:")
    for j in zip(vecs_df['lt'][np.argsort(cos_mat[i])[::-1]][:10], np.sort(cos_mat[i])[::-1][:10]):
        print("\t", j)
    print()

# %%
for k,v in lt_vecs.items():
    if k == "** xntpd[**]: synchronized to **, stratum=**" or k =="xntpd[**]: kernel time sync disabled **":
        plt.figure(figsize=(10, 5))
        plt.title(k)
        plt.plot(v)
        plt.show()

# %% [markdown]
# ### 単純な手法と比較してみる
# - BoW をk-means

# %%
len(corpus)

# %%
vec_len = len(word_dict)

bow_vecs = []
for v in corpus:
    vec = np.zeros(vec_len)
    for vv in v:
        vec[vv[0]] = vv[1]
    bow_vecs.append(vec)
bow_vecs = np.array(bow_vecs)

# %%
bow_vecs.shape

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters=40,random_state=9)
km.fit(bow_vecs)

# %%
vecs_df['km'] = 0 
for class_label in range(40):
#     print(class_label)
    idx = (km.labels_==class_label)
    vecs_df['km'][idx] = class_label

# %%
from scipy.stats import entropy

# %% [markdown]
# - entropyは小さいほうがいい．

# %%
vecs_df

# %%
tmp = dict()
for row in vecs_df[vecs_df["gt"]=="interface(agg)"][["lt", "tm"]].iterrows():
    if row[1]["tm"] in tmp:
        tmp[row[1]["tm"]].append(row[1]["lt"])
    else:
        tmp[row[1]["tm"]] =[row[1]["lt"]]

# %%
for k,v in tmp.items():
    print(k, v)

# %%
# import pickle

# with open("vecs_df_20180805", "wb") as f:
#     pickle.dump(vecs_df, f)

# %%
for cat in lt_per_cat.keys():
    print(cat)

    rows = vecs_df[vecs_df['gt']==cat]
    print("#class(tm)\t", len(set(rows['tm'])))
    print("\t", collections.Counter(rows['tm']))
    print("\tEntropy:\t", entropy(list(collections.Counter(rows['tm']).values())))
    
    print("#class(km)\t", len(set(rows['km'])))
    print("\t", collections.Counter(rows['km']))
    print("\tEntropy:\t", entropy(list(collections.Counter(rows['km']).values())))

    tm_y = np.zeros(50)
    km_y = np.zeros(50)
    
    for k,v in collections.Counter(rows['tm']).items():
        tm_y[int(k)] = v
    for k,v in collections.Counter(rows['km']).items():
        km_y[k] = v
    
    plt.figure(figsize=(10, 5))
    plt.bar(np.arange(50), tm_y, label="tm")
    plt.bar(np.arange(50), km_y, label="km", alpha=0.6)
    plt.legend()
    plt.grid()
    plt.show()

    print()

# %%
import matplotlib as mpl
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['lines.color'] = 'r'
mpl.rcParams['axes.titlesize'] = 20
mpl.rcParams['font.size'] = 15
mpl.rcParams['axes.labelsize'] = 20
mpl.rcParams['lines.markersize'] = 12
mpl.rcParams['xtick.major.size'] = 15
mpl.rcParams['xtick.minor.size'] = 15
mpl.rcParams['ytick.major.size'] = 15

mpl.rcParams['text.usetex'] = False
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

# %%
gt_ent = {}
for cat in lt_per_cat.keys():
    rows = vecs_df[vecs_df['gt']==cat]
    class_t = len(set(rows['tm']))
    hist = np.array(list(collections.Counter(rows['tm']).values()))
    hist_max = hist.sum()
    ent_t = entropy(hist/hist_max)
    
    class_k = len(set(rows['km']))
    hist = np.array(list(collections.Counter(rows['km']).values()))
    hist_max = hist.sum()
    ent_k = entropy(hist/hist_max)
    
    gt_ent[cat] = ((class_t, ent_t), (class_k, ent_k))

# %%
gt_ent[cat]

# %%
y_tm

# %%
gt_ent_item = [(k,v) for k,v in gt_ent.items()]
x = [k for k,v in gt_ent_item]
y_tm = []
y_km = []

for p, cat in enumerate(x):
    y_tm.append(gt_ent[cat][0][1])
    y_km.append(gt_ent[cat][1][1])

plt.figure(figsize=(20, 14))
plt.subplot(211)
plt.subplots_adjust(top=0.95, bottom=0.1, left=0.18, right=0.95, hspace=0.5)
plt.bar(np.arange(32)-0.2, y_tm[:32], label="topic model", width=0.4)
plt.bar(np.arange(32)+0.2, y_km[:32], label="k-means", width=0.4)
plt.xticks(np.arange(32), x[:32], rotation=90)
plt.legend()
plt.ylabel("Entropy")
plt.grid()

plt.subplot(212)
plt.bar(np.arange(32)-0.2, y_tm[32:], label="topic model", width=0.4)
plt.bar(np.arange(32)+0.2, y_km[32:], label="k-means", width=0.4)
plt.xticks(np.arange(32), x[32:], rotation=90)
plt.legend()
plt.ylabel("Entropy")
plt.grid()


plt.show()

# %%
inf_ent = {}
for idx in range(40):
    
    rows = vecs_df[vecs_df['tm']==idx]
    ent_t = entropy(list(collections.Counter(rows['gt']).values()))
    
    rows = vecs_df[vecs_df['km']==idx]
    ent_k = entropy(list(collections.Counter(rows['gt']).values()))
    
    inf_ent[idx] = ((ent_t, ent_k))

# %%
# gt_ent_item = [(k,v) for k,v in gt_ent.items()]
x = np.arange(40)
y_tm = []
y_km = []

for idx in range(40):
    y_tm.append(inf_ent[idx][0])
    y_km.append(inf_ent[idx][1])

plt.figure(figsize=(14, 5))

plt.bar(np.arange(40)-0.2, y_tm, label="topic model", width=0.4)
plt.bar(np.arange(40)+0.2, y_km, label="k-means", width=0.4)
plt.xticks(np.arange(40), rotation=90)
plt.legend()
plt.ylabel("Entropy")
plt.grid()

plt.show()

# %%
for row in vecs_df[vecs_df["gt"]=="system(alarm)"].iterrows():
    print(row[1]['lt'])
    print("\t", row[1]['km'])

# %%
print(np.array(y_tm).mean())
print(np.array(y_tm).std())
print()
print(np.array(y_km).mean())
print(np.array(y_km).std())

# %%
print(np.array(y_tm).mean())
print(np.array(y_tm).std())
print()
print(np.array(y_km).mean())
print(np.array(y_km).std())

# %%
## 逆
cats = lt_per_cat.keys()
cats_idx = {i:e for e,i in enumerate(cats)}

for idx in range(40):
    print(idx)
    
    tm_y = np.zeros(len(cats))
    km_y = np.zeros(len(cats))
    
    rows = vecs_df[vecs_df['tm']==idx]
    print("#class(tm)\t", len(set(rows['gt'])))
    print("\t", collections.Counter(rows['gt']))
    print("\tEntropy:\t", entropy(list(collections.Counter(rows['gt']).values())))
    for k,v in collections.Counter(rows['gt']).items():
        tm_y[cats_idx[k]] = v

    rows = vecs_df[vecs_df['km']==idx]
    print("#class(km)\t", len(set(rows['gt'])))
    print("\t", collections.Counter(rows['gt']))
    print("\tEntropy:\t", entropy(list(collections.Counter(rows['gt']).values())))
    for k,v in collections.Counter(rows['gt']).items():
        km_y[cats_idx[k]] = v
    
    plt.figure(figsize=(10, 5))
    plt.bar(np.arange(len(cats)), tm_y, label="tm")
    plt.bar(np.arange(len(cats)), km_y, label="km", alpha=0.6)
    plt.legend()
    plt.grid()
    plt.show()

    print()

# %%
with open("lda_result", "w") as f:
    for i in range(40):
        f.write(str(i))
        f.write("\n")
        for j in vecs_df[vecs_df["tm"]==i]["lt"].values:
            f.write("\t"+j)
            f.write("\n")

# %%
with open("km_result", "w") as f:
    for i in range(40):
        f.write(str(i))
        f.write("\n")
        for j in vecs_df[vecs_df["km"]==i]["lt"].values:
            f.write(j)
            f.write("\n")

# %%
for cat in lt_per_cat.keys():
    print(cat)
    
    rows = vecs_df[vecs_df['gt']==cat]
#     print(rows[['lt', 'gt', 'tm', 'km']])
    print("#class(tm)\t", len(set(rows['tm'])))
    print("\t", collections.Counter(rows['tm']))
    print("\tEntropy:\t", entropy(list(collections.Counter(rows['tm']).values())))
    
    print("#class(km)\t", len(set(rows['km'])))
    print("\t", collections.Counter(rows['km']))
    print("\tEntropy:\t", entropy(list(collections.Counter(rows['km']).values())))

    print()

# %% [markdown]
# ### LTの距離について

# %%
t = []
for a,b in lt_per_cat.items():
    t.append((a, len(b)))
    
print(sorted(t, key=lambda x: x[1]))

# %%
km.cluster_centers_

# %%
tsne2d = TSNE(
    n_components=2, #ここが削減後の次元数です．
    init='random',
    random_state=101,
    method='barnes_hut',
    n_iter=500,
    verbose=2
).fit_transform(km.cluster_centers_)

# %%
t = []
for a,b in lt_per_cat.items():
    t.append((a, len(b)))
    
print(sorted(t, key=lambda x: x[1]))

t = [i[0] for i in sorted(t, key=lambda x:x[1])[::-1][2:26]]

# %%
t

# %%
t = ["network(mtu)","monitor(snmp)"]

# %%
bool_idx = [False]*len(vecs_df)
for i in t:
    bool_idx = bool_idx | (vecs_df["gt"]==i)

cat_names = vecs_df[bool_idx]["gt"]

# %%
z = np.array([np.array(i) for i in vecs_df[bool_idx]["v"].values])
z_keys = vecs_df[bool_idx]["lt"].values

# %%
["mgmt(login)", "system(ui)","mgmt(command)","mgmt(ssh)","monitor(snmp)","system(alarm)"]

# %%
a = vecs_df[vecs_df["lt"]=='rpd[**]: EVENT <SNMP Index> ** index ** <Up Broadcast Multicast>']["v"].values[0]
b = vecs_df[vecs_df["lt"]=='snmpd[**]: SNMPD_BIND_INFO: Source address for trap socket was set to **']["v"].values[0]

# %%
cosine_similarity(np.array((a,b)).reshape(2, -1))

# %%
vecs_df

# %%
vecs_df[vecs_df["gt"]=="service(ntp)"]

# %%
a = "/kernel: setting server address to **"
b = "xntpd[**]: kernel time sync enabled **"
c = "xntpd[**]: NTP Server Unreachable"

bow_a = bow_vecs[vecs_df["lt"]==a][0]
bow_b = bow_vecs[vecs_df["lt"]==b][0]
bow_c = bow_vecs[vecs_df["lt"]==c][0]

d1 = np.sqrt(sum([i**2 for i in bow_a - bow_b]))
d2 = np.sqrt(sum([i**2 for i in bow_a - bow_c]))
d3 = np.sqrt(sum([i**2 for i in bow_b - bow_c]))

v_a = np.array(vecs_df[vecs_df["lt"]==a]["v"].values[0])
v_b = np.array(vecs_df[vecs_df["lt"]==b]["v"].values[0])
v_c = np.array(vecs_df[vecs_df["lt"]==c]["v"].values[0])

d4 = np.sqrt(sum([i**2 for i in v_a - v_b]))
d5 = np.sqrt(sum([i**2 for i in v_a - v_c]))
d6 = np.sqrt(sum([i**2 for i in v_b - v_c]))

plt.figure()
plt.plot(v_a, label="a")
plt.plot(v_b, label="b")
plt.plot(v_c, label="c")
plt.legend()
plt.show()

# %%
print(d1, d2, d3)
print(d4, d5, d6)

# %%
for i  in vecs_df[vecs_df['gt']=="network(mtu)"].iterrows():
    print(i[1]['lt'], np.argsort(i[1]['v']))
    
    plt.figure()
    plt.plot(i[1]['v'])
    plt.show()

# %%
vecs_df[vecs_df['gt']=="monitor(snmp)"]['lt'].values

# %%
tmp_df

# %%
import seaborn as sns
tmp_df = pd.DataFrame(cosine_similarity(z), columns=cat_names, index=cat_names)

plt.figure(figsize=(20, 20))
sns.heatmap(tmp_df)
plt.show()

# %%
tmp_df = pd.DataFrame(cosine_similarity(bow_vecs[bool_idx]), columns=cat_names, index=cat_names)

plt.figure(figsize=(20, 20))
sns.heatmap(tmp_df)
plt.show()

# %%
tsne2d = TSNE(
    n_components=2, #ここが削減後の次元数です．
    init='random',
    random_state=101,
    method='barnes_hut',
    n_iter=500,
    verbose=2
).fit_transform(z)

# %%
import plotly.offline as offline
import plotly.graph_objs as go
offline.init_notebook_mode()

le = preprocessing.LabelEncoder()
colors = le.fit_transform(cat_names)

trace2 = go.Scatter(
    x=tsne2d[:,0],
    y=tsne2d[:,1],
    mode='markers',
    text=[i[:50] for i in z_keys],
    marker=dict(
        sizemode='diameter',
        color = colors,
        colorscale = 'Portland',
        colorbar=dict(
            title='Colorbar',
            tickvals = np.arange(len(le.classes_)),
            ticktext = le.classes_
        ),
        line=dict(color='rgb(255, 255, 255)'),
        opacity=0.9,
        size=5
    )
)

data=[trace2]
layout=dict(height=800, width=800, title='Log Template Vectors')
fig=dict(data=data, layout=layout)
offline.iplot(fig, filename='tsne_example')

# %%
z = np.array([np.array(i) for i in vecs_df[bool_idx]["v"].values])
z_keys = vecs_df[bool_idx]["lt"].values

# %%
tsne2d = TSNE(
    n_components=2, #ここが削減後の次元数です．
    init='random',
    random_state=101,
    method='barnes_hut',
    n_iter=500,
    verbose=2
).fit_transform(z)

# %%
import plotly.offline as offline
import plotly.graph_objs as go
offline.init_notebook_mode()

le = preprocessing.LabelEncoder()
colors = le.fit_transform(cat_name)

trace2 = go.Scatter(
    x=tsne2d[:,0],
    y=tsne2d[:,1],
    mode='markers',
    text=[i[:50] for i in z_keys],
    marker=dict(
        sizemode='diameter',
        color = colors,
        colorscale = 'Portland',
        colorbar=dict(
            title='Colorbar',
            tickvals = np.arange(len(le.classes_)),
            ticktext = le.classes_
        ),
        line=dict(color='rgb(255, 255, 255)'),
        opacity=0.9,
        size=5
    )
)

data=[trace2]
layout=dict(height=800, width=800, title='Log Template Vectors')
fig=dict(data=data, layout=layout)
offline.iplot(fig, filename='tsne_example')

# %%
vecs_df[vecs_df["gt"]=="vpn(mpls)"]

# %% [markdown]
# ### 単純な手法と比較して見る-2
# - 編集距離

# %%
inf_topic_words[23]

# %%
import Levenshtein

string1 = "井上泰治"
string2 = "井上泰次"

print(Levenshtein.distance(string1, string2))

# %%
KMeans()

# %%
for i in vecs_df["lt"].values:
    print(i)
    print(string_to_corpus(i))
    
    
    break

# %%
idxs = np.argsort(cos_mat[72])[::-1][:60]

for idx in idxs:
    print(vecs_df["lt"][idx])

    v = np.array([i for i in vecs_df["v"][idx]])
    print(np.where(v>0.08))
    
    plt.figure(figsize=(10,5))
    plt.plot(v)
    plt.grid()
    plt.show()

# %%
plt.style.use('seaborn-colorblind')
plt.style.use('seaborn-whitegrid')
cvs = []

for cat, res in inf_per_cat.items():
    plt.figure(figsize=(15, 5))
    plt.title(cat)
    y = collections.Counter(res)
    y = [y[i] if i in y else 0 for i in range(40)]
    plt.bar(np.arange(40), y, color="#85C1E9")
    plt.xticks(np.arange(40))
    minY = 5 if max(y) < 5 else max(y)+1
    plt.ylim(0, minY)
    plt.show()

    print(np.array(y).std())
    cvs.append((cat, np.array(y).std()/np.array(y).mean()))

# %% [markdown]
# - ppe, snmp, l2, ui, pfe, fpc, agg, None

# %%
sorted_t = sorted(cvs, key=lambda x: x[1], reverse=True)

plt.figure(figsize=(15, 5))
plt.title('cv')
plt.bar(np.arange(len(sorted_t)), [i[1] for i in sorted_t], color="#85C1E9")
plt.xticks(np.arange(len(sorted_t)), [i[0] for i in sorted_t],rotation=90)
plt.hlines(3.5, xmin=0, xmax=len(sorted_t), color='red',linestyles='dotted', lw=3)
plt.show()

# %%
cat_per_inf

# %%
y = collections.Counter(res)
y = [y[i] if i in y else 0 for i in inf_per_cat.keys()]
y = np.array(y) / total_per_cat

# %%
## 逆変換

total_per_cat = np.array([len(lt_per_cat[i]) for i in inf_per_cat.keys()])

cat_per_inf = dict()
for i in range(40):
    cat_per_inf[i] = []

for cat, res in inf_per_cat.items():
    for r in res:
        cat_per_inf[r].append(cat)
    
for cat, res in cat_per_inf.items():
    plt.figure(figsize=(15, 5))
    plt.title(cat)
    y = collections.Counter(res)
    y = [y[i] if i in y else 0 for i in inf_per_cat.keys()]
    y = np.array(y) / total_per_cat
    plt.bar(np.arange(len(inf_per_cat)), y, color="#85C1E9")
    plt.xticks(np.arange(len(inf_per_cat)), inf_per_cat.keys(), rotation=90)
    plt.ylabel("#LT/#LT in the cat")
#     minY = 5 if max(y) < 5 else max(y)+1
#     plt.ylim(0, minY)
    plt.ylim(0, 1)
    plt.show()

# %%
lt_per_inf_topic = {}
for i in range(40):
    lt_per_inf_topic[i] = []
    
for ltid, data in raw_lt.items():
    lt = data['lt']
        
    c = list(collections.Counter([word_dict[w] for w in string_to_corpus(lt, max_len=7)]).items())
    topic_dist, word_topic, word_topic_dist = lda[c]
    inf_topic = np.argmax(np.array([t[1] for t in topic_dist]))
    
    lt_per_inf_topic[inf_topic].append((lt, string_to_corpus(lt, max_len=7)))

# %%
for inf_topic, lts in lt_per_inf_topic.items():
    print(inf_topic, inf_topic_words[inf_topic])
    
    for lt in lts:
        print("\t", lt[0], "\t",  lt[1])
    print()

# %% [markdown]
# ### グラフ生成
#
# - エッジの重みは，GTノードから出ているエッジの，それぞれの発生回数の割合

# %%
inf_per_cat

# %%
G = nx.DiGraph()
nx.set_node_attributes

pos = {}
for i,k in enumerate(inf_per_cat.keys()):
    if 'None' in k:
        pos[k] = (2,i)
    else:
        pos[k] = (0, i)
for i in range(40):
    pos[i] = (1, len(inf_per_cat)/40*i)

for cat, res in inf_per_cat.items():
    if cat not in G.nodes:
        G.add_node(cat)
        
    col = collections.Counter(res) # dstの集計
    total = sum(col.values())
    for dst, weight in col.items():
        if dst not in G.nodes:
            G.add_node(dst)
        G.add_edge(cat, dst, weight=weight/total)
        
for n, p in pos.items():
    G.node[n]['pos'] = p

# %%
for a in G.edges(data=True):
    print(a)

# %%
inf_node_edge_weight = dict()
for a,b in G.edges.items():
    if 'None'  in a[0]:
            if a[1] in inf_node_edge_weight:
                inf_node_edge_weight[a[1]] += 0
            else:
                inf_node_edge_weight[a[1]] = 0
        
    if a[1] in inf_node_edge_weight:
        inf_node_edge_weight[a[1]] += b['weight']
    else:
        inf_node_edge_weight[a[1]] = b['weight']
        
        
# edge_size = [i[2]['weight']*2 for i in G.edges(data=True)]
# edge_size = [1 if i[2]['weight']==1.0  else 0 for i in G.edges(data=True)]
# edge_size = [i[2]['weight'] if i[2]['weight']>0.55 else 0  for i in G.edges(data=True)]
edge_size = [i[2]['weight'] if "None" not in i[0] else -1 for i in G.edges(data=True)]

# %%
x = collections.Counter([int(e*1000)/10 for e in edge_size])
plt.figure(figsize=(10, 5))
plt.bar(x.keys(), x.values())
plt.title("Edge weights distribution")
plt.xlabel("%")
plt.ylabel("#edges")
plt.xticks([i for i in range(0, 100, 10)])
plt.show()

# %%
x = collections.Counter([int(e*1000)/10 for e in edge_size])

# remove -100% data
x = sorted(x.items(), key=lambda x:x[0])
x[0] = (0., 0)

plt.figure(figsize=(10, 5))
plt.bar([i[0] for i in x], [i[1] for i in x])
plt.title("Edge weights distribution (without 'None')")
plt.xlabel("%")
plt.ylabel("#edges")
plt.xticks([i for i in range(0, 100, 10)])
plt.ylim(0, 30)
plt.show()

# %%
print('All edges:', len(G.edges()))

print('Without None:', len([(k,v) for k,v in G.edges.items() if 'None' not in k[0]]))

# %%
# エッジ1本のみ
for i in np.where(np.array(edge_size)==1)[0]:
    print(list(G.edges())[i], "\t", edge_size[i])
    
print()
for i in np.where(np.array(edge_size)>0.55)[0]:
    print(list(G.edges())[i], "\n\t", edge_size[i], len(lt_per_cat[list(G.edges())[i][0]]))

# %%
plt.figure(figsize=(20, 30))
node_size = [20 if type(g) == str else inf_node_edge_weight[g]*500 for g in G.nodes]
nx.draw_networkx(G, pos, node_color='b', alpha=0.6, node_size=node_size, width=edge_size, edge_color='g')

plt.show()

# nx.draw_networkx_labels(G, pos, fontsize=14, font_family="Yu Gothic", font_weight="bold")

# edge_width = [ d['weight']*0.2 for (u,v,d) in G.edges(data=True)]
# nx.draw_networkx_edges(G, pos, alpha=0.4, edge_color='C', width=edge_width)

# plt.axis('off')
# plt.savefig("g2.png")
# plt.show()

# %% [markdown]
# ### 集計結果
#
# - gtのカテゴリごとに，どのトピックが振られたかを確認
#     - カテゴリとトピックのそれらしい対応をつけて見た
#     - 複数マージされるものと，対応づけられなかったものが存在
# - 訓練じはUIの単語を含むものは除外したが，評価じは全て含めた
# - gt通りにうまくいったものは存在

# %% [markdown]
# ## VyOS

# %%
with open("./vyos_logs/tpl_all_uniq", "r") as f:
    raw_vyos = f.readlines()

# %%
corpus = []
for lt in raw_vyos:
    words = [remove_symbols(t) for t in lt.split()]
    split_words = []
    for w in words:
        if len(w.split()) > 1: # さらに分割できる場合
            split_words.extend(w.split())
        else:
            split_words.append(w)
    split_words = [t.lower() for t in split_words if t != '']
    corpus.append(split_words)

# %%
all_words = list(set([word for words in corpus for word in words]))
word_dict = {w:i for i, w in enumerate(all_words)}
inv_word_dict = {v:k for k,v in word_dict.items()}

corpus = []
for lt in raw_vyos:
    words = [remove_symbols(t) for t in lt.split()]
    split_words = []
    for w in words:
        if len(w.split()) > 1: # さらに分割できる場合
            split_words.extend(w.split())
        else:
            split_words.append(w)
    split_words = [t.lower() for t in split_words if t != '']
    
    split_words = [w for w in split_words]

    split_words = split_words[:7] # 前方のみ残す

    lt_word_id_cnt = collections.Counter([word_dict[w] for w in split_words])

    corpus.append([(tid, cnt) for tid, cnt in lt_word_id_cnt.items()])

# %%
# 単語のカウント
word_cnt = {}
for wid, cnt in sorted(collections.Counter([c[0] for s in corpus for c in s]).items(), key= lambda x: x[1])[::-1]:
    print(inv_word_dict[wid], cnt)
    word_cnt[inv_word_dict[wid]] = cnt

# %%
# LTレベルの共起
cor_df = pd.DataFrame(index=np.arange(len(word_dict)), columns=np.arange(len(word_dict)), dtype=int)
cor_df = cor_df.fillna(0)

for s in corpus:
    for a,b in itertools.combinations(s, 2):
        ida = int(a[0])
        idb = int(b[0])
        cor_df[ida][idb] += 1
        cor_df[idb][ida] += 1

cor_list = []
for a,b in itertools.combinations(np.arange(len(word_dict)), 2):
    if cor_df[a][b] != 0 :
        cor_list.append([(a, b) , cor_df[a][b]])
        
# for i in tqdm.tqdm(sorted(cor_list, key=lambda x:x[1], reverse=True)):
#     a,b = i[0]
#     print(inv_word_dict[a], inv_word_dict[b], i[1])
#     print("\t simpson:", i[1]/min(word_cnt[inv_word_dict[a]], word_cnt[inv_word_dict[b]]))
#     print("\t jaccard:", i[1]/(word_cnt[inv_word_dict[a]] + word_cnt[inv_word_dict[b]] - i[1]))
#     print()

# %%
word_dict['failed']

# %%
cor_df[315].sum()

# %%
plot_data = [i[1] for i in sorted(cor_list, key=lambda x:x[1], reverse=True)][1000:2000]
plt.figure(figsize=(15, 15))
plt.bar(np.arange(len(plot_data)), plot_data)
plt.grid()
plt.show()

# %%
G = nx.DiGraph()
nx.set_node_attributes

for i in sorted(cor_list, key=lambda x:x[1], reverse=True):
    if i[1] > 50: # 共起がn回以上
        a,b = i[0]
        
        if inv_word_dict[a] == 'failed' or inv_word_dict[a] == 'cant' or inv_word_dict[b] == 'failed' or inv_word_dict[b] == 'cant':
            continue
            
        simpson = i[1]/min(word_cnt[inv_word_dict[a]], word_cnt[inv_word_dict[b]])
        jaccard = i[1]/(word_cnt[inv_word_dict[a]] + word_cnt[inv_word_dict[b]] - i[1])
        
        print(simpson)
        if simpson > 0.95:
            if a not in G.nodes:
                G.add_node(inv_word_dict[a])

            if b not in G.nodes:
                G.add_node(inv_word_dict[b])

            src = inv_word_dict[a] if np.argmin([word_cnt[inv_word_dict[a]], word_cnt[inv_word_dict[b]]]) == 0 else inv_word_dict[b]
            dst = inv_word_dict[a] if src == inv_word_dict[b] else inv_word_dict[b]
            G.add_edge(src, dst, weight=jaccard)

# %%
json_data = nx.node_link_data(G)
f = open("./d3_test/vyos_nx.json", "w")
json.dump(json_data, f, ensure_ascii=False, indent=4, sort_keys=True, separators=(',', ': '))
f.close()

# %%
plt.figure(figsize=(13, 13))
nx.draw_networkx(G, pos=nx.shell_layout(G))
plt.show()

# %% [markdown]
# ## LDA

# %% [markdown]
# ### full length

# %%
for cat, lts in lt_per_cat.items():
    print(cat)

# %%
tmp = []
eval_corpus = []
eval_corpus_ltids = []
for ltid, i in enumerate(corpus):
    if word_dict['ui'] not in [j[0] for j in i]: # uiを弾く(550番)
        tmp.append(tuple(sorted(i)))
        eval_corpus.append(i)
        eval_corpus_ltids.append(ltid)
    
print(len(tmp))
set_corpus = list(set(tmp))

# %%
corpus

# %%
lda = gensim.models.ldamodel.LdaModel(
                                      #corpus=corpus, 
                                      corpus=set_corpus,
                                      chunksize=10,
                                      num_topics=40, 
                                      id2word=inv_word_dict, 
                                      minimum_probability=1e-8, 
                                      #gamma_threshold=1e-5,
                                      #eval_every=10,
                                      iterations=100,
#                                       alpha='auto', 
#                                       eta='auto', 
                                      decay=1.0,
                                      passes=1,
                                      per_word_topics=True)

# %%
results =  [np.argmax(l) for l in lda.inference(eval_corpus)[0]]

inference_results = {}
for a,b in zip(eval_corpus, results):
    if b in inference_results:
        inference_results[b].append([inv_word_dict[c[0]] for c in a])
    else:
        inference_results[b] = [[inv_word_dict[c[0]] for c in a]]

# %%
for topic in range(lda.num_topics):
    print(topic, [inv_word_dict[i[0]] for i in lda.get_topic_terms(topic)])
# print('1', [inv_word_dict[i[0]] for i in lda.get_topic_terms(1)])

# %%
inf_ltids = {}
for ltid, inf_cat in results.items():
    if inf_cat in inf_ltids:
        inf_ltids[inf_cat].append(ltid)
    else:
        inf_ltids[inf_cat] = [ltid]

# %%
for inf_cat, ltids in inf_ltids.items():
    print("topic:", inf_cat)
    for i in ltids:
        print(raw_lt[str(i)]['lt'])
    print()

# %% [markdown]
# ### eval
#
# - 外れたやつについて，調査

# %%
compared_results = {}
for inf_cat, ltids in inf_ltids.items():
    for ltid in ltids:
        true_cat = raw_lt[str(ltid)]['cat']
        if true_cat in compared_results:
            compared_results[true_cat].append((ltid, inf_cat))
        else:
            compared_results[true_cat] = [(ltid, inf_cat)]

# %%
for cat, res in compared_results.items():
    plt.figure(figsize=(15, 5))
    plt.title(cat)
    y = collections.Counter([r[1] for r in res])
    y = [y[i] if i in y else 0 for i in range(40)]
#     print(collections.Counter([r[1] for r in res]), y)
    plt.bar(np.arange(40), y)
    plt.show()
